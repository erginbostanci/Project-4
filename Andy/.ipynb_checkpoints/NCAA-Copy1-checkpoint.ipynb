# %%
import requests
import json
import sklearn
import pandas as pd
import numpy as pd
import csv
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
import tensorflow as tf


from config import api_key

from pprint import pprint
# Out:
# C:\Users\ahumb\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bba3e2f09c3d> in <module>()
#      11
#      12
# ---> 13 from config import api_key
#      14
#      15 from pprint import pprint
#
# ModuleNotFoundError: No module named 'config'

# %%
League_url = "http://api.sportradar.us/ncaamb/trial/v4/en/league/hierarchy.json?"+{api_key}

Team_url = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/"+{2018}+"/REG/teams/fae4855b-1b64-4b40-a632-9ed345e1e952/statistics.json?"+{api_key}




format = "json"

# %%
League_response = requests.get(League_url).json()


print (League_response)

# %%
print(json.dumps(League_response, indent=4, sort_keys=True))
# Out:
# {
#     "divisions": [
#         {
#             "alias": "ACCA",
#             "conferences": [
#                 {
#                     "alias": "NCCAA",
#                     "id": "328295f9-c326-48c2-b553-f2e2c49f4f10",
#                     "name": "National Christian College Athletic Association",
#                     "teams": [
#                         {
#                             "alias": "PIU",
#                             "id": "495c6d01-0c8b-4c18-b3ab-b2bc662f4615",
#                             "market": "Piedmont International",
#                             "name": "Bruins"
#                         },
#                         {
#                             "alias": "BC",
#                             "id": "63e9eb95-8097-422f-9444-ec1cb850a8e9",
#                             "market": "Boyce College",
#                             "name": "Bulldogs"
#                         },
#                         {
#                             "alias": "LCU",
#                             "id": "bf6b9db6-ca43-4cc3-99f1-cc4641cdc7c0",
#                             "market": "Lincoln Christian University",
#                             "name": "Red Lions"
#                         },
#                         {
#                             "alias": "BARC",
#                             "id": "c2749176-0670-4535-a27f-12fe69b853dc",
#                             "market": "Barclay College",
#                             "name": "Bears"
#                         },
#                         {
#                             "alias": "JOHN",
#                             "id": "c3daed6f-bbe4-4afb-946b-34174b8e954e",
#                             "market": "Johnson (FL)",
#                             "name": "Suns"
#                         },
#                         {
#                             "alias": "WLCH",
#                             "id": "dd86b4dd-85cf-4be0-a3a4-338a69b69662",
#                             "market": "Welch",
#                             "name": "Flames"
#                         },
#                         {
#                             "alias": "NEWH",
#                             "id": "fc1fd728-13ca-4f5a-bb77-1c838b02eccd",
#                             "market": "New Hope Christian College",
#                             "name": "Deacons"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "ACCA-IND",
#                     "id": "d69f2770-9310-45f7-9465-a6c1fe2567cc",
#                     "name": "Independents (ACCA)",
#                     "teams": [
#                         {
#                             "alias": "DW",
#                             "id": "c1dd489f-4ada-43e9-aecd-06d02304c695",
#                             "market": "Daniel Webster",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "CBAP",
#                             "id": "cd34248e-6f7d-4e0a-b694-567699bd7917",
#                             "market": "Champion Christian College",
#                             "name": "Tigers"
#                         }
#                     ]
#                 }
#             ],
#             "id": "18b713d6-561d-4aab-8986-175c4da04aa8",
#             "name": "ACCA"
#         },
#         {
#             "alias": "CIS",
#             "conferences": [
#                 {
#                     "alias": "OUA",
#                     "id": "52039746-5c2b-4edf-830d-1d05055b81eb",
#                     "name": "Ontario University Athletics",
#                     "teams": [
#                         {
#                             "alias": "RYER",
#                             "id": "358a140d-ac17-440a-85e7-0a4ecfc381e2",
#                             "market": "Ryerson",
#                             "name": "Rams"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "QSSF",
#                     "id": "fd092b06-3f32-46c4-aa69-3adfd580bd71",
#                     "name": "Quebec Student Sports Federation",
#                     "teams": [
#                         {
#                             "alias": "MU",
#                             "id": "bcb07ee4-16d2-4185-aadd-89087e59a551",
#                             "market": "McGill University",
#                             "name": "Redmen"
#                         }
#                     ]
#                 }
#             ],
#             "id": "274ff4e0-b1d6-420a-90ff-55b97426cd6d",
#             "name": "Canadian Interuniversity Sport"
#         },
#         {
#             "alias": "NAIA",
#             "conferences": [
#                 {
#                     "alias": "KCAC",
#                     "id": "02cdb06e-b644-48e8-a5c9-dd235b888f7a",
#                     "name": "Kansas Collegiate Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "BETH",
#                             "id": "0dd44ba7-caf4-4b4f-8b65-120f51fd05d7",
#                             "market": "Bethany (KS)",
#                             "name": "Swedes"
#                         },
#                         {
#                             "alias": "YORK",
#                             "id": "34309039-b4f3-4afc-96a3-844ec0e9a150",
#                             "market": "York College (NE)",
#                             "name": "Panthers"
#                         },
#                         {
#                             "alias": "SWKS",
#                             "id": "3ab6c233-e223-442f-875f-e8d0ceb34df9",
#                             "market": "Southwestern (KS)",
#                             "name": "Moundbuilders"
#                         },
#                         {
#                             "alias": "MCPH",
#                             "id": "b40c3e0f-fef2-41a0-98c6-40534b64f613",
#                             "market": "McPherson",
#                             "name": "Bulldogs"
#                         },
#                         {
#                             "alias": "OU",
#                             "id": "e87a6c52-ca0b-4380-a5a4-d8de94b208a6",
#                             "market": "Ottawa University",
#                             "name": "Braves"
#                         },
#                         {
#                             "alias": "TAB",
#                             "id": "ea22a80e-0194-4bda-99d1-a32f3545fffc",
#                             "market": "Tabor College",
#                             "name": "Bluejays"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "MCC",
#                     "id": "3e37a5b4-29da-488f-8176-3b33121c036d",
#                     "name": "Midwest Collegiate Conference",
#                     "teams": [
#                         {
#                             "alias": "MTME",
#                             "id": "42348211-a433-42be-a316-043f1bfbb3df",
#                             "market": "Mount Mercy",
#                             "name": "Mustangs"
#                         },
#                         {
#                             "alias": "STAU",
#                             "id": "84212ed4-bc31-469b-ac46-41584e83deec",
#                             "market": "St. Ambrose",
#                             "name": "Fighting Bees"
#                         },
#                         {
#                             "alias": "VIT",
#                             "id": "fac4a71e-40a9-47a6-b8d9-61a50d3c6edc",
#                             "market": "Viterbo",
#                             "name": "Hawks"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "MSC",
#                     "id": "3e7f8b62-5379-4895-8883-5aadcd8b0704",
#                     "name": "Mid-South Conference",
#                     "teams": [
#                         {
#                             "alias": "UCUM",
#                             "id": "1afc7dda-f6cb-4daa-8e98-14e29d3361c7",
#                             "market": "University of the Cumberlands",
#                             "name": "Patriots"
#                         },
#                         {
#                             "alias": "CMPB",
#                             "id": "2855b228-8b34-458b-8f9b-009cb15d6629",
#                             "market": "Campbellsville",
#                             "name": "Tigers"
#                         },
#                         {
#                             "alias": "CUMB",
#                             "id": "7337246a-e264-43e6-8d60-ecd64ccbbdb3",
#                             "market": "Cumberland",
#                             "name": "Phoenix"
#                         },
#                         {
#                             "alias": "LW",
#                             "id": "99a4192a-ac50-4edd-bd9a-4dbd1f5ed22e",
#                             "market": "Lindsey Wilson",
#                             "name": "Blue Raiders"
#                         },
#                         {
#                             "alias": "SCC",
#                             "id": "c893e13b-c0d1-4b27-b9de-e3785eb3f08c",
#                             "market": "Saint Catharine",
#                             "name": "Patriots"
#                         },
#                         {
#                             "alias": "GC",
#                             "id": "dc68eec8-de7b-4ef5-94dc-9847d2ebfb9e",
#                             "market": "Georgetown College",
#                             "name": "Tigers"
#                         },
#                         {
#                             "alias": "LIFE",
#                             "id": "df17c9cf-be8a-43d7-a43f-a0a367f094fb",
#                             "market": "Life University",
#                             "name": "Running Eagles"
#                         },
#                         {
#                             "alias": "SWST",
#                             "id": "e10bfa81-450c-43a3-8748-451d931f4990",
#                             "market": "Shawnee State",
#                             "name": "Bears"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "PCAC",
#                     "id": "4044ffb4-b89a-44d0-a658-4dcb1d9c5e5c",
#                     "name": "Pacific Coast Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "SK",
#                             "id": "0a50907c-0141-4d40-81e7-d1652b307838",
#                             "market": "Saint Katherine",
#                             "name": "Firebirds"
#                         },
#                         {
#                             "alias": "BRIS",
#                             "id": "6397f307-7734-430f-8af8-404a1c795baa",
#                             "market": "Bristol",
#                             "name": "Bears"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "HAAC",
#                     "id": "509a1d98-5d50-45b3-8f2a-d9bead591683",
#                     "name": "Heart of America Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "PERU",
#                             "id": "0eebcb32-e9ab-4869-9576-81f94c8e9815",
#                             "market": "Peru State",
#                             "name": "Bobcats"
#                         },
#                         {
#                             "alias": "AVU",
#                             "id": "0f91d69b-7cbe-4e68-ba83-98d099b5e72e",
#                             "market": "Avila",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "EVAN",
#                             "id": "8784cd8e-00f3-47b9-8788-29172ee14d9d",
#                             "market": "Evangel",
#                             "name": "Crusaders"
#                         },
#                         {
#                             "alias": "BAK",
#                             "id": "cad7ac49-62b6-4681-aefd-4239ed29f8ee",
#                             "market": "Baker",
#                             "name": "Wildcats"
#                         },
#                         {
#                             "alias": "CEME",
#                             "id": "d71421ad-7010-4ede-84c2-484a89541b74",
#                             "market": "Central Methodist",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "MVC",
#                             "id": "d8f9f177-ed14-49ec-acc6-3856390a3907",
#                             "market": "Missouri Valley",
#                             "name": "Vikings"
#                         },
#                         {
#                             "alias": "GU",
#                             "id": "e6a41be0-b1a1-4bba-beb4-330a7ea6b20d",
#                             "market": "Graceland",
#                             "name": "Yellow Jackets"
#                         },
#                         {
#                             "alias": "CVST",
#                             "id": "e83b24a0-ebe8-4f37-92ce-6c5944b18085",
#                             "market": "Culver-Stockton",
#                             "name": "Wildcats"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "RSC",
#                     "id": "5137513f-9e3b-4a96-854d-c1acbf38fc03",
#                     "name": "River States Conference",
#                     "teams": [
#                         {
#                             "alias": "OCU",
#                             "id": "25fb8b8c-9450-40f4-bb90-ea3f99d55ef4",
#                             "market": "Ohio Christian",
#                             "name": "Trailblazers"
#                         },
#                         {
#                             "alias": "CARL",
#                             "id": "579819c8-c472-466a-a73b-d721058305bf",
#                             "market": "Carlow",
#                             "name": "Celtics"
#                         },
#                         {
#                             "alias": "MID",
#                             "id": "bdf7405d-66c0-4b2d-9764-d7152c264eaa",
#                             "market": "Midway",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "PPRK",
#                             "id": "de2358b1-7905-486a-b159-220ab3bd4000",
#                             "market": "Point Park",
#                             "name": "Pioneers"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "GCAC",
#                     "id": "53c58838-49b8-42a9-85ee-030c08040721",
#                     "name": "Gulf Coast Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "TC",
#                             "id": "2d627295-cce2-4c48-928d-d7a202d9a502",
#                             "market": "Tougaloo",
#                             "name": "Bulldogs"
#                         },
#                         {
#                             "alias": "EWC",
#                             "id": "62984600-6d23-46ba-ab2f-1661582d02d1",
#                             "market": "Edward Waters",
#                             "name": "Tigers",
#                             "venue": {
#                                 "address": "1859 Kings Road",
#                                 "capacity": 1800,
#                                 "city": "Jacksonville",
#                                 "country": "USA",
#                                 "id": "3ed83554-50e7-41fe-bf0d-f3c36ead4176",
#                                 "name": "Edward Waters Gymnasium",
#                                 "state": "FL",
#                                 "zip": "32209"
#                             }
#                         },
#                         {
#                             "alias": "DILL",
#                             "id": "690ee661-1b4f-4d9d-8af0-8f5f6c42054b",
#                             "market": "Dillard",
#                             "name": "Bleu Devils"
#                         },
#                         {
#                             "alias": "XULA",
#                             "id": "7cf3a95e-a7f5-4789-a76d-e652c4963f4a",
#                             "market": "Xavier University of Louisiana",
#                             "name": "Gold Rush"
#                         },
#                         {
#                             "alias": "SUNO",
#                             "id": "f58d6a9a-992c-4e1c-aed9-97ce54907e07",
#                             "market": "Southern University at New Orleans",
#                             "name": "Knights"
#                         },
#                         {
#                             "alias": "VOOR",
#                             "id": "fdd807b5-adce-4041-9dcd-3ff69865cda7",
#                             "market": "Voorhees",
#                             "name": "Tigers"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "KIAC",
#                     "id": "5689efb2-d8e8-41e9-9219-842dc917ba76",
#                     "name": "Kentucky Intercollegiate Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "ASBY",
#                             "id": "22d734ec-c0f1-4d28-9de1-3867597393c1",
#                             "market": "Asbury",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "BRES",
#                             "id": "345a1791-10ce-4443-8a6b-2688e5804911",
#                             "market": "Brescia",
#                             "name": "Bearcats"
#                         },
#                         {
#                             "alias": "IUK",
#                             "id": "5c2ca084-02c4-41e5-84ce-6e565d096dc8",
#                             "market": "Indiana-Kokomo",
#                             "name": "Cougars"
#                         },
#                         {
#                             "alias": "RIO",
#                             "id": "6bbd35c9-6e6c-41d0-9143-194cf3dc368b",
#                             "market": "Rio Grande",
#                             "name": "Red Storm"
#                         },
#                         {
#                             "alias": "CCU",
#                             "id": "9057c8ed-7577-4381-babd-28b5a698ff8b",
#                             "market": "Cincinnati Christian",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "ALC",
#                             "id": "dc9bf155-af55-44db-baff-3621558ac1f7",
#                             "market": "Alice Lloyd",
#                             "name": "Eagles"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "NAIA-AAC",
#                     "id": "588af0ee-e211-4104-9f27-2f81fad68b2b",
#                     "name": "Appalachian Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "TRUE",
#                             "id": "2de2f805-e9dd-4126-9e0e-d2e568552cf8",
#                             "market": "Truett-McConnell",
#                             "name": "Bears"
#                         },
#                         {
#                             "alias": "UNIC",
#                             "id": "3341a5e9-0fb8-4e22-acfd-cc800c72f008",
#                             "market": "Union (KY)",
#                             "name": "Bulldogs"
#                         },
#                         {
#                             "alias": "TNW",
#                             "id": "5a5349ae-c4fa-4a92-9398-837003ec2fe1",
#                             "market": "Tennessee Wesleyan",
#                             "name": "Bulldogs"
#                         },
#                         {
#                             "alias": "STAN",
#                             "id": "74f890b7-e5ec-4217-9359-4f7b8a55b67c",
#                             "market": "St. Andrews",
#                             "name": "Knights"
#                         },
#                         {
#                             "alias": "PU",
#                             "id": "86579b93-b7f4-487d-bb34-5f42e7271433",
#                             "market": "Point University",
#                             "name": "Skyhawks"
#                         },
#                         {
#                             "alias": "REIN",
#                             "id": "9b9644e4-47cd-4616-8ae0-364461454784",
#                             "market": "Reinhardt",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "MONT",
#                             "id": "a6d6d859-ed70-47eb-8b5a-ff6843136696",
#                             "market": "Montreat",
#                             "name": "Cavaliers"
#                         },
#                         {
#                             "alias": "BRYC",
#                             "id": "d0ea7e30-a15f-4c37-99ea-d316c4a12a7e",
#                             "market": "Bryan College",
#                             "name": "Lions"
#                         },
#                         {
#                             "alias": "BLUE",
#                             "id": "e0f237b4-c832-4123-b750-e962e9acf25f",
#                             "market": "Bluefield",
#                             "name": "Rams"
#                         },
#                         {
#                             "alias": "MILL",
#                             "id": "f2ff8456-7a8d-427b-8418-4216b6f241bf",
#                             "market": "Milligan",
#                             "name": "Buffaloes"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "CROSS",
#                     "id": "6730f185-9783-43ad-a3fa-b67f3fb4b22a",
#                     "name": "Crossroads League",
#                     "teams": [
#                         {
#                             "alias": "GC",
#                             "id": "170dca43-d296-4994-8613-4aad63826bcc",
#                             "market": "Goshen College",
#                             "name": "Maple Leafs"
#                         },
#                         {
#                             "alias": "TAY",
#                             "id": "1d542153-752a-4c0f-8dd6-b467ede4bd2a",
#                             "market": "Taylor",
#                             "name": "Trojans"
#                         },
#                         {
#                             "alias": "MVNU",
#                             "id": "41c784b2-5169-4d54-936b-41b4b26757bb",
#                             "market": "Mount Vernon Nazarene",
#                             "name": "Cougars"
#                         },
#                         {
#                             "alias": "GRCE",
#                             "id": "521ceae1-7a2b-4159-b4df-2a665a84c09e",
#                             "market": "Grace College",
#                             "name": "Lancers"
#                         },
#                         {
#                             "alias": "MARI",
#                             "id": "c3a808e6-2c5d-415f-9cd5-334148961392",
#                             "market": "Marian (IN)",
#                             "name": "Knights"
#                         },
#                         {
#                             "alias": "SAU",
#                             "id": "e43fdcb1-c679-4fc8-9b66-c6171603a1c7",
#                             "market": "Spring Arbor",
#                             "name": "Cougars"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "CCAC",
#                     "id": "698d65c8-553c-421d-8ae2-2c1ec42eff92",
#                     "name": "Chicagoland Collegiate Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "PNC",
#                             "id": "06ddae19-2725-4ece-82e2-0265e8244bd8",
#                             "market": "Purdue North Central",
#                             "name": "Panthers"
#                         },
#                         {
#                             "alias": "TICC",
#                             "id": "12a506e9-aeb5-44b1-a16d-52c774f2f12c",
#                             "market": "Trinity (IL) Christian College",
#                             "name": "Trolls"
#                         },
#                         {
#                             "alias": "IUSB",
#                             "id": "1d8332df-ca4f-4d65-9bf0-f662d1f98fb5",
#                             "market": "Indiana University South Bend",
#                             "name": "Titans"
#                         },
#                         {
#                             "alias": "JUDS",
#                             "id": "2ba89059-62e5-4624-8fe5-d4b18ab865ca",
#                             "market": "Judson",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "PUC",
#                             "id": "45c8e873-4049-4923-98a4-f766c7b5d518",
#                             "market": "Purdue-Calumet",
#                             "name": "Peregrines"
#                         },
#                         {
#                             "alias": "SXU",
#                             "id": "4ebf2e77-c5ca-4d42-9492-a8944af62d7b",
#                             "market": "St. Xavier University",
#                             "name": "Cougars"
#                         },
#                         {
#                             "alias": "ROOS",
#                             "id": "6ff70323-8df8-40ed-b98b-e5dd4a101493",
#                             "market": "Roosevelt",
#                             "name": "Lakers"
#                         },
#                         {
#                             "alias": "SFIL",
#                             "id": "a0d3b9ec-f430-448a-b172-b46cfa9a5d9b",
#                             "market": "St. Francis (IL)",
#                             "name": "Fighting Saints"
#                         },
#                         {
#                             "alias": "ONAZ",
#                             "id": "a8c644e0-cb57-48ea-acc4-b7dab11db64d",
#                             "market": "Olivet Nazarene",
#                             "name": "Tigers"
#                         },
#                         {
#                             "alias": "TIU",
#                             "id": "d1b9acfa-8bb2-4b6f-a570-94f1a6f96bd7",
#                             "market": "Trinity International University",
#                             "name": "Trojans"
#                         },
#                         {
#                             "alias": "ILLT",
#                             "id": "e030d4c4-5c96-42d7-bd0b-0dd0922c87a7",
#                             "market": "Illinois Tech",
#                             "name": "Scarlet Hawks"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "RRAC",
#                     "id": "6b725066-4a58-4cdb-b58c-59493a1da269",
#                     "name": "Red River Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "BAC",
#                             "id": "0196c7b3-95a1-4f93-9701-e9013f9c1187",
#                             "market": "Bacone",
#                             "name": "Warriors"
#                         },
#                         {
#                             "alias": "JARV",
#                             "id": "1b636371-1c29-4b6a-91b2-e1593c94f012",
#                             "market": "Jarvis Christian",
#                             "name": "Bulldogs"
#                         },
#                         {
#                             "alias": "HTU",
#                             "id": "38fa68fb-ac54-4e62-84cb-c3dafc34fe09",
#                             "market": "Huston-Tillotson",
#                             "name": "Rams",
#                             "venue": {
#                                 "capacity": 1800,
#                                 "city": "Austin",
#                                 "country": "USA",
#                                 "id": "ee7f1bcf-75aa-4766-8c7c-ade61864e49f",
#                                 "name": "Mary E. Branch Gymnasium",
#                                 "state": "TX"
#                             }
#                         },
#                         {
#                             "alias": "OLLU",
#                             "id": "4935c691-a4ba-40f7-ae46-abf8241a2629",
#                             "market": "Our Lady of the Lake",
#                             "name": "Saints"
#                         },
#                         {
#                             "alias": "USW",
#                             "id": "4cf221b6-dd88-4e00-aa34-d23907b044c5",
#                             "market": "University of the Southwest",
#                             "name": "Mustangs"
#                         },
#                         {
#                             "alias": "WC",
#                             "id": "706d96bf-088d-4562-9b43-672245dfcbba",
#                             "market": "Wiley",
#                             "name": "Wildcats"
#                         },
#                         {
#                             "alias": "STTX",
#                             "id": "7ea36595-a70a-4bc6-a654-96da46baddc4",
#                             "market": "St. Thomas (TX)",
#                             "name": "Celts"
#                         },
#                         {
#                             "alias": "PQC",
#                             "id": "9357745f-1c20-4167-8cb3-55f43bc1189f",
#                             "market": "Paul Quinn College",
#                             "name": "Tigers"
#                         },
#                         {
#                             "alias": "LSUA",
#                             "id": "99a5f715-99bc-4fc7-a19a-138953d1db81",
#                             "market": "LSU-Alexandria",
#                             "name": "Generals"
#                         },
#                         {
#                             "alias": "TC",
#                             "id": "a443e2fb-c2eb-4130-9a29-bacc06b4b02b",
#                             "market": "Texas College",
#                             "name": "Steers"
#                         },
#                         {
#                             "alias": "LSUS",
#                             "id": "bd08f76d-3586-48a2-97f9-494ca50a93bc",
#                             "market": "LSU-Shreveport",
#                             "name": "Pilots"
#                         },
#                         {
#                             "alias": "LANG",
#                             "id": "c77380be-7809-4f26-a2c2-886ba2f633be",
#                             "market": "Langston",
#                             "name": "Lions"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "CCC",
#                     "id": "7ca9c0a6-5baa-4cfa-b6be-f0a6968c8e81",
#                     "name": "Cascade Collegiate Conference",
#                     "teams": [
#                         {
#                             "alias": "NU",
#                             "id": "21590973-08c6-43a4-8e9b-b23aac65b866",
#                             "market": "Northwest University",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "OTEC",
#                             "id": "31ac98c4-4517-41f9-b113-ae604bea5678",
#                             "market": "Oregon Tech",
#                             "name": "Hustlin' Owls"
#                         },
#                         {
#                             "alias": "SOU",
#                             "id": "4394d246-3c71-4556-9b62-fdd9ed731b72",
#                             "market": "Southern Oregon",
#                             "name": "Raiders"
#                         },
#                         {
#                             "alias": "COI",
#                             "id": "48c7f9f3-f7e4-4c4a-b429-7995f9ee78c4",
#                             "market": "College of Idaho",
#                             "name": "Coyotes"
#                         },
#                         {
#                             "alias": "NCU",
#                             "id": "9c7f3b90-ec9f-4a30-9ade-e0bcb8c8835e",
#                             "market": "Northwest Christian",
#                             "name": "Beacons"
#                         },
#                         {
#                             "alias": "EOU",
#                             "id": "9e99d5a6-3522-4ab1-8c69-1350227496b8",
#                             "market": "Eastern Oregon",
#                             "name": "Mountaineers"
#                         },
#                         {
#                             "alias": "CORB",
#                             "id": "ad925b0b-8411-41de-81df-212482545581",
#                             "market": "Corban University",
#                             "name": "Warriors"
#                         },
#                         {
#                             "alias": "MULT",
#                             "id": "f2057198-3fd9-4b04-a6bf-6ff57a77c118",
#                             "market": "Multnomah",
#                             "name": "Lions"
#                         },
#                         {
#                             "alias": "ESC",
#                             "id": "f44fe469-f49d-4f91-be6b-260269f35021",
#                             "market": "Evergreen State",
#                             "name": "Geoducks"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "GPAC",
#                     "id": "823a8f8c-8a4f-43d0-9ee7-d4de0bc8c2b1",
#                     "name": "Great Plains Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "CUNE",
#                             "id": "0717335e-2875-4009-b0ff-3b7b0399ff8a",
#                             "market": "Concordia (NE)",
#                             "name": "Bulldogs"
#                         },
#                         {
#                             "alias": "MTM",
#                             "id": "78e58b8a-dff7-48fa-bc6d-18f9b91c3345",
#                             "market": "Mount Marty",
#                             "name": "Lancers"
#                         },
#                         {
#                             "alias": "DOAN",
#                             "id": "a07f9779-8082-4377-9fed-f88b3061e337",
#                             "market": "Doane",
#                             "name": "Tigers"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "WHAC",
#                     "id": "8292bd49-3580-403e-bf3f-2df23375d019",
#                     "name": "Wolverine-Hoosier Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "SIH",
#                             "id": "20132147-705f-4b22-9e21-ea2e82abfddb",
#                             "market": "Siena Heights",
#                             "name": "Saints"
#                         },
#                         {
#                             "alias": "LOUR",
#                             "id": "26265446-8f2c-45df-882a-387e0ac43e87",
#                             "market": "Lourdes",
#                             "name": "Gray Wolves"
#                         },
#                         {
#                             "alias": "NWOH",
#                             "id": "2ea29e9c-fd81-4720-86a2-eccc6a14ab51",
#                             "market": "Northwestern Ohio",
#                             "name": "Racers"
#                         },
#                         {
#                             "alias": "MU",
#                             "id": "43b3b584-0e9d-4ee8-ba3c-bcaa65a97d38",
#                             "market": "Madonna",
#                             "name": "Crusaders"
#                         },
#                         {
#                             "alias": "AQC",
#                             "id": "7946084d-8b68-40bd-a5ac-71bdc852c44a",
#                             "market": "Aquinas College",
#                             "name": "Saints"
#                         },
#                         {
#                             "alias": "MC",
#                             "id": "8f231e8c-116a-4caa-9f0e-0441b45333b3",
#                             "market": "Marygrove",
#                             "name": "Mustangs"
#                         },
#                         {
#                             "alias": "LAWT",
#                             "id": "9c603f87-5511-4bd0-8344-edb3934dcf5e",
#                             "market": "Lawrence Tech",
#                             "name": "Blue Devil"
#                         },
#                         {
#                             "alias": "MI-D",
#                             "id": "a96ad616-86c4-40c3-9cdd-19833ed363b8",
#                             "market": "Michigan-Dearborn",
#                             "name": "Wolverines"
#                         },
#                         {
#                             "alias": "CUMI",
#                             "id": "aa3be6ea-fe19-408c-8db0-5405dc1c60e6",
#                             "market": "Concordia (MI)",
#                             "name": "Cardinals"
#                         },
#                         {
#                             "alias": "INTC",
#                             "id": "d8c88441-b98a-4e07-a85b-60141758bdde",
#                             "market": "Indiana Tech",
#                             "name": "Warriors"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "TSC",
#                     "id": "87c7624d-dff8-4fba-8d54-b05dc07629db",
#                     "name": "The Sun Conference",
#                     "teams": [
#                         {
#                             "alias": "AVE",
#                             "id": "0835a989-ef26-4b2c-b4b9-e8945ce5752a",
#                             "market": "Ave Maria",
#                             "name": "Gyrenes"
#                         },
#                         {
#                             "alias": "THOM",
#                             "id": "59d61883-4694-4e6d-be1e-256aab3015c3",
#                             "market": "Thomas (GA)",
#                             "name": "Night Hawks"
#                         },
#                         {
#                             "alias": "SE",
#                             "id": "7a30b75c-f777-45cc-af25-f8efad56960f",
#                             "market": "Southeastern",
#                             "name": "Fire"
#                         },
#                         {
#                             "alias": "JWFL",
#                             "id": "9b0e6604-a29a-4231-9dd7-679260ee1ebc",
#                             "market": "Johnson & Wales (FL)",
#                             "name": "Wildcats"
#                         },
#                         {
#                             "alias": "KEIS",
#                             "id": "b27dd206-8fe8-448a-9282-f299a984caa6",
#                             "market": "Keiser",
#                             "name": "Seahawks"
#                         },
#                         {
#                             "alias": "WARN",
#                             "id": "c63f2aa8-f86f-4797-b1bc-883aef69d357",
#                             "market": "Warner",
#                             "name": "Royals"
#                         },
#                         {
#                             "alias": "WIU",
#                             "id": "d2acd808-eb4f-484a-a8af-b86451e64a87",
#                             "market": "Webber International",
#                             "name": "Warriors"
#                         },
#                         {
#                             "alias": "FMU",
#                             "id": "d63c9ebc-fb77-40c5-a4bf-77cfd8b64412",
#                             "market": "Florida Memorial",
#                             "name": "Fighting Lions"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "DIII-MCC",
#                     "id": "9ed8cddf-ead2-4925-b092-47b018a4b2e3",
#                     "name": "Midlands Collegiate Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "WC",
#                             "id": "0c85b125-48f2-468c-8461-afa7fdab248a",
#                             "market": "Waldorf",
#                             "name": "Warriors"
#                         },
#                         {
#                             "alias": "HASK",
#                             "id": "482510f1-3015-4928-a332-1a33c223f4b6",
#                             "market": "Haskell",
#                             "name": "Indians"
#                         },
#                         {
#                             "alias": "CBC",
#                             "id": "751973da-43b0-4778-b525-8bae830d4da4",
#                             "market": "Central Baptist College",
#                             "name": "Mustangs"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "AII",
#                     "id": "a22c29fd-c677-46e7-a5fe-85ac6e1aaf88",
#                     "name": "Association of Independent Institutions",
#                     "teams": [
#                         {
#                             "alias": "WFU",
#                             "id": "2d650b54-67fe-44ce-99b5-e12091c1886c",
#                             "market": "Wilberforce",
#                             "name": "Bulldogs"
#                         },
#                         {
#                             "alias": "KCU",
#                             "id": "2fb2c386-bcd7-453d-90ba-6eeac86daad2",
#                             "market": "Kentucky Christian",
#                             "name": "Knights"
#                         },
#                         {
#                             "alias": "FISH",
#                             "id": "33d26837-88bb-4b5f-b776-a649d337f762",
#                             "market": "Fisher",
#                             "name": "Falcons"
#                         },
#                         {
#                             "alias": "WALL",
#                             "id": "701ab32b-ac60-4106-97a7-cf70a0a053f7",
#                             "market": "Walla Walla",
#                             "name": "Wolves"
#                         },
#                         {
#                             "alias": "FISK",
#                             "id": "9fdeb490-e8e5-4fe7-8011-0d00e8784b1c",
#                             "market": "Fisk",
#                             "name": "Bulldogs"
#                         },
#                         {
#                             "alias": "ALLN",
#                             "id": "cdc49932-9bb9-452c-9301-7ad914ee47ad",
#                             "market": "Allen",
#                             "name": "Fighting Yellow Jackets"
#                         },
#                         {
#                             "alias": "NNMX",
#                             "id": "ce3eef52-86bf-4ff2-a0ff-a17852d42923",
#                             "market": "Northern New Mexico",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "IUN",
#                             "id": "d12ead25-780e-4ff9-9d7f-44e196268811",
#                             "market": "Indiana-Northwest",
#                             "name": "Redhawks"
#                         },
#                         {
#                             "alias": "WVT",
#                             "id": "e05b4477-2af4-4d23-9978-8803d3bc012b",
#                             "market": "West Virginia Tech",
#                             "name": "Golden Bears"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "NSAA",
#                     "id": "c7b491e8-2e79-4713-9ad8-2c992d31b9b5",
#                     "name": "North Star Athletic Association",
#                     "teams": [
#                         {
#                             "alias": "MSU",
#                             "id": "0620a022-381d-4097-9ade-8de0d4d24cc9",
#                             "market": "Mayville State",
#                             "name": "Comets"
#                         },
#                         {
#                             "alias": "BELL",
#                             "id": "065e9c15-c404-40d4-9663-71872f1c6868",
#                             "market": "Bellevue",
#                             "name": "Bruins"
#                         },
#                         {
#                             "alias": "DSU",
#                             "id": "2f4a24c4-212b-4d5a-b2cf-f16fd0acd47a",
#                             "market": "Dickinson State",
#                             "name": "Blue Hawks"
#                         },
#                         {
#                             "alias": "PC",
#                             "id": "5c3acc60-52e0-4454-a363-fd086fbb534b",
#                             "market": "Presentation College",
#                             "name": "Saints"
#                         },
#                         {
#                             "alias": "VCSU",
#                             "id": "8edae726-8c29-4b67-86e9-3d1d769f410e",
#                             "market": "Valley City State",
#                             "name": "Vikings"
#                         },
#                         {
#                             "alias": "JAME",
#                             "id": "d5b15075-9e7b-4bec-abf3-467760294886",
#                             "market": "Jamestown",
#                             "name": "Jimmies"
#                         },
#                         {
#                             "alias": "DAKS",
#                             "id": "dea363c7-6e3e-4486-a670-5462bb69da8b",
#                             "market": "Dakota State",
#                             "name": "Trojans"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "SSAC",
#                     "id": "d22ad1c8-3e4b-431a-a8aa-4aea8dc2f85a",
#                     "name": "Southern States Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "MAR",
#                             "id": "1f656245-6e13-456c-8722-40a83cb22b52",
#                             "market": "Martin Methodist",
#                             "name": "Redhawks"
#                         },
#                         {
#                             "alias": "FAUL",
#                             "id": "3a83cf87-1022-4adb-abe3-f2e2ffeff9a2",
#                             "market": "Faulkner",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "BETH",
#                             "id": "5c2f0319-eef6-4a73-b95e-857c830b0fac",
#                             "market": "Bethel (TN)",
#                             "name": "Wildcats"
#                         },
#                         {
#                             "alias": "WCU",
#                             "id": "a2744977-be5e-4fc0-bc68-f6810633916d",
#                             "market": "William Carey",
#                             "name": "Crusaders"
#                         },
#                         {
#                             "alias": "UM",
#                             "id": "ac0462ad-cc5b-4a09-92e7-f6d587422e5d",
#                             "market": "Mobile",
#                             "name": "Rams"
#                         },
#                         {
#                             "alias": "DSC",
#                             "id": "b419f710-f458-46b7-aaa3-d14658a74440",
#                             "market": "Dalton State",
#                             "name": "Roadrunners",
# ...
#                             "name": "Warriors"
#                         },
#                         {
#                             "alias": "SOME",
#                             "id": "da9ca542-d382-4c9b-a122-469439c330c1",
#                             "market": "Southern Maine",
#                             "name": "Huskies"
#                         },
#                         {
#                             "alias": "MABO",
#                             "id": "dbd3591c-a49c-49da-ab52-a364a1b2e032",
#                             "market": "Massachusetts-Boston",
#                             "name": "Beacons"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "MACF",
#                     "id": "f961087e-f8ee-4453-988f-5423fe54c54e",
#                     "name": "MAC Freedom Conference",
#                     "teams": [
#                         {
#                             "alias": "FDUF",
#                             "id": "0283d380-1fea-4d6f-a1bf-b83c26a1b1bb",
#                             "market": "FDU-Florham",
#                             "name": "Devils"
#                         },
#                         {
#                             "alias": "WILK",
#                             "id": "3f847eae-48b6-4648-96df-3f1bf28abb41",
#                             "market": "Wilkes",
#                             "name": "Colonels"
#                         },
#                         {
#                             "alias": "EAST",
#                             "id": "46e6f4db-8b7f-4085-aade-5865fc465758",
#                             "market": "Eastern University",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "MISE",
#                             "id": "9a4a8d2c-36c9-4b02-9091-a807cbab036f",
#                             "market": "Misericordia",
#                             "name": "Cougars"
#                         },
#                         {
#                             "alias": "DSALE",
#                             "id": "bbf54d0b-09e2-4f59-bc46-3e1bc50d42b0",
#                             "market": "DeSales",
#                             "name": "Bulldogs"
#                         },
#                         {
#                             "alias": "DVU",
#                             "id": "c6a81263-baf3-4a3b-927e-e02b9d4d262f",
#                             "market": "Delaware Valley",
#                             "name": "Aggies"
#                         },
#                         {
#                             "alias": "KING",
#                             "id": "c76bb4fe-d4a0-4e04-9faa-02c4a9a7ab09",
#                             "market": "King's College",
#                             "name": "Monarchs"
#                         },
#                         {
#                             "alias": "MANV",
#                             "id": "f06d97ef-8c61-459f-af1c-4baae96bc30d",
#                             "market": "Manhattanville",
#                             "name": "Valiants"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "CAC",
#                     "id": "f98dac74-5ed0-4500-9b24-2d73b199a301",
#                     "name": "Capital Athletic Conference",
#                     "teams": [
#                         {
#                             "alias": "SMCM",
#                             "id": "26eaeb27-2fc4-4c9f-93b2-27f6afe39071",
#                             "market": "St. Mary's College of Maryland",
#                             "name": "Seahawks"
#                         },
#                         {
#                             "alias": "CNU",
#                             "id": "2c2933a8-5317-4675-b5ba-589bec90b653",
#                             "market": "Christopher Newport",
#                             "name": "Captains"
#                         },
#                         {
#                             "alias": "SVU",
#                             "id": "5150020f-f660-4dd5-b25b-dbaf9e17e9f2",
#                             "market": "Southern Virginia",
#                             "name": "Knights"
#                         },
#                         {
#                             "alias": "YCPA",
#                             "id": "6560815b-8df7-4198-af3b-46c2e8e92560",
#                             "market": "York College (PA)",
#                             "name": "Spartans"
#                         },
#                         {
#                             "alias": "FSU",
#                             "id": "83bb9428-da35-437a-a432-187b0b52b4f1",
#                             "market": "Frostburg State",
#                             "name": "Bobcats"
#                         },
#                         {
#                             "alias": "UMW",
#                             "id": "914fda67-13b2-44e2-9050-12172c15875c",
#                             "market": "Mary Washington",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "PSH",
#                             "id": "ae097d72-c56a-4d7b-93c0-18869e5dcb15",
#                             "market": "Penn State-Harrisburg",
#                             "name": "Lions"
#                         },
#                         {
#                             "alias": "SAL",
#                             "id": "b8cf9a03-c80e-47b8-9b3d-7f5b38e36bf4",
#                             "market": "Salisbury",
#                             "name": "Sea Gulls"
#                         }
#                     ]
#                 }
#             ],
#             "id": "d0196fdb-369c-4318-a318-d8e7b986ffb8",
#             "name": "NCAA Division III"
#         },
#         {
#             "alias": "NCCAA",
#             "conferences": [
#                 {
#                     "alias": "D2-MID-WEST",
#                     "id": "0b4eb4ae-c5df-4d5c-a031-06c59ad47545",
#                     "name": "Division II Mid-West Region",
#                     "teams": [
#                         {
#                             "alias": "GBC",
#                             "id": "2cbac96a-c971-4752-96e4-4de7e0711e2a",
#                             "market": "Grace Bible College",
#                             "name": "Tigers"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "D2-EAST",
#                     "id": "10e71f80-e00f-49b2-b837-d680b56cf7b9",
#                     "name": "Division II East Region",
#                     "teams": []
#                 },
#                 {
#                     "alias": "D1-WEST",
#                     "id": "53630324-fd56-42e6-ba4c-dc040a31dfff",
#                     "name": "Division I West Region",
#                     "teams": [
#                         {
#                             "alias": "BETH",
#                             "id": "78434f3d-9b05-480c-b79f-4f228a0a155b",
#                             "market": "Bethesda",
#                             "name": "Flames"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "D1-MID-EAST",
#                     "id": "659b6525-8b0c-43b4-831a-6c923dd18f03",
#                     "name": "Division I Mid-East Region",
#                     "teams": [
#                         {
#                             "alias": "HIW",
#                             "id": "2d9703a1-4838-47a4-8909-11e6f947402b",
#                             "market": "Hiwassee",
#                             "name": "Tigers"
#                         },
#                         {
#                             "alias": "COV",
#                             "id": "8709616c-fb1c-4210-bd0c-ec4bd68fd69f",
#                             "market": "Covenant",
#                             "name": "Scots"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "D2-MID-EAST",
#                     "id": "86fd71f9-9f66-43fd-ae70-e4b71c5e69b7",
#                     "name": "Division II Mid-East Region",
#                     "teams": [
#                         {
#                             "alias": "JU",
#                             "id": "2e9743ef-b360-42cb-a2c7-e176ac44081e",
#                             "market": "Johnson University",
#                             "name": "Royals"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "D2-SOUTH",
#                     "id": "88bb6d9b-e7a2-493e-87e6-7ca40171e373",
#                     "name": "Division II South Region",
#                     "teams": [
#                         {
#                             "alias": "PCC",
#                             "id": "26dfefd2-a56d-4ac1-a7b6-f4e4bc1940c9",
#                             "market": "Pensacola Christian",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "CCC",
#                             "id": "3b5fe2b9-5d48-488b-a685-4e5652ccaa7c",
#                             "market": "Clearwater",
#                             "name": "Cougars"
#                         },
#                         {
#                             "alias": "MGC",
#                             "id": "4c9479a1-7791-42bd-8471-b38654fd8d07",
#                             "market": "Middle Georgia State",
#                             "name": "Knights"
#                         },
#                         {
#                             "alias": "TBC",
#                             "id": "b3b07f46-f173-4d54-bad9-dbbdac6c8bdb",
#                             "market": "Trinity Baptist",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "TFC",
#                             "id": "f02e7357-5a05-463a-b61d-09e381ba3815",
#                             "market": "Toccoa Falls",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "TRIN",
#                             "id": "f6eeed01-5a94-4044-aec4-1ea36fe0f7e6",
#                             "market": "Trinity (FL)",
#                             "name": "Tigers"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "ACCA",
#                     "id": "927bd1b3-e518-4c4e-8c90-6a37fa2fede8",
#                     "name": "Association of Christian College Athletics Conference",
#                     "teams": [
#                         {
#                             "alias": "RU",
#                             "id": "08d2a0d1-323b-4cd3-92f0-63d1a0d446e5",
#                             "market": "Randall",
#                             "name": "Saints"
#                         },
#                         {
#                             "alias": "SEBC",
#                             "id": "5515f84f-9e94-441e-95f6-5dc89b9e9435",
#                             "market": "Southeastern Baptist College",
#                             "name": "Chargers"
#                         },
#                         {
#                             "alias": "CU",
#                             "id": "7ced29ca-9b03-4a21-aa6f-4b75e2146120",
#                             "market": "Calvary University",
#                             "name": "Warriors"
#                         },
#                         {
#                             "alias": "OHCC",
#                             "id": "af1c00e4-0f6d-4da3-ac6d-d4a086369ff1",
#                             "market": "Oak Hills Christian College",
#                             "name": "Wolfpack"
#                         },
#                         {
#                             "alias": "MIDA",
#                             "id": "bac89a23-ae88-4131-be7d-13df2f31ffa0",
#                             "market": "Mount Ida",
#                             "name": "Mustangs"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "D2-SOUTHWEST",
#                     "id": "a607d2fd-b72a-4f7a-9aa8-41ea750786fd",
#                     "name": "Division II Southwest Region",
#                     "teams": [
#                         {
#                             "alias": "ABAP",
#                             "id": "2adafff6-1187-421c-85ce-6c9f60e4a412",
#                             "market": "Arlington Baptist",
#                             "name": "Patriots"
#                         },
#                         {
#                             "alias": "HFWBC",
#                             "id": "5f7ad804-e302-4ba2-99fd-e13c309aad45",
#                             "market": "Hillsdale Free Will Baptist College",
#                             "name": "Saints"
#                         },
#                         {
#                             "alias": "DCC",
#                             "id": "b293fafe-48bb-4e2c-9d41-777125398b2d",
#                             "market": "Dallas Christian",
#                             "name": "Crusaders"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "D1-SOUTH",
#                     "id": "dc2f00ed-7ee7-4dd5-afaf-1a89c4af1bf3",
#                     "name": "Division I South Region",
#                     "teams": [
#                         {
#                             "alias": "REGU",
#                             "id": "4a98feae-5ea4-417f-b2aa-d3daab5ec568",
#                             "market": "Regent University",
#                             "name": "Royals"
#                         },
#                         {
#                             "alias": "BOBJ",
#                             "id": "b232c20f-6289-4e86-a784-6ea09f7284d1",
#                             "market": "Bob Jones",
#                             "name": "Bruins"
#                         },
#                         {
#                             "alias": "CIU",
#                             "id": "de1e599a-32df-4e8c-916f-9ac20912009c",
#                             "market": "Columbia International",
#                             "name": "Rams"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "D1-CENT",
#                     "id": "df49947b-a43a-4f9b-b71a-faf06c97a870",
#                     "name": "Division I Central Region",
#                     "teams": [
#                         {
#                             "alias": "SWCU",
#                             "id": "29e59b8b-db7d-493d-adc1-2eec8f49a959",
#                             "market": "Southwestern Christian",
#                             "name": "Eagles"
#                         },
#                         {
#                             "alias": "CRC",
#                             "id": "73399a24-e05f-4d0f-bc99-f633324a31eb",
#                             "market": "Crowley's Ridge",
#                             "name": "Pioneers"
#                         },
#                         {
#                             "alias": "ECCC",
#                             "id": "dead023d-2eb3-42f7-b9a4-3968d7f3b4cc",
#                             "market": "Ecclesia",
#                             "name": "Royals"
#                         }
#                     ]
#                 },
#                 {
#                     "alias": "D2-WEST",
#                     "id": "f4ab39df-c699-4fea-a74e-b49b92de381b",
#                     "name": "Division II West Region",
#                     "teams": [
#                         {
#                             "alias": "LPC",
#                             "id": "1abe928d-aec9-4133-9193-617b96ddaf42",
#                             "market": "Life Pacific College",
#                             "name": "Warriors"
#                         }
#                     ]
#                 }
#             ],
#             "id": "efdde904-b901-44af-a234-17712072b213",
#             "name": "NCCAA"
#         }
#     ],
#     "league": {
#         "alias": "NCAAM",
#         "id": "cd4268ee-07aa-4c4d-a435-ec44ad2c76cb",
#         "name": "NCAA MEN"
#     }
# }

# %%
Teams_response = requests.get(Team_url).json()


print (Teams_response)
# Out:
# {'id': 'fae4855b-1b64-4b40-a632-9ed345e1e952', 'name': 'Jayhawks', 'market': 'Kansas', 'season': {'id': '6c78669c-a47f-41b8-8715-5482db4d8a45', 'year': 2018, 'type': 'REG'}, 'own_record': {'total': {'games_played': 28, 'minutes': 5675.0, 'field_goals_made': 769, 'field_goals_att': 1639, 'field_goals_pct': 0.469, 'two_points_made': 558, 'two_points_att': 1055, 'two_points_pct': 0.529, 'three_points_made': 211, 'three_points_att': 584, 'three_points_pct': 0.361, 'blocked_att': 94, 'free_throws_made': 377, 'free_throws_att': 546, 'free_throws_pct': 0.69, 'offensive_rebounds': 250, 'defensive_rebounds': 718, 'rebounds': 968, 'assists': 380, 'turnovers': 373, 'assists_turnover_ratio': 1.02, 'steals': 194, 'blocks': 106, 'personal_fouls': 480, 'tech_fouls': 3, 'points': 2126, 'fast_break_pts': 248, 'flagrant_fouls': 4, 'points_off_turnovers': 445, 'second_chance_pts': 308, 'ejections': 0, 'foulouts': 11, 'points_in_paint': 962, 'efficiency': 2362, 'true_shooting_att': 1879.24, 'true_shooting_pct': 0.566}, 'average': {'fast_break_pts': 8.86, 'points_off_turnovers': 15.89, 'second_chance_pts': 11.0, 'minutes': 202.7, 'points': 75.9, 'off_rebounds': 8.93, 'def_rebounds': 25.64, 'rebounds': 34.57, 'assists': 13.6, 'steals': 6.93, 'blocks': 3.79, 'turnovers': 13.32, 'personal_fouls': 17.14, 'flagrant_fouls': 0.14, 'blocked_att': 3.36, 'field_goals_made': 27.46, 'field_goals_att': 58.54, 'three_points_made': 7.54, 'three_points_att': 20.86, 'free_throws_made': 13.46, 'free_throws_att': 19.5, 'two_points_made': 19.93, 'two_points_att': 37.68, 'points_in_paint': 34.36, 'efficiency': 84.36, 'true_shooting_att': 67.12}}, 'opponents': {'total': {'games_played': 28, 'minutes': 5675.0, 'field_goals_made': 695, 'field_goals_att': 1716, 'field_goals_pct': 0.405, 'two_points_made': 452, 'two_points_att': 1003, 'two_points_pct': 0.451, 'three_points_made': 243, 'three_points_att': 713, 'three_points_pct': 0.341, 'blocked_att': 108, 'free_throws_made': 323, 'free_throws_att': 468, 'free_throws_pct': 0.69, 'offensive_rebounds': 282, 'defensive_rebounds': 647, 'rebounds': 929, 'assists': 376, 'turnovers': 384, 'assists_turnover_ratio': 0.98, 'steals': 179, 'blocks': 95, 'personal_fouls': 482, 'tech_fouls': 1, 'points': 1956, 'fast_break_pts': 191, 'flagrant_fouls': 0, 'points_off_turnovers': 348, 'second_chance_pts': 260, 'ejections': 0, 'foulouts': 14, 'points_in_paint': 732, 'efficiency': 1985, 'true_shooting_att': 1921.92, 'true_shooting_pct': 0.509}, 'average': {'fast_break_pts': 6.82, 'points_off_turnovers': 12.43, 'second_chance_pts': 9.29, 'minutes': 202.7, 'points': 69.9, 'off_rebounds': 10.07, 'def_rebounds': 23.11, 'rebounds': 33.18, 'assists': 13.4, 'steals': 6.39, 'blocks': 3.39, 'turnovers': 13.71, 'personal_fouls': 17.21, 'flagrant_fouls': 0.0, 'blocked_att': 3.86, 'field_goals_made': 24.82, 'field_goals_att': 61.29, 'three_points_made': 8.68, 'three_points_att': 25.46, 'free_throws_made': 11.54, 'free_throws_att': 16.71, 'two_points_made': 16.14, 'two_points_att': 35.82, 'points_in_paint': 26.14, 'efficiency': 70.89, 'true_shooting_att': 68.64}}, 'players': [{'id': '0bb0ec09-0186-4dfa-9d71-6e63515416e5', 'full_name': 'Mitch Lightfoot', 'first_name': 'Mitch', 'last_name': 'Lightfoot', 'position': 'F', 'primary_position': 'NA', 'jersey_number': '44', 'total': {'games_played': 26, 'games_started': 0, 'minutes': 287.0, 'field_goals_made': 24, 'field_goals_att': 41, 'field_goals_pct': 0.585, 'two_points_made': 23, 'two_points_att': 33, 'two_points_pct': 0.697, 'three_points_made': 1, 'three_points_att': 8, 'three_points_pct': 0.125, 'blocked_att': 0, 'free_throws_made': 13, 'free_throws_att': 27, 'free_throws_pct': 0.481, 'offensive_rebounds': 28, 'defensive_rebounds': 48, 'rebounds': 76, 'assists': 11, 'turnovers': 10, 'assists_turnover_ratio': 1.1, 'steals': 4, 'blocks': 21, 'personal_fouls': 44, 'tech_fouls': 0, 'points': 62, 'flagrant_fouls': 1, 'ejections': 0, 'foulouts': 2, 'true_shooting_att': 52.88, 'true_shooting_pct': 0.586, 'effici ...

# %%
print(json.dumps(Teams_response, indent=4, sort_keys=True))
# Out:
# {
#     "id": "fae4855b-1b64-4b40-a632-9ed345e1e952",
#     "market": "Kansas",
#     "name": "Jayhawks",
#     "opponents": {
#         "average": {
#             "assists": 13.4,
#             "blocked_att": 3.86,
#             "blocks": 3.39,
#             "def_rebounds": 23.11,
#             "efficiency": 70.89,
#             "fast_break_pts": 6.82,
#             "field_goals_att": 61.29,
#             "field_goals_made": 24.82,
#             "flagrant_fouls": 0.0,
#             "free_throws_att": 16.71,
#             "free_throws_made": 11.54,
#             "minutes": 202.7,
#             "off_rebounds": 10.07,
#             "personal_fouls": 17.21,
#             "points": 69.9,
#             "points_in_paint": 26.14,
#             "points_off_turnovers": 12.43,
#             "rebounds": 33.18,
#             "second_chance_pts": 9.29,
#             "steals": 6.39,
#             "three_points_att": 25.46,
#             "three_points_made": 8.68,
#             "true_shooting_att": 68.64,
#             "turnovers": 13.71,
#             "two_points_att": 35.82,
#             "two_points_made": 16.14
#         },
#         "total": {
#             "assists": 376,
#             "assists_turnover_ratio": 0.98,
#             "blocked_att": 108,
#             "blocks": 95,
#             "defensive_rebounds": 647,
#             "efficiency": 1985,
#             "ejections": 0,
#             "fast_break_pts": 191,
#             "field_goals_att": 1716,
#             "field_goals_made": 695,
#             "field_goals_pct": 0.405,
#             "flagrant_fouls": 0,
#             "foulouts": 14,
#             "free_throws_att": 468,
#             "free_throws_made": 323,
#             "free_throws_pct": 0.69,
#             "games_played": 28,
#             "minutes": 5675.0,
#             "offensive_rebounds": 282,
#             "personal_fouls": 482,
#             "points": 1956,
#             "points_in_paint": 732,
#             "points_off_turnovers": 348,
#             "rebounds": 929,
#             "second_chance_pts": 260,
#             "steals": 179,
#             "tech_fouls": 1,
#             "three_points_att": 713,
#             "three_points_made": 243,
#             "three_points_pct": 0.341,
#             "true_shooting_att": 1921.92,
#             "true_shooting_pct": 0.509,
#             "turnovers": 384,
#             "two_points_att": 1003,
#             "two_points_made": 452,
#             "two_points_pct": 0.451
#         }
#     },
#     "own_record": {
#         "average": {
#             "assists": 13.6,
#             "blocked_att": 3.36,
#             "blocks": 3.79,
#             "def_rebounds": 25.64,
#             "efficiency": 84.36,
#             "fast_break_pts": 8.86,
#             "field_goals_att": 58.54,
#             "field_goals_made": 27.46,
#             "flagrant_fouls": 0.14,
#             "free_throws_att": 19.5,
#             "free_throws_made": 13.46,
#             "minutes": 202.7,
#             "off_rebounds": 8.93,
#             "personal_fouls": 17.14,
#             "points": 75.9,
#             "points_in_paint": 34.36,
#             "points_off_turnovers": 15.89,
#             "rebounds": 34.57,
#             "second_chance_pts": 11.0,
#             "steals": 6.93,
#             "three_points_att": 20.86,
#             "three_points_made": 7.54,
#             "true_shooting_att": 67.12,
#             "turnovers": 13.32,
#             "two_points_att": 37.68,
#             "two_points_made": 19.93
#         },
#         "total": {
#             "assists": 380,
#             "assists_turnover_ratio": 1.02,
#             "blocked_att": 94,
#             "blocks": 106,
#             "defensive_rebounds": 718,
#             "efficiency": 2362,
#             "ejections": 0,
#             "fast_break_pts": 248,
#             "field_goals_att": 1639,
#             "field_goals_made": 769,
#             "field_goals_pct": 0.469,
#             "flagrant_fouls": 4,
#             "foulouts": 11,
#             "free_throws_att": 546,
#             "free_throws_made": 377,
#             "free_throws_pct": 0.69,
#             "games_played": 28,
#             "minutes": 5675.0,
#             "offensive_rebounds": 250,
#             "personal_fouls": 480,
#             "points": 2126,
#             "points_in_paint": 962,
#             "points_off_turnovers": 445,
#             "rebounds": 968,
#             "second_chance_pts": 308,
#             "steals": 194,
#             "tech_fouls": 3,
#             "three_points_att": 584,
#             "three_points_made": 211,
#             "three_points_pct": 0.361,
#             "true_shooting_att": 1879.24,
#             "true_shooting_pct": 0.566,
#             "turnovers": 373,
#             "two_points_att": 1055,
#             "two_points_made": 558,
#             "two_points_pct": 0.529
#         }
#     },
#     "players": [
#         {
#             "average": {
#                 "assists": 0.4,
#                 "blocked_att": 0.0,
#                 "blocks": 0.81,
#                 "def_rebounds": 1.85,
#                 "efficiency": 5.12,
#                 "field_goals_att": 1.58,
#                 "field_goals_made": 0.92,
#                 "flagrant_fouls": 0.04,
#                 "free_throws_att": 1.04,
#                 "free_throws_made": 0.5,
#                 "minutes": 11.0,
#                 "off_rebounds": 1.08,
#                 "personal_fouls": 1.69,
#                 "points": 2.4,
#                 "rebounds": 2.92,
#                 "steals": 0.15,
#                 "three_points_att": 0.31,
#                 "three_points_made": 0.04,
#                 "true_shooting_att": 2.03,
#                 "turnovers": 0.38,
#                 "two_points_att": 1.27,
#                 "two_points_made": 0.88
#             },
#             "first_name": "Mitch",
#             "full_name": "Mitch Lightfoot",
#             "id": "0bb0ec09-0186-4dfa-9d71-6e63515416e5",
#             "jersey_number": "44",
#             "last_name": "Lightfoot",
#             "position": "F",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 11,
#                 "assists_turnover_ratio": 1.1,
#                 "blocked_att": 0,
#                 "blocks": 21,
#                 "defensive_rebounds": 48,
#                 "efficiency": 133,
#                 "ejections": 0,
#                 "field_goals_att": 41,
#                 "field_goals_made": 24,
#                 "field_goals_pct": 0.585,
#                 "flagrant_fouls": 1,
#                 "foulouts": 2,
#                 "free_throws_att": 27,
#                 "free_throws_made": 13,
#                 "free_throws_pct": 0.481,
#                 "games_played": 26,
#                 "games_started": 0,
#                 "minutes": 287.0,
#                 "offensive_rebounds": 28,
#                 "personal_fouls": 44,
#                 "points": 62,
#                 "rebounds": 76,
#                 "steals": 4,
#                 "tech_fouls": 0,
#                 "three_points_att": 8,
#                 "three_points_made": 1,
#                 "three_points_pct": 0.125,
#                 "true_shooting_att": 52.88,
#                 "true_shooting_pct": 0.586,
#                 "turnovers": 10,
#                 "two_points_att": 33,
#                 "two_points_made": 23,
#                 "two_points_pct": 0.697
#             }
#         },
#         {
#             "average": {
#                 "assists": 0.1,
#                 "blocked_att": 0.0,
#                 "blocks": 0.0,
#                 "def_rebounds": 0.13,
#                 "efficiency": 0.13,
#                 "field_goals_att": 0.5,
#                 "field_goals_made": 0.13,
#                 "flagrant_fouls": 0.0,
#                 "free_throws_att": 0.0,
#                 "free_throws_made": 0.0,
#                 "minutes": 1.9,
#                 "off_rebounds": 0.0,
#                 "personal_fouls": 0.25,
#                 "points": 0.4,
#                 "rebounds": 0.13,
#                 "steals": 0.0,
#                 "three_points_att": 0.5,
#                 "three_points_made": 0.13,
#                 "true_shooting_att": 0.5,
#                 "turnovers": 0.13,
#                 "two_points_att": 0.0,
#                 "two_points_made": 0.0
#             },
#             "first_name": "Chris",
#             "full_name": "Chris Teahan",
#             "id": "14b0d156-a3fb-41ff-bb25-bf05dc0b309e",
#             "jersey_number": "12",
#             "last_name": "Teahan",
#             "position": "G",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 1,
#                 "assists_turnover_ratio": 1.0,
#                 "blocked_att": 0,
#                 "blocks": 0,
#                 "defensive_rebounds": 1,
#                 "efficiency": 1,
#                 "ejections": 0,
#                 "field_goals_att": 4,
#                 "field_goals_made": 1,
#                 "field_goals_pct": 0.25,
#                 "flagrant_fouls": 0,
#                 "foulouts": 0,
#                 "free_throws_att": 0,
#                 "free_throws_made": 0,
#                 "free_throws_pct": 0,
#                 "games_played": 8,
#                 "games_started": 0,
#                 "minutes": 15.0,
#                 "offensive_rebounds": 0,
#                 "personal_fouls": 2,
#                 "points": 3,
#                 "rebounds": 1,
#                 "steals": 0,
#                 "tech_fouls": 0,
#                 "three_points_att": 4,
#                 "three_points_made": 1,
#                 "three_points_pct": 0.25,
#                 "true_shooting_att": 4.0,
#                 "true_shooting_pct": 0.375,
#                 "turnovers": 1,
#                 "two_points_att": 0,
#                 "two_points_made": 0,
#                 "two_points_pct": 0
#             }
#         },
#         {
#             "average": {
#                 "assists": 0.6,
#                 "blocked_att": 0.33,
#                 "blocks": 1.56,
#                 "def_rebounds": 4.56,
#                 "efficiency": 15.89,
#                 "field_goals_att": 8.67,
#                 "field_goals_made": 6.11,
#                 "flagrant_fouls": 0.0,
#                 "free_throws_att": 3.56,
#                 "free_throws_made": 1.22,
#                 "minutes": 20.4,
#                 "off_rebounds": 2.22,
#                 "personal_fouls": 2.89,
#                 "points": 13.4,
#                 "rebounds": 6.78,
#                 "steals": 0.44,
#                 "three_points_att": 0.0,
#                 "three_points_made": 0.0,
#                 "true_shooting_att": 10.23,
#                 "turnovers": 2.0,
#                 "two_points_att": 8.67,
#                 "two_points_made": 6.11
#             },
#             "first_name": "Udoka",
#             "full_name": "Udoka Azubuike",
#             "id": "27c05c0d-3608-4de2-a8b3-3c92ae0a81db",
#             "jersey_number": "35",
#             "last_name": "Azubuike",
#             "position": "C",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 5,
#                 "assists_turnover_ratio": 0.28,
#                 "blocked_att": 3,
#                 "blocks": 14,
#                 "defensive_rebounds": 41,
#                 "efficiency": 143,
#                 "ejections": 0,
#                 "field_goals_att": 78,
#                 "field_goals_made": 55,
#                 "field_goals_pct": 0.705,
#                 "flagrant_fouls": 0,
#                 "foulouts": 1,
#                 "free_throws_att": 32,
#                 "free_throws_made": 11,
#                 "free_throws_pct": 0.344,
#                 "games_played": 9,
#                 "games_started": 9,
#                 "minutes": 184.0,
#                 "offensive_rebounds": 20,
#                 "personal_fouls": 26,
#                 "points": 121,
#                 "rebounds": 61,
#                 "steals": 4,
#                 "tech_fouls": 0,
#                 "three_points_att": 0,
#                 "three_points_made": 0,
#                 "three_points_pct": 0,
#                 "true_shooting_att": 92.08,
#                 "true_shooting_pct": 0.657,
#                 "turnovers": 18,
#                 "two_points_att": 78,
#                 "two_points_made": 55,
#                 "two_points_pct": 0.705
#             }
#         },
#         {
#             "average": {
#                 "assists": 1.9,
#                 "blocked_att": 0.36,
#                 "blocks": 0.11,
#                 "def_rebounds": 1.89,
#                 "efficiency": 5.46,
#                 "field_goals_att": 7.18,
#                 "field_goals_made": 2.75,
#                 "flagrant_fouls": 0.0,
#                 "free_throws_att": 1.5,
#                 "free_throws_made": 0.82,
#                 "minutes": 26.4,
#                 "off_rebounds": 0.46,
#                 "personal_fouls": 2.29,
#                 "points": 7.6,
#                 "rebounds": 2.36,
#                 "steals": 0.5,
#                 "three_points_att": 4.04,
#                 "three_points_made": 1.32,
#                 "true_shooting_att": 7.84,
#                 "turnovers": 1.89,
#                 "two_points_att": 3.14,
#                 "two_points_made": 1.43
#             },
#             "first_name": "Quentin",
#             "full_name": "Quentin Grimes",
#             "id": "3334c2ab-1594-4524-a5e9-e9a691a98c8c",
#             "jersey_number": "5",
#             "last_name": "Grimes",
#             "position": "G",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 52,
#                 "assists_turnover_ratio": 0.98,
#                 "blocked_att": 10,
#                 "blocks": 3,
#                 "defensive_rebounds": 53,
#                 "efficiency": 153,
#                 "ejections": 0,
#                 "field_goals_att": 201,
#                 "field_goals_made": 77,
#                 "field_goals_pct": 0.383,
#                 "flagrant_fouls": 0,
#                 "foulouts": 1,
#                 "free_throws_att": 42,
#                 "free_throws_made": 23,
#                 "free_throws_pct": 0.548,
#                 "games_played": 28,
#                 "games_started": 28,
#                 "minutes": 738.0,
#                 "offensive_rebounds": 13,
#                 "personal_fouls": 64,
#                 "points": 214,
#                 "rebounds": 66,
#                 "steals": 14,
#                 "tech_fouls": 0,
#                 "three_points_att": 113,
#                 "three_points_made": 37,
#                 "three_points_pct": 0.327,
#                 "true_shooting_att": 219.48,
#                 "true_shooting_pct": 0.488,
#                 "turnovers": 53,
#                 "two_points_att": 88,
#                 "two_points_made": 40,
#                 "two_points_pct": 0.455
#             }
#         },
#         {
#             "average": {
#                 "assists": 2.1,
#                 "blocked_att": 0.68,
#                 "blocks": 0.41,
#                 "def_rebounds": 2.59,
#                 "efficiency": 9.05,
#                 "field_goals_att": 6.23,
#                 "field_goals_made": 2.59,
#                 "flagrant_fouls": 0.0,
#                 "free_throws_att": 2.68,
#                 "free_throws_made": 1.59,
#                 "minutes": 28.4,
#                 "off_rebounds": 0.86,
#                 "personal_fouls": 1.82,
#                 "points": 7.2,
#                 "rebounds": 3.45,
#                 "steals": 1.68,
#                 "three_points_att": 1.64,
#                 "three_points_made": 0.45,
#                 "true_shooting_att": 7.41,
#                 "turnovers": 1.14,
#                 "two_points_att": 4.59,
#                 "two_points_made": 2.14
#             },
#             "first_name": "Marcus",
#             "full_name": "Marcus Garrett",
#             "id": "37617439-1421-47bb-ab37-9ef0f6b740b9",
#             "jersey_number": "0",
#             "last_name": "Garrett",
#             "position": "G",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 47,
#                 "assists_turnover_ratio": 1.88,
#                 "blocked_att": 15,
#                 "blocks": 9,
#                 "defensive_rebounds": 57,
#                 "efficiency": 199,
#                 "ejections": 0,
#                 "field_goals_att": 137,
#                 "field_goals_made": 57,
#                 "field_goals_pct": 0.416,
#                 "flagrant_fouls": 0,
#                 "foulouts": 0,
#                 "free_throws_att": 59,
#                 "free_throws_made": 35,
#                 "free_throws_pct": 0.593,
#                 "games_played": 22,
#                 "games_started": 13,
#                 "minutes": 625.0,
#                 "offensive_rebounds": 19,
#                 "personal_fouls": 40,
#                 "points": 159,
#                 "rebounds": 76,
#                 "steals": 37,
#                 "tech_fouls": 0,
#                 "three_points_att": 36,
#                 "three_points_made": 10,
#                 "three_points_pct": 0.278,
#                 "true_shooting_att": 162.96,
#                 "true_shooting_pct": 0.488,
#                 "turnovers": 25,
#                 "two_points_att": 101,
#                 "two_points_made": 47,
#                 "two_points_pct": 0.465
#             }
#         },
#         {
#             "average": {
#                 "assists": 1.9,
#                 "blocked_att": 0.3,
#                 "blocks": 0.22,
#                 "def_rebounds": 3.48,
#                 "efficiency": 12.87,
#                 "field_goals_att": 10.78,
#                 "field_goals_made": 5.13,
#                 "flagrant_fouls": 0.0,
#                 "free_throws_att": 1.3,
#                 "free_throws_made": 1.0,
#                 "minutes": 33.0,
#                 "off_rebounds": 0.48,
#                 "personal_fouls": 1.3,
#                 "points": 14.1,
#                 "rebounds": 3.96,
#                 "steals": 1.17,
#                 "three_points_att": 6.3,
#                 "three_points_made": 2.87,
#                 "true_shooting_att": 11.36,
#                 "turnovers": 2.52,
#                 "two_points_att": 4.48,
#                 "two_points_made": 2.26
#             },
#             "first_name": "Lagerald",
#             "full_name": "Lagerald Vick",
#             "id": "3a752574-69d8-4744-af7a-aedc2cf547bd",
#             "jersey_number": "24",
#             "last_name": "Vick",
#             "position": "G",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 43,
#                 "assists_turnover_ratio": 0.74,
#                 "blocked_att": 7,
#                 "blocks": 5,
#                 "defensive_rebounds": 80,
#                 "efficiency": 296,
#                 "ejections": 0,
#                 "field_goals_att": 248,
#                 "field_goals_made": 118,
#                 "field_goals_pct": 0.476,
#                 "flagrant_fouls": 0,
#                 "foulouts": 0,
#                 "free_throws_att": 30,
#                 "free_throws_made": 23,
#                 "free_throws_pct": 0.767,
#                 "games_played": 23,
#                 "games_started": 20,
#                 "minutes": 759.0,
#                 "offensive_rebounds": 11,
#                 "personal_fouls": 30,
#                 "points": 325,
#                 "rebounds": 91,
#                 "steals": 27,
#                 "tech_fouls": 1,
#                 "three_points_att": 145,
#                 "three_points_made": 66,
#                 "three_points_pct": 0.455,
#                 "true_shooting_att": 261.2,
#                 "true_shooting_pct": 0.622,
#                 "turnovers": 58,
#                 "two_points_att": 103,
#                 "two_points_made": 52,
#                 "two_points_pct": 0.505
#             }
#         },
#         {
#             "average": {
#                 "assists": 0.5,
#                 "blocked_att": 0.04,
#                 "blocks": 0.04,
#                 "def_rebounds": 1.3,
#                 "efficiency": 3.96,
#                 "field_goals_att": 2.41,
#                 "field_goals_made": 1.15,
#                 "flagrant_fouls": 0.0,
#                 "free_throws_att": 0.78,
#                 "free_throws_made": 0.59,
#                 "minutes": 10.0,
#                 "off_rebounds": 0.59,
#                 "personal_fouls": 1.44,
#                 "points": 3.3,
#                 "rebounds": 1.89,
#                 "steals": 0.19,
#                 "three_points_att": 1.26,
#                 "three_points_made": 0.44,
#                 "true_shooting_att": 2.75,
#                 "turnovers": 0.56,
#                 "two_points_att": 1.15,
#                 "two_points_made": 0.7
#             },
#             "first_name": "K.J.",
#             "full_name": "K.J. Lawson",
#             "id": "3b5dfe93-b62e-42ff-b3aa-17b0f0bf7ec0",
#             "jersey_number": "13",
#             "last_name": "Lawson",
#             "position": "G",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 14,
#                 "assists_turnover_ratio": 0.93,
#                 "blocked_att": 1,
#                 "blocks": 1,
#                 "defensive_rebounds": 35,
#                 "efficiency": 107,
#                 "ejections": 0,
#                 "field_goals_att": 65,
#                 "field_goals_made": 31,
#                 "field_goals_pct": 0.477,
#                 "flagrant_fouls": 0,
#                 "foulouts": 0,
#                 "free_throws_att": 21,
#                 "free_throws_made": 16,
#                 "free_throws_pct": 0.762,
#                 "games_played": 27,
#                 "games_started": 0,
#                 "minutes": 270.0,
#                 "offensive_rebounds": 16,
#                 "personal_fouls": 39,
#                 "points": 90,
#                 "rebounds": 51,
#                 "steals": 5,
#                 "tech_fouls": 0,
#                 "three_points_att": 34,
#                 "three_points_made": 12,
#                 "three_points_pct": 0.353,
#                 "true_shooting_att": 74.24,
#                 "true_shooting_pct": 0.606,
#                 "turnovers": 15,
#                 "two_points_att": 31,
#                 "two_points_made": 19,
#                 "two_points_pct": 0.613
#             }
#         },
#         {
#             "average": {
#                 "assists": 2.0,
#                 "blocked_att": 1.04,
#                 "blocks": 1.07,
#                 "def_rebounds": 7.25,
#                 "efficiency": 22.86,
#                 "field_goals_att": 13.96,
#                 "field_goals_made": 6.86,
#                 "flagrant_fouls": 0.07,
#                 "free_throws_att": 5.64,
#                 "free_throws_made": 4.43,
#                 "minutes": 32.8,
#                 "off_rebounds": 3.04,
#                 "personal_fouls": 2.79,
#                 "points": 19.0,
#                 "rebounds": 10.29,
#                 "steals": 1.14,
#                 "three_points_att": 2.39,
#                 "three_points_made": 0.82,
#                 "true_shooting_att": 16.45,
#                 "turnovers": 2.25,
#                 "two_points_att": 11.57,
#                 "two_points_made": 6.04
#             },
#             "first_name": "Dedric",
#             "full_name": "Dedric Lawson",
#             "id": "4339985f-39fc-4fd6-995e-07986bf42539",
#             "jersey_number": "1",
#             "last_name": "Lawson",
#             "position": "F",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 55,
#                 "assists_turnover_ratio": 0.87,
#                 "blocked_att": 29,
#                 "blocks": 30,
#                 "defensive_rebounds": 203,
#                 "efficiency": 640,
#                 "ejections": 0,
#                 "field_goals_att": 391,
#                 "field_goals_made": 192,
#                 "field_goals_pct": 0.491,
#                 "flagrant_fouls": 2,
#                 "foulouts": 3,
#                 "free_throws_att": 158,
#                 "free_throws_made": 124,
#                 "free_throws_pct": 0.785,
#                 "games_played": 28,
#                 "games_started": 28,
#                 "minutes": 917.0,
#                 "offensive_rebounds": 85,
#                 "personal_fouls": 78,
#                 "points": 531,
#                 "rebounds": 288,
#                 "steals": 32,
#                 "tech_fouls": 0,
#                 "three_points_att": 67,
#                 "three_points_made": 23,
#                 "three_points_pct": 0.343,
#                 "true_shooting_att": 460.52,
#                 "true_shooting_pct": 0.577,
#                 "turnovers": 63,
#                 "two_points_att": 324,
#                 "two_points_made": 169,
#                 "two_points_pct": 0.522
#             }
#         },
#         {
#             "average": {
#                 "assists": 0.2,
#                 "blocked_att": 0.12,
#                 "blocks": 0.38,
#                 "def_rebounds": 1.46,
#                 "efficiency": 3.62,
#                 "field_goals_att": 1.77,
#                 "field_goals_made": 0.96,
#                 "flagrant_fouls": 0.0,
#                 "free_throws_att": 0.81,
#                 "free_throws_made": 0.42,
#                 "minutes": 8.4,
#                 "off_rebounds": 0.88,
#                 "personal_fouls": 1.04,
#                 "points": 2.3,
#                 "rebounds": 2.35,
#                 "steals": 0.15,
#                 "three_points_att": 0.0,
#                 "three_points_made": 0.0,
#                 "true_shooting_att": 2.12,
#                 "turnovers": 0.62,
#                 "two_points_att": 1.77,
#                 "two_points_made": 0.96
#             },
#             "first_name": "David",
#             "full_name": "David McCormack",
#             "id": "4e98e972-295f-47c9-9a87-6a2aab97937e",
#             "jersey_number": "33",
#             "last_name": "McCormack",
#             "position": "F",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 5,
#                 "assists_turnover_ratio": 0.31,
#                 "blocked_att": 3,
#                 "blocks": 10,
#                 "defensive_rebounds": 38,
#                 "efficiency": 94,
#                 "ejections": 0,
#                 "field_goals_att": 46,
#                 "field_goals_made": 25,
#                 "field_goals_pct": 0.543,
#                 "flagrant_fouls": 0,
#                 "foulouts": 0,
#                 "free_throws_att": 21,
#                 "free_throws_made": 11,
#                 "free_throws_pct": 0.524,
#                 "games_played": 26,
#                 "games_started": 5,
#                 "minutes": 219.0,
#                 "offensive_rebounds": 23,
#                 "personal_fouls": 27,
#                 "points": 61,
#                 "rebounds": 61,
#                 "steals": 4,
#                 "tech_fouls": 0,
#                 "three_points_att": 0,
#                 "three_points_made": 0,
#                 "three_points_pct": 0,
#                 "true_shooting_att": 55.24,
#                 "true_shooting_pct": 0.552,
#                 "turnovers": 16,
#                 "two_points_att": 46,
#                 "two_points_made": 25,
#                 "two_points_pct": 0.543
#             }
#         },
#         {
#             "average": {
#                 "assists": 0,
#                 "blocked_att": 0,
#                 "blocks": 0,
#                 "def_rebounds": 0,
#                 "efficiency": 0,
#                 "field_goals_att": 0,
#                 "field_goals_made": 0,
#                 "flagrant_fouls": 0,
#                 "free_throws_att": 0,
#                 "free_throws_made": 0,
#                 "minutes": 0,
#                 "off_rebounds": 0,
#                 "personal_fouls": 0,
#                 "points": 0,
#                 "rebounds": 0,
#                 "steals": 0,
#                 "three_points_att": 0,
#                 "three_points_made": 0,
#                 "true_shooting_att": 0,
#                 "turnovers": 0,
#                 "two_points_att": 0,
#                 "two_points_made": 0
#             },
#             "first_name": "Silvio",
#             "full_name": "Silvio De Sousa",
#             "id": "6c25f209-bd61-4a1e-a239-f5996e77335b",
#             "jersey_number": "22",
#             "last_name": "De Sousa",
#             "position": "F",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 0,
#                 "assists_turnover_ratio": 0,
#                 "blocked_att": 0,
#                 "blocks": 0,
#                 "defensive_rebounds": 0,
#                 "efficiency": 0,
#                 "ejections": 0,
#                 "field_goals_att": 0,
#                 "field_goals_made": 0,
#                 "field_goals_pct": 0,
#                 "flagrant_fouls": 0,
#                 "foulouts": 0,
#                 "free_throws_att": 0,
#                 "free_throws_made": 0,
#                 "free_throws_pct": 0,
#                 "games_played": 0,
#                 "games_started": 0,
#                 "minutes": 0.0,
#                 "offensive_rebounds": 0,
#                 "personal_fouls": 0,
#                 "points": 0,
#                 "rebounds": 0,
#                 "steals": 0,
#                 "tech_fouls": 0,
#                 "three_points_att": 0,
#                 "three_points_made": 0,
#                 "three_points_pct": 0,
#                 "true_shooting_att": 0.0,
#                 "true_shooting_pct": 0,
#                 "turnovers": 0,
#                 "two_points_att": 0,
#                 "two_points_made": 0,
#                 "two_points_pct": 0
#             }
#         },
#         {
#             "average": {
#                 "assists": 0.7,
#                 "blocked_att": 0.29,
#                 "blocks": 0.43,
#                 "def_rebounds": 3.79,
#                 "efficiency": 10.57,
#                 "field_goals_att": 6.64,
#                 "field_goals_made": 3.36,
#                 "flagrant_fouls": 0.0,
#                 "free_throws_att": 2.14,
#                 "free_throws_made": 1.5,
#                 "minutes": 26.1,
#                 "off_rebounds": 1.0,
#                 "personal_fouls": 1.86,
#                 "points": 9.4,
#                 "rebounds": 4.79,
#                 "steals": 0.71,
#                 "three_points_att": 3.21,
#                 "three_points_made": 1.14,
#                 "true_shooting_att": 7.59,
#                 "turnovers": 1.5,
#                 "two_points_att": 3.43,
#                 "two_points_made": 2.21
#             },
#             "first_name": "Ochai",
#             "full_name": "Ochai Agbaji",
#             "id": "6c7aeb2a-036c-4928-a201-a805136803e4",
#             "jersey_number": "30",
#             "last_name": "Agbaji",
#             "position": "G",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 10,
#                 "assists_turnover_ratio": 0.48,
#                 "blocked_att": 4,
#                 "blocks": 6,
#                 "defensive_rebounds": 53,
#                 "efficiency": 148,
#                 "ejections": 0,
#                 "field_goals_att": 93,
#                 "field_goals_made": 47,
#                 "field_goals_pct": 0.505,
#                 "flagrant_fouls": 0,
#                 "foulouts": 1,
#                 "free_throws_att": 30,
#                 "free_throws_made": 21,
#                 "free_throws_pct": 0.7,
#                 "games_played": 14,
#                 "games_started": 8,
#                 "minutes": 365.0,
#                 "offensive_rebounds": 14,
#                 "personal_fouls": 26,
#                 "points": 131,
#                 "rebounds": 67,
#                 "steals": 10,
#                 "tech_fouls": 0,
#                 "three_points_att": 45,
#                 "three_points_made": 16,
#                 "three_points_pct": 0.356,
#                 "true_shooting_att": 106.2,
#                 "true_shooting_pct": 0.617,
#                 "turnovers": 21,
#                 "two_points_att": 48,
#                 "two_points_made": 31,
#                 "two_points_pct": 0.646
#             }
#         },
#         {
#             "average": {
#                 "assists": 0.1,
#                 "blocked_att": 0.14,
#                 "blocks": 0.0,
#                 "def_rebounds": 0.0,
#                 "efficiency": -0.29,
#                 "field_goals_att": 0.43,
#                 "field_goals_made": 0.0,
#                 "flagrant_fouls": 0.0,
#                 "free_throws_att": 0.0,
#                 "free_throws_made": 0.0,
#                 "minutes": 1.0,
#                 "off_rebounds": 0.14,
#                 "personal_fouls": 0.29,
#                 "points": 0.0,
#                 "rebounds": 0.14,
#                 "steals": 0.0,
#                 "three_points_att": 0.14,
#                 "three_points_made": 0.0,
#                 "true_shooting_att": 0.43,
#                 "turnovers": 0.14,
#                 "two_points_att": 0.29,
#                 "two_points_made": 0.0
#             },
#             "first_name": "Garrett",
#             "full_name": "Garrett Luinstra",
#             "id": "7a46cfd2-a2f9-4900-b4f8-9ca86a368787",
#             "jersey_number": "20",
#             "last_name": "Luinstra",
#             "position": "G",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 1,
#                 "assists_turnover_ratio": 1.0,
#                 "blocked_att": 1,
#                 "blocks": 0,
#                 "defensive_rebounds": 0,
#                 "efficiency": -2,
#                 "ejections": 0,
#                 "field_goals_att": 3,
#                 "field_goals_made": 0,
#                 "field_goals_pct": 0.0,
#                 "flagrant_fouls": 0,
#                 "foulouts": 0,
#                 "free_throws_att": 0,
#                 "free_throws_made": 0,
#                 "free_throws_pct": 0,
#                 "games_played": 7,
#                 "games_started": 0,
#                 "minutes": 7.0,
#                 "offensive_rebounds": 1,
#                 "personal_fouls": 2,
#                 "points": 0,
#                 "rebounds": 1,
#                 "steals": 0,
#                 "tech_fouls": 0,
#                 "three_points_att": 1,
#                 "three_points_made": 0,
#                 "three_points_pct": 0.0,
#                 "true_shooting_att": 3.0,
#                 "true_shooting_pct": 0.0,
#                 "turnovers": 1,
#                 "two_points_att": 2,
#                 "two_points_made": 0,
#                 "two_points_pct": 0.0
#             }
#         },
#         {
#             "average": {
#                 "assists": 1.3,
#                 "blocked_att": 0.11,
#                 "blocks": 0.07,
#                 "def_rebounds": 0.78,
#                 "efficiency": 2.52,
#                 "field_goals_att": 3.96,
#                 "field_goals_made": 1.15,
#                 "flagrant_fouls": 0.0,
#                 "free_throws_att": 0.52,
#                 "free_throws_made": 0.37,
#                 "minutes": 14.0,
#                 "off_rebounds": 0.22,
#                 "personal_fouls": 1.04,
#                 "points": 3.3,
#                 "rebounds": 1.0,
#                 "steals": 0.63,
#                 "three_points_att": 2.48,
#                 "three_points_made": 0.67,
#                 "true_shooting_att": 4.19,
#                 "turnovers": 0.85,
#                 "two_points_att": 1.48,
#                 "two_points_made": 0.48
#             },
#             "first_name": "Charlie",
#             "full_name": "Charlie Moore",
#             "id": "80f20f25-39f3-42a5-875d-ac546d004cd1",
#             "jersey_number": "2",
#             "last_name": "Moore",
#             "position": "G",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 35,
#                 "assists_turnover_ratio": 1.52,
#                 "blocked_att": 3,
#                 "blocks": 2,
#                 "defensive_rebounds": 21,
#                 "efficiency": 68,
#                 "ejections": 0,
#                 "field_goals_att": 107,
#                 "field_goals_made": 31,
#                 "field_goals_pct": 0.29,
#                 "flagrant_fouls": 0,
#                 "foulouts": 0,
#                 "free_throws_att": 14,
#                 "free_throws_made": 10,
#                 "free_throws_pct": 0.714,
#                 "games_played": 27,
#                 "games_started": 1,
#                 "minutes": 378.0,
#                 "offensive_rebounds": 6,
#                 "personal_fouls": 28,
#                 "points": 90,
#                 "rebounds": 27,
#                 "steals": 17,
#                 "tech_fouls": 0,
#                 "three_points_att": 67,
#                 "three_points_made": 18,
#                 "three_points_pct": 0.269,
#                 "true_shooting_att": 113.16,
#                 "true_shooting_pct": 0.398,
#                 "turnovers": 23,
#                 "two_points_att": 40,
#                 "two_points_made": 13,
#                 "two_points_pct": 0.325
#             }
#         },
#         {
#             "average": {
#                 "assists": 3.6,
#                 "blocked_att": 0.64,
#                 "blocks": 0.18,
#                 "def_rebounds": 3.14,
#                 "efficiency": 13.79,
#                 "field_goals_att": 8.04,
#                 "field_goals_made": 3.96,
#                 "flagrant_fouls": 0.04,
#                 "free_throws_att": 4.0,
#                 "free_throws_made": 3.21,
#                 "minutes": 32.5,
#                 "off_rebounds": 0.5,
#                 "personal_fouls": 2.57,
#                 "points": 12.1,
#                 "rebounds": 3.64,
#                 "steals": 1.43,
#                 "three_points_att": 2.29,
#                 "three_points_made": 0.96,
#                 "true_shooting_att": 9.8,
#                 "turnovers": 2.32,
#                 "two_points_att": 5.75,
#                 "two_points_made": 3.0
#             },
#             "first_name": "Devon",
#             "full_name": "Devon Dotson",
#             "id": "82ff0d93-cd03-4ad9-9093-e54344f67c24",
#             "jersey_number": "11",
#             "last_name": "Dotson",
#             "position": "G",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 101,
#                 "assists_turnover_ratio": 1.55,
#                 "blocked_att": 18,
#                 "blocks": 5,
#                 "defensive_rebounds": 88,
#                 "efficiency": 386,
#                 "ejections": 0,
#                 "field_goals_att": 225,
#                 "field_goals_made": 111,
#                 "field_goals_pct": 0.493,
#                 "flagrant_fouls": 1,
#                 "foulouts": 3,
#                 "free_throws_att": 112,
#                 "free_throws_made": 90,
#                 "free_throws_pct": 0.804,
#                 "games_played": 28,
#                 "games_started": 28,
#                 "minutes": 911.0,
#                 "offensive_rebounds": 14,
#                 "personal_fouls": 72,
#                 "points": 339,
#                 "rebounds": 102,
#                 "steals": 40,
#                 "tech_fouls": 0,
#                 "three_points_att": 64,
#                 "three_points_made": 27,
#                 "three_points_pct": 0.422,
#                 "true_shooting_att": 274.28,
#                 "true_shooting_pct": 0.618,
#                 "turnovers": 65,
#                 "two_points_att": 161,
#                 "two_points_made": 84,
#                 "two_points_pct": 0.522
#             }
#         },
#         {
#             "average": {
#                 "assists": 0,
#                 "blocked_att": 0,
#                 "blocks": 0,
#                 "def_rebounds": 0,
#                 "efficiency": 0,
#                 "field_goals_att": 0,
#                 "field_goals_made": 0,
#                 "flagrant_fouls": 0,
#                 "free_throws_att": 0,
#                 "free_throws_made": 0,
#                 "minutes": 0,
#                 "off_rebounds": 0,
#                 "personal_fouls": 0,
#                 "points": 0,
#                 "rebounds": 0,
#                 "steals": 0,
#                 "three_points_att": 0,
#                 "three_points_made": 0,
#                 "true_shooting_att": 0,
#                 "turnovers": 0,
#                 "two_points_att": 0,
#                 "two_points_made": 0
#             },
#             "first_name": "Elijah",
#             "full_name": "Elijah Elliot",
#             "id": "b3d1fa8d-9d86-470a-b625-d418c9ecd826",
#             "jersey_number": "10",
#             "last_name": "Elliot",
#             "position": "G",
#             "primary_position": "NA",
#             "total": {
#                 "assists": 0,
#                 "assists_turnover_ratio": 0,
#                 "blocked_att": 0,
#                 "blocks": 0,
#                 "defensive_rebounds": 0,
#                 "efficiency": 0,
#                 "ejections": 0,
#                 "field_goals_att": 0,
#                 "field_goals_made": 0,
#                 "field_goals_pct": 0,
#                 "flagrant_fouls": 0,
#                 "foulouts": 0,
#                 "free_throws_att": 0,
#                 "free_throws_made": 0,
#                 "free_throws_pct": 0,
#                 "games_played": 0,
#                 "games_started": 0,
#                 "minutes": 0.0,
#                 "offensive_rebounds": 0,
#                 "personal_fouls": 0,
#                 "points": 0,
#                 "rebounds": 0,
#                 "steals": 0,
#                 "tech_fouls": 0,
#                 "three_points_att": 0,
#                 "three_points_made": 0,
#                 "three_points_pct": 0,
#                 "true_shooting_att": 0.0,
#                 "true_shooting_pct": 0,
#                 "turnovers": 0,
#                 "two_points_att": 0,
#                 "two_points_made": 0,
#                 "two_points_pct": 0
#             }
#         }
#     ],
#     "season": {
#         "id": "6c78669c-a47f-41b8-8715-5482db4d8a45",
#         "type": "REG",
#         "year": 2018
#     }
# }
