# %%
import requests
import json
import sklearn
import pandas as pd
import numpy as np
import csv
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
import tensorflow as tf

import time

from config import api_key

from pprint import pprint

# %% [markdown]
# ## Setting up URL and pull of League Data

# %%
# Original example from Collin
# League_url = f"http://api.sportradar.us/ncaamb/trial/v4/en/league/hierarchy.json?+{api_key}"

# added "api_key=" to the end of the URLs, changed URLs to be strings
# added api_key in the requests.get cells

# Team_url is the team level info, each team has a unique id and has to be pulled one at a time
#Team_url = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/fae4855b-1b64-4b40-a632-9ed345e1e952/statistics.json?api_key=" #+{api_key}
#Team_url = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/statistics.json?api_key=" #+{api_key}

# This url will get you all of the divisions, conferences, and related teams
# When looking at the division level we found that the 8th level was D1, which translates to [7] since it is zero indexed
League_url = "http://api.sportradar.us/ncaamb/trial/v4/en/league/hierarchy.json?api_key="


format = "json"

# %%
# #Collin's version
#League_url = f"http://api.sportradar.us/ncaamb/trial/v4/en/league/hierarchy.json?+{api_key}"
#format = "json"

# %%
# # Reformatted the requests.get
# League_response = requests.get(League_url + api_key).json()


# #League_response

# %%
# # Looking at data shape of the League level
#  print(json.dumps(League_response, indent=4, sort_keys=True))

# %%
# #division level - 7 is the NCAA D1
# d1 = League_response["divisions"][7] ["conferences"]#[0]
# #d1

# %%
# #conference level
# conferences = d1[0]["teams"]
# #conferences

# %%
# # Trying to look at venue - venue has the city/state info
# # We needed this info for the Tableau interactive map
# teams = conferences[0]["venue"]
# #teams

# %%
# #Breakdown of Conferences and teams within conference, along with IDs
# #included city and state to the output


# conference_names = []
# conference_ids = []
# team_names = []
# team_ids = []
# team_market = []
# team_city = []
# team_state = []


# for i in range(0,len(d1)):
#     conferences = d1[i]["teams"]
#     for j in range(0,len(conferences)):
#         teams = conferences[j]["venue"]
#         for k in range (0,len(teams)):
#             #print(d1[i]["name"])
#             #print(d1[i]["id"])
#             #print(conferences[j]["name"])
#             #print(conferences[j]["id"])
#             conference_names.append(d1[i]["name"])
#             conference_ids.append(d1[i]["id"])
#             team_market.append(conferences[j]["market"])
#             team_names.append(conferences[j]["name"])
#             team_ids.append(conferences[j]["id"])
#             team_city.append(conferences[j]["venue"]["city"])
#             team_state.append(conferences[j]["venue"]["state"])

# %%
#for j in range(0,len(conferences)):
        #teams = conferences[j]["venue"]
        #for k in range (0,len(teams)):
            #team_names.append(conferences[j]["name"])
            #team_ids.append(conferences[j]["id"])
            #team_city.append(conferences[j]["venue"]["city"])
            #team_state.append(conferences[j]["venue"]["state"])

# %%
# using zip
# zippedList = list(zip(team_market,team_names,team_ids,team_city,team_state,conference_names,conference_ids))
# zippedList

# %%
# # turning zipped list into a DF
# #teamdf = pd.DataFrame(zippedList,columns = [team_name,team_id,conference_name,conference_id],index=[])
# teamdf = pd.DataFrame({"team_market":team_market,
#                       "team_name":team_names,
#                       "team_id":team_ids,
#                        "team_city":team_city,
#                        "team_state":team_state,
#                       "conference_name":conference_names,
#                        "conference_id":conference_ids                       
#                       })

# #teamdf

# %%
# # This ouputs our DF into a CSV file
# teamdf.to_csv("team_conference_with_id_and_loc.csv", index=False)

# %% [markdown]
# ### This section is what I was using to attempt to loop through the team URL and pull team specific data
# ### It was left for reference only and should be mostly ignored
# ### Part of the issue may have been not allowing enough time for API response, but that was solved using a different loop method

# %%
#trying to set up list of teams... team_ids is already a list, team_ids_df is a datafram
#trying to use one of these to loop through a requests.get for teh teams
#team_ids_df = pd.DataFrame({"team_id":team_ids})
#team_ids

# %%
#team_id

#for i in range(0,len(d1)):
    #conferences = d1[i]["teams"]
    #for j in range(0,len(conferences)):
        #print(d1[i]["name"])
        #print(d1[i]["id"])
        #print(conferences[j]["name"])
        #print(conferences[j]["id"])
        #conference_name.append(d1[i]["name"])
        #conference_id.append(d1[i]["id"])
        #team_name.append(conferences[j]["name"])
        #team_id.append(conferences[j]["id"])
        
#for j in range(0,len(conferences)):
        #print(d1[i]["name"])
        #print(d1[i]["id"])
        #print(conferences[j]["name"])
        #print(conferences[j]["id"])
        #conference_name.append(d1[i]["name"])
        #conference_id.append(d1[i]["id"])
        #team_name.append(conferences[j]["name"])
        #team_id.append(conferences[j]["id"])

# %%
#Team_response = requests.get(Team_url + api_key).json()
#Team_url_1 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/"
#Team_url_2 = "/statistics.json?api_key="

#team_id -- this is taken from our lists

#Team_response = requests.get(Team_url_1 + team_id(i) + Team_url_2 + api_key).json()

# %%
#for team_id in team_ids:
    #Team_url_1 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/"
    #Team_url_2 = "/statistics.json?api_key="
    #Team_response = requests.get(Team_url_1 + team_id + Team_url_2 + api_key).json()

#for k in range(0,len(team_id_df)):
    #Team_response = requests.get(Team_url_1 + team_id_df(k) + Team_url_2 + api_key).json()


    #for i in range(0,len(d1)):
            #Team_response = d1[i]["teams"]
            #for j in range(0,len(Team_response)):
                #print(d1[i]["name"])
                #print(d1[i]["id"])
                #print(conferences[j]["name"])
                #print(conferences[j]["id"])
                #conference_name.append(d1[i]["name"])
                #conference_id.append(d1[i]["id"])
                #team_name.append(Team_response[j]["name"])
                #team_id.append(Team_response[j]["id"])
        
                #teamdf = pd.DataFrame({"team_name":name,
                                      #"type":reg,
                                      #"conference_name":conference_name,
                                      #"conference_id":conference_id
                                      #})

# %%
#print(Team_response)

# %%
#d1 = League_response

# %%
# #0d037a5d-827a-44dd-8b70-57603d671d5d
# #04d5255d-b2dc-43df-9fa8-d296b0f8ccd7
# Team_url_michigan_wolv = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/bdc2561d-f603-4fab-a262-f1d2af462277/statistics.json?api_key="
# mich = requests.get(Team_url_michigan_wolv + api_key).json()
# #d1 = League_response["divisions"][7] ["conferences"]

# %%
# mich

# %%
#d1_team_data = Team_pretend_response #["divisions"][7] ["conferences"]

# %% [markdown]
# ### This section is where we created the initial query of team information - totals and averages
# ### This was used to manually pull the top 16 teams of the 2018 tournament
# ### Once exported, the CSV was loaded into an SQLite db and joined with other data

# %%
# #defining empty lists here - BEFORE running URL and appends
# #If we have to manually run 64 teams through, then we don't want to empty our lists each time

# team_market = []
# team_names = []
# team_ids2 = []
# #Total
# total_games_played = []
# total_minutes_played = []
# total_field_goals_made = []
# total_field_goals_att = []
# total_minutes = []
# total_field_goals_made = []
# total_field_goals_att = []
# total_field_goals_pct = []
# total_two_points_made = []
# total_two_points_att = []
# total_two_points_pct = []
# total_three_points_made = []
# total_three_points_att = []
# total_three_points_pct = []
# total_blocked_att = []
# total_free_throws_made = []
# total_free_throws_att = []
# total_free_throws_pct = []
# total_offensive_rebounds = []
# total_defensive_rebounds = []
# total_rebounds = []
# total_assists = []
# total_turnovers = []
# total_assists_turnover_ratio = []
# total_steals = []
# total_blocks = []
# total_personal_fouls = []
# total_tech_fouls = []
# total_points = []
# total_fast_break_pts = []
# total_flagrant_fouls = []
# total_points_off_turnovers = []
# total_second_chance_pts = []
# total_ejections = []
# total_foulouts = []
# total_points_in_paint = []
# total_efficiency = []
# total_true_shooting_att = []
# total_true_shooting_pct = []
# #Average
# average_fast_break_pts = []
# average_points_off_turnovers = []
# average_second_chance_pts = []
# average_minutes = []
# average_points = []
# average_off_rebounds = []
# average_def_rebounds = []
# average_rebounds = []
# average_assists = []
# average_steals = []
# average_blocks = []
# average_turnovers = []
# average_personal_fouls = []
# average_flagrant_fouls = []
# average_blocked_att = []
# average_field_goals_made = []
# average_field_goals_att = []
# average_three_points_made = []
# average_three_points_att = []
# average_free_throws_made = []
# average_free_throws_att = []
# average_two_points_made = []
# average_two_points_att = []
# average_points_in_paint = []
# average_efficiency = []
# average_true_shooting_att = []

# %%
# #2016-2017 Teams - top 4 seed each region
# #4383eb6a-7fd8-4ff2-94c5-43c933121e88
# #faeb1160-5d15-4f26-99fc-c441cf21fc7f
# #db6e1cab-3fa3-4a93-a673-8b2a358ff4bf
# #912f8837-1d81-4ef9-a576-a21f271d4c64
# #fae4855b-1b64-4b40-a632-9ed345e1e952
# #b795ddbc-baab-4499-8803-52e8608520ab
# #1da70895-f77f-44ef-b216-d63c02e696eb
# #12d7f888-675b-459f-9099-a38f771d8a95
# #e9ca48b2-00ba-41c0-a02b-6885a2da1ff1
# #2267a1f4-68f6-418b-aaf6-2aa0c4b291f1
# #ec0d6b67-4b16-4b50-92b2-1a651dae6b0f
# #bdb7d7a4-45f8-4bf3-ab85-15488c451494
# #2f4d21f8-6d5f-48a5-abca-52a30583871a
# #9b166a3f-e64b-4825-bb6b-92c6f0418263
# #d3c8a767-b6fc-45d4-a5f2-18406f2993f1
# #f770d3a2-221c-49ce-9c7a-680f7417fe9e

# #2017-2018 Teams - top 4 seed each region
# #4383eb6a-7fd8-4ff2-94c5-43c933121e88
# #12d7f888-675b-459f-9099-a38f771d8a95
# #f8c705b7-87d3-411a-9c8b-5124daab0469
# #f38b58de-3273-4723-a78b-2f918e9aa2d5
# #fae4855b-1b64-4b40-a632-9ed345e1e952
# #faeb1160-5d15-4f26-99fc-c441cf21fc7f
# #a41d5a05-4c11-4171-a57e-e7a1ea325a6d
# #0c0608b3-f349-4f5e-9a10-7e6a744dd0d2
# #56913910-87f7-4ad7-ae3b-5cd9fb218fd9
# #a17dfc54-415f-49c3-a2e6-d6fa9db18b0a
# #b827dbdf-230f-4916-9703-3bb9004e26eb
# #9b166a3f-e64b-4825-bb6b-92c6f0418263
# #0d8a328f-20ce-410b-bed1-15fc01308aaf
# #e9ca48b2-00ba-41c0-a02b-6885a2da1ff1
# #bdc2561d-f603-4fab-a262-f1d2af462277
# #2f4d21f8-6d5f-48a5-abca-52a30583871a

# Team_url_2 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2017/REG/teams/bdc2561d-f603-4fab-a262-f1d2af462277/statistics.json?api_key="

# %%
# teams_response_2 = requests.get(Team_url_2 + api_key ).json()


# #teams_response_2

# %%
# team_market.append(teams_response_2["market"])
# team_names.append(teams_response_2["name"])
# team_ids2.append(teams_response_2["id"])
# total_games_played.append(teams_response_2["own_record"]["total"]["games_played"])
# total_minutes_played.append(teams_response_2["own_record"]["total"]["minutes"])
# total_field_goals_made.append(teams_response_2["own_record"]["total"]["field_goals_made"])
# total_field_goals_att.append(teams_response_2["own_record"]["total"]["field_goals_att"])
# total_field_goals_pct.append(teams_response_2["own_record"]["total"]["two_points_att"])
# total_two_points_made.append(teams_response_2["own_record"]["total"]["two_points_made"])
# total_two_points_att.append(teams_response_2["own_record"]["total"]["minutes"])
# total_two_points_pct.append(teams_response_2["own_record"]["total"]["two_points_pct"])
# total_three_points_made.append(teams_response_2["own_record"]["total"]["three_points_made"])
# total_three_points_att.append(teams_response_2["own_record"]["total"]["three_points_att"])
# total_three_points_pct.append(teams_response_2["own_record"]["total"]["three_points_pct"])
# total_blocked_att.append(teams_response_2["own_record"]["total"]["blocked_att"])
# total_free_throws_made.append(teams_response_2["own_record"]["total"]["free_throws_made"])
# total_free_throws_att.append(teams_response_2["own_record"]["total"]["free_throws_att"])
# total_free_throws_pct.append(teams_response_2["own_record"]["total"]["free_throws_pct"])
# total_offensive_rebounds.append(teams_response_2["own_record"]["total"]["offensive_rebounds"])
# total_defensive_rebounds.append(teams_response_2["own_record"]["total"]["defensive_rebounds"])
# total_rebounds.append(teams_response_2["own_record"]["total"]["rebounds"])
# total_assists.append(teams_response_2["own_record"]["total"]["assists"])
# total_turnovers.append(teams_response_2["own_record"]["total"]["turnovers"])
# total_assists_turnover_ratio.append(teams_response_2["own_record"]["total"]["assists_turnover_ratio"])
# total_steals.append(teams_response_2["own_record"]["total"]["steals"])
# total_blocks.append(teams_response_2["own_record"]["total"]["blocks"])
# total_personal_fouls.append(teams_response_2["own_record"]["total"]["personal_fouls"])
# total_tech_fouls.append(teams_response_2["own_record"]["total"]["tech_fouls"])
# total_points.append(teams_response_2["own_record"]["total"]["points"])
# total_fast_break_pts.append(teams_response_2["own_record"]["total"]["fast_break_pts"])
# total_flagrant_fouls.append(teams_response_2["own_record"]["total"]["flagrant_fouls"])
# total_points_off_turnovers.append(teams_response_2["own_record"]["total"]["points_off_turnovers"])
# total_second_chance_pts.append(teams_response_2["own_record"]["total"]["second_chance_pts"])
# total_ejections.append(teams_response_2["own_record"]["total"]["ejections"])
# total_foulouts.append(teams_response_2["own_record"]["total"]["foulouts"])
# total_points_in_paint.append(teams_response_2["own_record"]["total"]["points_in_paint"])
# total_efficiency.append(teams_response_2["own_record"]["total"]["efficiency"])
# total_true_shooting_att.append(teams_response_2["own_record"]["total"]["true_shooting_att"])
# total_true_shooting_pct.append(teams_response_2["own_record"]["total"]["true_shooting_pct"])
# average_fast_break_pts.append(teams_response_2["own_record"]["average"]["fast_break_pts"])
# average_points_off_turnovers.append(teams_response_2["own_record"]["average"]["points_off_turnovers"])
# average_second_chance_pts.append(teams_response_2["own_record"]["average"]["second_chance_pts"])
# average_minutes.append(teams_response_2["own_record"]["average"]["minutes"])
# average_points.append(teams_response_2["own_record"]["average"]["points"])
# average_off_rebounds.append(teams_response_2["own_record"]["average"]["off_rebounds"])
# average_def_rebounds.append(teams_response_2["own_record"]["average"]["def_rebounds"])
# average_rebounds.append(teams_response_2["own_record"]["average"]["rebounds"])
# average_assists.append(teams_response_2["own_record"]["average"]["assists"])
# average_steals.append(teams_response_2["own_record"]["average"]["steals"])
# average_blocks.append(teams_response_2["own_record"]["average"]["blocks"])
# average_turnovers.append(teams_response_2["own_record"]["average"]["turnovers"])
# average_personal_fouls.append(teams_response_2["own_record"]["average"]["personal_fouls"])
# average_flagrant_fouls.append(teams_response_2["own_record"]["average"]["flagrant_fouls"])
# average_blocked_att.append(teams_response_2["own_record"]["average"]["blocked_att"])
# average_field_goals_made.append(teams_response_2["own_record"]["average"]["field_goals_made"])
# average_field_goals_att.append(teams_response_2["own_record"]["average"]["field_goals_att"])
# average_three_points_made.append(teams_response_2["own_record"]["average"]["three_points_made"])
# average_three_points_att.append(teams_response_2["own_record"]["average"]["three_points_att"])
# average_free_throws_made.append(teams_response_2["own_record"]["average"]["free_throws_made"])
# average_free_throws_att.append(teams_response_2["own_record"]["average"]["free_throws_att"])
# average_two_points_made.append(teams_response_2["own_record"]["average"]["two_points_made"])
# average_two_points_att.append(teams_response_2["own_record"]["average"]["two_points_att"])
# average_points_in_paint.append(teams_response_2["own_record"]["average"]["points_in_paint"])
# average_efficiency.append(teams_response_2["own_record"]["average"]["efficiency"])
# average_true_shooting_att.append(teams_response_2["own_record"]["average"]["true_shooting_att"])

# %%
# zippedList = list(zip(team_market,team_names,team_ids2,total_games_played,total_minutes_played,total_field_goals_made,total_field_goals_att,
#                       total_minutes,total_field_goals_made,total_field_goals_att,total_field_goals_pct,total_two_points_made,total_two_points_att,
#                       total_two_points_pct,total_three_points_made,total_three_points_att,total_three_points_pct,total_blocked_att,total_free_throws_made,
#                       total_free_throws_att,total_free_throws_pct,total_offensive_rebounds,total_defensive_rebounds,total_rebounds,total_assists,
#                       total_turnovers,total_assists_turnover_ratio,total_steals,total_blocks,total_personal_fouls,total_tech_fouls,total_points,
#                       total_fast_break_pts,total_flagrant_fouls,total_points_off_turnovers,total_second_chance_pts,total_ejections,total_foulouts,
#                       total_points_in_paint,total_efficiency,total_true_shooting_att,total_true_shooting_pct,average_fast_break_pts,average_points_off_turnovers,
#                       average_second_chance_pts,average_minutes,average_points,average_off_rebounds,average_def_rebounds,average_rebounds,
#                       average_assists,average_steals,average_blocks,average_turnovers,average_personal_fouls,average_flagrant_fouls,average_blocked_att,
#                       average_field_goals_made,average_field_goals_att,average_three_points_made,average_three_points_att,average_free_throws_made,
#                       average_free_throws_att,average_two_points_made,average_two_points_att,average_points_in_paint,average_efficiency,average_true_shooting_att))

# %%
# teamdf = pd.DataFrame({"team_market":team_market,
#                       "team_name":team_names,
#                       "team_id":team_ids2,
#                       #totals
#                       'total_games_played' : total_games_played,
#                       'total_minutes_played' : total_minutes_played,
#                       'total_field_goals_made' : total_field_goals_made,
#                       'total_field_goals_att' : total_field_goals_att,
#                       'total_field_goals_pct' : total_field_goals_pct,
#                       'total_two_points_made' : total_two_points_made,
#                       'total_two_points_att' : total_two_points_att,
#                       'total_two_points_pct' : total_two_points_pct,
#                       'total_three_points_made' : total_three_points_made,
#                       'total_three_points_att' : total_three_points_att,
#                       'total_three_points_pct' : total_three_points_pct,
#                       'total_blocked_att' : total_blocked_att,
#                       'total_free_throws_made' : total_free_throws_made,
#                       'total_free_throws_att' : total_free_throws_att,
#                       'total_free_throws_pct' : total_free_throws_pct,
#                       'total_offensive_rebounds' : total_offensive_rebounds,
#                       'total_defensive_rebounds' : total_defensive_rebounds,
#                       'total_rebounds' : total_rebounds,
#                       'total_assists' : total_assists,
#                       'total_turnovers' : total_turnovers,
#                       'total_assists_turnover_ratio' : total_assists_turnover_ratio,
#                       'total_steals' : total_steals,
#                       'total_blocks' : total_blocks,
#                       'total_personal_fouls' : total_personal_fouls,
#                       'total_tech_fouls' : total_tech_fouls,
#                       'total_points' : total_points,
#                       'total_fast_break_pts' : total_fast_break_pts,
#                       'total_flagrant_fouls' : total_flagrant_fouls,
#                       'total_points_off_turnovers' : total_points_off_turnovers,
#                       'total_second_chance_pts' : total_second_chance_pts,
#                       'total_ejections' : total_ejections,
#                       'total_foulouts' : total_foulouts,
#                       'total_points_in_paint' : total_points_in_paint,
#                       'total_efficiency' : total_efficiency,
#                       'total_true_shooting_att' : total_true_shooting_att,
#                       'total_true_shooting_pct' : total_true_shooting_pct,
#                       #Averages
#                       'average_fast_break_pts' : average_fast_break_pts,
#                       'average_points_off_turnovers' : average_points_off_turnovers,
#                       'average_second_chance_pts' : average_second_chance_pts,
#                       'average_minutes' : average_minutes,
#                       'average_points' : average_points,
#                       'average_off_rebounds' : average_off_rebounds,
#                       'average_def_rebounds' : average_def_rebounds,
#                       'average_rebounds' : average_rebounds,
#                       'average_assists' : average_assists,
#                       'average_steals' : average_steals,
#                       'average_blocks' : average_blocks,
#                       'average_turnovers' : average_turnovers,
#                       'average_personal_fouls' : average_personal_fouls,
#                       'average_flagrant_fouls' : average_flagrant_fouls,
#                       'average_blocked_att' : average_blocked_att,
#                       'average_field_goals_made' : average_field_goals_made,
#                       'average_field_goals_att' : average_field_goals_att,
#                       'average_three_points_made' : average_three_points_made,
#                       'average_three_points_att' : average_three_points_att,
#                       'average_free_throws_made' : average_free_throws_made,
#                       'average_free_throws_att' : average_free_throws_att,
#                       'average_two_points_made' : average_two_points_made,
#                       'average_two_points_att' : average_two_points_att,
#                       'average_points_in_paint' : average_points_in_paint,
#                       'average_efficiency' : average_efficiency,
#                       'average_true_shooting_att' : average_true_shooting_att

#                       })

# %%
# # Cell used to export to CSV
# #teamdf
# teamdf.to_csv("2018_Team_Stats_sample.csv", index=False)
# #teamdf.to_csv("wolverines_only.csv", index=False)

# %% [markdown]
# ## Team data loop and output

# %%
# #Still trying to get a loop working to pull in all market data
# #Team_url_1 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/"
# #Team_url_2 = "/statistics.json?api_key="
# team_market = []
# team_names = []
# team_ids3 = []
# # Total
# total_games_played = []

# %%
#str1s = ''.join(team_ids)
#team_ids

# %%
## This cell pulls in a CSV file with all of the URLs and adds them to a list
## 

#First attempt
#with open ('URL_List.csv',newline='') as csvfile:
    #reader=csv.DictReader(csvfile)
    #for row in reader:
        #print (row['url'])

# Working version
url_loops = []        
with open('URL_List.csv','r') as url_dump:
    url_read=csv.reader(url_dump,delimiter=',')
    header = next(url_read)
    for row in url_read:
        url_loops.append(row[0])

# %%
#Checking the first record to make sure it looks okay
#url_loops= ''.join(team_ids)
#print(len(url_loops))
url_loops[0]

# %%
## This can be ignored - code used while playing around and trying to get the loop working
#for url_loop in url_loops:
    #Team_url_1 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/"
    #Team_url_2 = "/statistics.json?api_key="
    #Team_response_4 = requests.get(url_loop  + api_key).json()
    #Team_url_1 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/"+str(team_id)+"/statistics.json?api_key="
    #Team_response_3 = requests.get(Team_url_1 + api_key).json()
    #team_market.append(Team_response_3["market"])
    #team_names.append(Team_response_3["name"])
    #team_ids.append(Team_response_3["id"])
    #total_games_played.append(Team_response_3["own_record"]["total"]["games_played"])
    #Team_response_3

# %% [markdown]
# ## Finally got the loop working
# ### added a time delay to allow the api enough time to respond

# %%
#defining empty lists here - BEFORE running URL and appends
#If we have to manually run 64 teams through, then we don't want to empty our lists each time

team_market = []
team_names = []
team_ids2 = []
#Total
total_games_played = []
total_minutes_played = []
total_field_goals_made = []
total_field_goals_att = []
total_minutes = []
total_field_goals_made = []
total_field_goals_att = []
total_field_goals_pct = []
total_two_points_made = []
total_two_points_att = []
total_two_points_pct = []
total_three_points_made = []
total_three_points_att = []
total_three_points_pct = []
total_blocked_att = []
total_free_throws_made = []
total_free_throws_att = []
total_free_throws_pct = []
total_offensive_rebounds = []
total_defensive_rebounds = []
total_rebounds = []
total_assists = []
total_turnovers = []
total_assists_turnover_ratio = []
total_steals = []
total_blocks = []
total_personal_fouls = []
total_tech_fouls = []
total_points = []
total_fast_break_pts = []
total_flagrant_fouls = []
total_points_off_turnovers = []
total_second_chance_pts = []
total_ejections = []
total_foulouts = []
total_points_in_paint = []
total_efficiency = []
total_true_shooting_att = []
total_true_shooting_pct = []
#Average
average_fast_break_pts = []
average_points_off_turnovers = []
average_second_chance_pts = []
average_minutes = []
average_points = []
average_off_rebounds = []
average_def_rebounds = []
average_rebounds = []
average_assists = []
average_steals = []
average_blocks = []
average_turnovers = []
average_personal_fouls = []
average_flagrant_fouls = []
average_blocked_att = []
average_field_goals_made = []
average_field_goals_att = []
average_three_points_made = []
average_three_points_att = []
average_free_throws_made = []
average_free_throws_att = []
average_two_points_made = []
average_two_points_att = []
average_points_in_paint = []
average_efficiency = []
average_true_shooting_att = []

# %%
import time

k = []

# %%
# # Cell is for trying to develop a way to ignore terms that are not in the URL list

# for k in range(0,len(url_loops)):
#     Team_response_3 = requests.get(url_loops[k]  + api_key).json()
    
#     # Using a print statement to help see if the pull trips up
#     # 
#     print(Team_response_3["name"])
#     #ignore_errors=True
#     team_market.append(Team_response_3["market"],ignore_errors=True)
#     team_names.append(Team_response_3["name"],ignore_errors=True)
#     team_ids2.append(Team_response_3["id"],ignore_errors=True)
#     total_games_played.append(Team_response_3["own_record"]["total"]["games_played"],ignore_errors=True)
    
    
#     time.sleep(3)

# %%
#Team_url_1
#Team_response_3
#len(url_loops)
# Importing time and adding a delay, had an issue where we couldn't pull
#import time

#k = []
for k in range(0,len(url_loops)):
    Team_response_3 = requests.get(url_loops[k]  + api_key).json()
    
    # Using a print statement to help see if the pull trips up
    # 
    print(Team_response_3["name"])
    
    team_market.append(Team_response_3["market"])
    team_names.append(Team_response_3["name"])
    team_ids2.append(Team_response_3["id"])
    total_games_played.append(Team_response_3["own_record"]["total"]["games_played"])
    total_minutes_played.append(Team_response_3["own_record"]["total"]["minutes"])
    total_field_goals_made.append(Team_response_3["own_record"]["total"]["field_goals_made"])
    total_field_goals_att.append(Team_response_3["own_record"]["total"]["field_goals_att"])
    total_field_goals_pct.append(Team_response_3["own_record"]["total"]["two_points_att"])
    total_two_points_made.append(Team_response_3["own_record"]["total"]["two_points_made"])
    total_two_points_att.append(Team_response_3["own_record"]["total"]["minutes"])
    total_two_points_pct.append(Team_response_3["own_record"]["total"]["two_points_pct"])
    total_three_points_made.append(Team_response_3["own_record"]["total"]["three_points_made"])
    total_three_points_att.append(Team_response_3["own_record"]["total"]["three_points_att"])
    total_three_points_pct.append(Team_response_3["own_record"]["total"]["three_points_pct"])
    total_blocked_att.append(Team_response_3["own_record"]["total"]["blocked_att"])
    total_free_throws_made.append(Team_response_3["own_record"]["total"]["free_throws_made"])
    total_free_throws_att.append(Team_response_3["own_record"]["total"]["free_throws_att"])
    total_free_throws_pct.append(Team_response_3["own_record"]["total"]["free_throws_pct"])
    total_offensive_rebounds.append(Team_response_3["own_record"]["total"]["offensive_rebounds"])
    total_defensive_rebounds.append(Team_response_3["own_record"]["total"]["defensive_rebounds"])
    total_rebounds.append(Team_response_3["own_record"]["total"]["rebounds"])
    total_assists.append(Team_response_3["own_record"]["total"]["assists"])
    total_turnovers.append(Team_response_3["own_record"]["total"]["turnovers"])
    total_assists_turnover_ratio.append(Team_response_3["own_record"]["total"]["assists_turnover_ratio"])
    total_steals.append(Team_response_3["own_record"]["total"]["steals"])
    total_blocks.append(Team_response_3["own_record"]["total"]["blocks"])
    total_personal_fouls.append(Team_response_3["own_record"]["total"]["personal_fouls"])
    total_tech_fouls.append(Team_response_3["own_record"]["total"]["tech_fouls"])
    total_points.append(Team_response_3["own_record"]["total"]["points"])
    total_fast_break_pts.append(Team_response_3["own_record"]["total"]["fast_break_pts"])
    total_flagrant_fouls.append(Team_response_3["own_record"]["total"]["flagrant_fouls"])
    total_points_off_turnovers.append(Team_response_3["own_record"]["total"]["points_off_turnovers"])
    total_second_chance_pts.append(Team_response_3["own_record"]["total"]["second_chance_pts"])
    total_ejections.append(Team_response_3["own_record"]["total"]["ejections"])
    total_foulouts.append(Team_response_3["own_record"]["total"]["foulouts"])
    total_points_in_paint.append(Team_response_3["own_record"]["total"]["points_in_paint"])
    total_efficiency.append(Team_response_3["own_record"]["total"]["efficiency"])
    total_true_shooting_att.append(Team_response_3["own_record"]["total"]["true_shooting_att"])
    total_true_shooting_pct.append(Team_response_3["own_record"]["total"]["true_shooting_pct"])
    average_fast_break_pts.append(Team_response_3["own_record"]["average"]["fast_break_pts"])
    average_points_off_turnovers.append(Team_response_3["own_record"]["average"]["points_off_turnovers"])
    average_second_chance_pts.append(Team_response_3["own_record"]["average"]["second_chance_pts"])
    average_minutes.append(Team_response_3["own_record"]["average"]["minutes"])
    average_points.append(Team_response_3["own_record"]["average"]["points"])
    average_off_rebounds.append(Team_response_3["own_record"]["average"]["off_rebounds"])
    average_def_rebounds.append(Team_response_3["own_record"]["average"]["def_rebounds"])
    average_rebounds.append(Team_response_3["own_record"]["average"]["rebounds"])
    average_assists.append(Team_response_3["own_record"]["average"]["assists"])
    average_steals.append(Team_response_3["own_record"]["average"]["steals"])
    average_blocks.append(Team_response_3["own_record"]["average"]["blocks"])
    average_turnovers.append(Team_response_3["own_record"]["average"]["turnovers"])
    average_personal_fouls.append(Team_response_3["own_record"]["average"]["personal_fouls"])
    average_flagrant_fouls.append(Team_response_3["own_record"]["average"]["flagrant_fouls"])
    average_blocked_att.append(Team_response_3["own_record"]["average"]["blocked_att"])
    average_field_goals_made.append(Team_response_3["own_record"]["average"]["field_goals_made"])
    average_field_goals_att.append(Team_response_3["own_record"]["average"]["field_goals_att"])
    average_three_points_made.append(Team_response_3["own_record"]["average"]["three_points_made"])
    average_three_points_att.append(Team_response_3["own_record"]["average"]["three_points_att"])
    average_free_throws_made.append(Team_response_3["own_record"]["average"]["free_throws_made"])
    average_free_throws_att.append(Team_response_3["own_record"]["average"]["free_throws_att"])
    average_two_points_made.append(Team_response_3["own_record"]["average"]["two_points_made"])
    average_two_points_att.append(Team_response_3["own_record"]["average"]["two_points_att"])
    average_points_in_paint.append(Team_response_3["own_record"]["average"]["points_in_paint"])
    average_efficiency.append(Team_response_3["own_record"]["average"]["efficiency"])
    average_true_shooting_att.append(Team_response_3["own_record"]["average"]["true_shooting_att"])
    time.sleep(3)

# %%
zippedList = list(zip(team_market,team_names,team_ids2,total_games_played,total_minutes_played,total_field_goals_made,total_field_goals_att,
                      total_minutes,total_field_goals_made,total_field_goals_att,total_field_goals_pct,total_two_points_made,total_two_points_att,
                      total_two_points_pct,total_three_points_made,total_three_points_att,total_three_points_pct,total_blocked_att,total_free_throws_made,
                      total_free_throws_att,total_free_throws_pct,total_offensive_rebounds,total_defensive_rebounds,total_rebounds,total_assists,
                      total_turnovers,total_assists_turnover_ratio,total_steals,total_blocks,total_personal_fouls,total_tech_fouls,total_points,
                      total_fast_break_pts,total_flagrant_fouls,total_points_off_turnovers,total_second_chance_pts,total_ejections,total_foulouts,
                      total_points_in_paint,total_efficiency,total_true_shooting_att,total_true_shooting_pct,average_fast_break_pts,average_points_off_turnovers,
                      average_second_chance_pts,average_minutes,average_points,average_off_rebounds,average_def_rebounds,average_rebounds,
                      average_assists,average_steals,average_blocks,average_turnovers,average_personal_fouls,average_flagrant_fouls,average_blocked_att,
                      average_field_goals_made,average_field_goals_att,average_three_points_made,average_three_points_att,average_free_throws_made,
                      average_free_throws_att,average_two_points_made,average_two_points_att,average_points_in_paint,average_efficiency,average_true_shooting_att))

# %%
teamdf = pd.DataFrame({"team_market":team_market,
                      "team_name":team_names,
                      "team_id":team_ids2,
                      #totals
                      'total_games_played' : total_games_played,
                      'total_minutes_played' : total_minutes_played,
                      'total_field_goals_made' : total_field_goals_made,
                      'total_field_goals_att' : total_field_goals_att,
                      'total_field_goals_pct' : total_field_goals_pct,
                      'total_two_points_made' : total_two_points_made,
                      'total_two_points_att' : total_two_points_att,
                      'total_two_points_pct' : total_two_points_pct,
                      'total_three_points_made' : total_three_points_made,
                      'total_three_points_att' : total_three_points_att,
                      'total_three_points_pct' : total_three_points_pct,
                      'total_blocked_att' : total_blocked_att,
                      'total_free_throws_made' : total_free_throws_made,
                      'total_free_throws_att' : total_free_throws_att,
                      'total_free_throws_pct' : total_free_throws_pct,
                      'total_offensive_rebounds' : total_offensive_rebounds,
                      'total_defensive_rebounds' : total_defensive_rebounds,
                      'total_rebounds' : total_rebounds,
                      'total_assists' : total_assists,
                      'total_turnovers' : total_turnovers,
                      'total_assists_turnover_ratio' : total_assists_turnover_ratio,
                      'total_steals' : total_steals,
                      'total_blocks' : total_blocks,
                      'total_personal_fouls' : total_personal_fouls,
                      'total_tech_fouls' : total_tech_fouls,
                      'total_points' : total_points,
                      'total_fast_break_pts' : total_fast_break_pts,
                      'total_flagrant_fouls' : total_flagrant_fouls,
                      'total_points_off_turnovers' : total_points_off_turnovers,
                      'total_second_chance_pts' : total_second_chance_pts,
                      'total_ejections' : total_ejections,
                      'total_foulouts' : total_foulouts,
                      'total_points_in_paint' : total_points_in_paint,
                      'total_efficiency' : total_efficiency,
                      'total_true_shooting_att' : total_true_shooting_att,
                      'total_true_shooting_pct' : total_true_shooting_pct,
                      #Averages
                      'average_fast_break_pts' : average_fast_break_pts,
                      'average_points_off_turnovers' : average_points_off_turnovers,
                      'average_second_chance_pts' : average_second_chance_pts,
                      'average_minutes' : average_minutes,
                      'average_points' : average_points,
                      'average_off_rebounds' : average_off_rebounds,
                      'average_def_rebounds' : average_def_rebounds,
                      'average_rebounds' : average_rebounds,
                      'average_assists' : average_assists,
                      'average_steals' : average_steals,
                      'average_blocks' : average_blocks,
                      'average_turnovers' : average_turnovers,
                      'average_personal_fouls' : average_personal_fouls,
                      'average_flagrant_fouls' : average_flagrant_fouls,
                      'average_blocked_att' : average_blocked_att,
                      'average_field_goals_made' : average_field_goals_made,
                      'average_field_goals_att' : average_field_goals_att,
                      'average_three_points_made' : average_three_points_made,
                      'average_three_points_att' : average_three_points_att,
                      'average_free_throws_made' : average_free_throws_made,
                      'average_free_throws_att' : average_free_throws_att,
                      'average_two_points_made' : average_two_points_made,
                      'average_two_points_att' : average_two_points_att,
                      'average_points_in_paint' : average_points_in_paint,
                      'average_efficiency' : average_efficiency,
                      'average_true_shooting_att' : average_true_shooting_att

                      })

# %%
# Output the data to CSV
# Will need to change season
# 2017 is for the 2017-2018 season
# 2018 is for the 2018-2019 season
teamdf.to_csv("2017_Reg_Season.csv", index=False)

# %%
#error_url = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2017/REG/teams/3a000455-de7c-4ca8-880e-abdce7f21da9/statistics.json?api_key="
error_url = "https://api.sportradar.us/ncaamb/trial/v4/en/rpi/2017/rankings.json?api_key="
turkey_farts = requests.get(error_url + api_key).json()

# %%
turkey_farts
# Out:
# {'season': {'id': '8a0e25c0-4e7b-4c26-84db-39701582087a',
#   'year': 2017,
#   'type': 'REG'},
#  'rankings': [{'id': '4383eb6a-7fd8-4ff2-94c5-43c933121e88',
#    'name': 'Wildcats',
#    'market': 'Villanova',
#    'rank': 1,
#    'prev_rank': 1,
#    'wins': 36,
#    'losses': 4,
#    'home_wins': 12,
#    'home_losses': 1,
#    'away_wins': 9,
#    'away_losses': 3,
#    'neut_wins': 15,
#    'neut_losses': 0,
#    'opp_wins': 792,
#    'opp_losses': 478,
#    'owp': 0.613,
#    'oowp': 0.5457,
#    'awp': 0.9158,
#    'sos': 0.5906,
#    'rpi': 0.6719,
#    'opponents': [{'rank': '1-25', 'wins': 7, 'losses': 0},
#     {'rank': '1-50', 'wins': 12, 'losses': 0},
#     {'rank': '101-150', 'wins': 7, 'losses': 1},
#     {'rank': '151+', 'wins': 7, 'losses': 0},
#     {'rank': '26-50', 'wins': 5, 'losses': 0},
#     {'rank': '51-100', 'wins': 10, 'losses': 3}]},
#   {'id': '56913910-87f7-4ad7-ae3b-5cd9fb218fd9',
#    'name': 'Cavaliers',
#    'market': 'Virginia',
#    'rank': 2,
#    'prev_rank': 2,
#    'wins': 31,
#    'losses': 3,
#    'home_wins': 16,
#    'home_losses': 1,
#    'away_wins': 10,
#    'away_losses': 1,
#    'neut_wins': 5,
#    'neut_losses': 1,
#    'opp_wins': 667,
#    'opp_losses': 430,
#    'owp': 0.5898,
#    'oowp': 0.5532,
#    'awp': 0.9051,
#    'sos': 0.5776,
#    'rpi': 0.6595,
#    'opponents': [{'rank': '1-25', 'wins': 6, 'losses': 0},
#     {'rank': '1-50', 'wins': 13, 'losses': 1},
#     {'rank': '101-150', 'wins': 4, 'losses': 1},
#     {'rank': '151+', 'wins': 9, 'losses': 0},
#     {'rank': '26-50', 'wins': 7, 'losses': 1},
#     {'rank': '51-100', 'wins': 5, 'losses': 1}]},
#   {'id': 'fae4855b-1b64-4b40-a632-9ed345e1e952',
#    'name': 'Jayhawks',
#    'market': 'Kansas',
#    'rank': 3,
#    'prev_rank': 3,
#    'wins': 31,
#    'losses': 8,
#    'home_wins': 14,
#    'home_losses': 4,
#    'away_wins': 7,
#    'away_losses': 3,
#    'neut_wins': 10,
#    'neut_losses': 1,
#    'opp_wins': 822,
#    'opp_losses': 450,
#    'owp': 0.6387,
#    'oowp': 0.5551,
#    'awp': 0.7705,
#    'sos': 0.6108,
#    'rpi': 0.6507,
#    'opponents': [{'rank': '1-25', 'wins': 5, 'losses': 2},
#     {'rank': '1-50', 'wins': 13, 'losses': 3},
#     {'rank': '101-150', 'wins': 3, 'losses': 2},
#     {'rank': '151+', 'wins': 5, 'losses': 0},
#     {'rank': '26-50', 'wins': 8, 'losses': 1},
#     {'rank': '51-100', 'wins': 10, 'losses': 3}]},
#   {'id': 'faeb1160-5d15-4f26-99fc-c441cf21fc7f',
#    'name': 'Blue Devils',
#    'market': 'Duke',
#    'rank': 4,
#    'prev_rank': 4,
#    'wins': 29,
#    'losses': 8,
#    'home_wins': 15,
#    'home_losses': 1,
#    'away_wins': 6,
#    'away_losses': 5,
#    'neut_wins': 8,
#    'neut_losses': 2,
#    'opp_wins': 721,
#    'opp_losses': 462,
#    'owp': 0.612,
#    'oowp': 0.5525,
#    'awp': 0.7987,
#    'sos': 0.5921,
#    'rpi': 0.6438,
#    'opponents': [{'rank': '1-25', 'wins': 4, 'losses': 4},
#     {'rank': '1-50', 'wins': 10, 'losses': 4},
#     {'rank': '101-150', 'wins': 2, 'losses': 2},
#     {'rank': '151+', 'wins': 10, 'losses': 0},
#     {'rank': '26-50', 'wins': 6, 'losses': 0},
#     {'rank': '51-100', 'wins': 7, 'losses': 2}]},
#   {'id': '0d8a328f-20ce-410b-bed1-15fc01308aaf',
#    'name': 'Musketeers',
#    'market': 'Xavier',
#    'rank': 5,
#    'prev_rank': 5,
#    'wins': 29,
#    'losses': 6,
#    'home_wins': 17,
#    'home_losses': 1,
#    'away_wins': 9,
#    'away_losses': 2,
#    'neut_wins': 3,
#    'neut_losses': 3,
#    'opp_wins': 664,
#    'opp_losses': 441,
#    'owp': 0.5869,
#    'oowp': 0.543,
#    'awp': 0.8217,
#    'sos': 0.5723,
#    'rpi': 0.6346,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 2},
#     {'rank': '1-50', 'wins': 3, 'losses': 3},
#     {'rank': '101-150', 'wins': 6, 'losses': 0},
#     {'rank': '151+', 'wins': 8, 'losses': 0},
#     {'rank': '26-50', 'wins': 2, 'losses': 1},
#     {'rank': '51-100', 'wins': 12, 'losses': 3}]},
#   {'id': 'b827dbdf-230f-4916-9703-3bb9004e26eb',
#    'name': 'Volunteers',
#    'market': 'Tennessee',
#    'rank': 6,
#    'prev_rank': 6,
#    'wins': 26,
#    'losses': 9,
#    'home_wins': 13,
#    'home_losses': 2,
#    'away_wins': 8,
#    'away_losses': 4,
#    'neut_wins': 5,
#    'neut_losses': 3,
#    'opp_wins': 682,
#    'opp_losses': 440,
#    'owp': 0.6006,
#    'oowp': 0.5591,
#    'awp': 0.7453,
#    'sos': 0.5868,
#    'rpi': 0.6264,
#    'opponents': [{'rank': '1-25', 'wins': 4, 'losses': 5},
#     {'rank': '1-50', 'wins': 8, 'losses': 8},
#     {'rank': '101-150', 'wins': 2, 'losses': 0},
#     {'rank': '151+', 'wins': 8, 'losses': 0},
#     {'rank': '26-50', 'wins': 4, 'losses': 3},
#     {'rank': '51-100', 'wins': 8, 'losses': 1}]},
#   {'id': 'bdc2561d-f603-4fab-a262-f1d2af462277',
#    'name': 'Wolverines',
#    'market': 'Michigan',
#    'rank': 7,
#    'prev_rank': 7,
#    'wins': 32,
#    'losses': 8,
#    'home_wins': 15,
#    'home_losses': 1,
#    'away_wins': 6,
#    'away_losses': 5,
#    'neut_wins': 11,
#    'neut_losses': 2,
#    'opp_wins': 767,
#    'opp_losses': 504,
#    'owp': 0.5714,
#    'oowp': 0.5378,
#    'awp': 0.8161,
#    'sos': 0.5602,
#    'rpi': 0.6242,
#    'opponents': [{'rank': '1-25', 'wins': 7, 'losses': 5},
#     {'rank': '1-50', 'wins': 9, 'losses': 5},
#     {'rank': '101-150', 'wins': 3, 'losses': 0},
#     {'rank': '151+', 'wins': 14, 'losses': 1},
#     {'rank': '26-50', 'wins': 2, 'losses': 0},
#     {'rank': '51-100', 'wins': 6, 'losses': 2}]},
#   {'id': 'e9ca48b2-00ba-41c0-a02b-6885a2da1ff1',
#    'name': 'Tar Heels',
#    'market': 'North Carolina',
#    'rank': 8,
#    'prev_rank': 8,
#    'wins': 26,
#    'losses': 11,
#    'home_wins': 12,
#    'home_losses': 3,
#    'away_wins': 7,
#    'away_losses': 5,
#    'neut_wins': 7,
#    'neut_losses': 3,
#    'opp_wins': 777,
#    'opp_losses': 423,
#    'owp': 0.6153,
#    'oowp': 0.5628,
#    'awp': 0.7018,
#    'sos': 0.5978,
#    'rpi': 0.6238,
#    'opponents': [{'rank': '1-25', 'wins': 6, 'losses': 6},
#     {'rank': '1-50', 'wins': 11, 'losses': 8},
#     {'rank': '101-150', 'wins': 2, 'losses': 1},
#     {'rank': '151+', 'wins': 6, 'losses': 0},
#     {'rank': '26-50', 'wins': 5, 'losses': 2},
#     {'rank': '51-100', 'wins': 7, 'losses': 2}]},
#   {'id': '62a73b4a-e281-4483-a1f8-f1160a18e456',
#    'name': 'Wolf Pack',
#    'market': 'Nevada',
#    'rank': 9,
#    'prev_rank': 9,
#    'wins': 29,
#    'losses': 8,
#    'home_wins': 14,
#    'home_losses': 1,
#    'away_wins': 11,
#    'away_losses': 3,
#    'neut_wins': 4,
#    'neut_losses': 4,
#    'opp_wins': 662,
#    'opp_losses': 467,
#    'owp': 0.5877,
#    'oowp': 0.5168,
#    'awp': 0.7943,
#    'sos': 0.5641,
#    'rpi': 0.6216,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 2},
#     {'rank': '1-50', 'wins': 2, 'losses': 3},
#     {'rank': '101-150', 'wins': 8, 'losses': 2},
#     {'rank': '151+', 'wins': 10, 'losses': 0},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 9, 'losses': 3}]},
#   {'id': 'a17dfc54-415f-49c3-a2e6-d6fa9db18b0a',
#    'name': 'Bearcats',
#    'market': 'Cincinnati',
#    'rank': 10,
#    'prev_rank': 10,
#    'wins': 31,
#    'losses': 5,
#    'home_wins': 15,
#    'home_losses': 1,
#    'away_wins': 9,
#    'away_losses': 2,
#    'neut_wins': 7,
#    'neut_losses': 2,
#    'opp_wins': 655,
#    'opp_losses': 472,
#    'owp': 0.548,
#    'oowp': 0.5285,
#    'awp': 0.8614,
#    'sos': 0.5415,
#    'rpi': 0.6215,
#    'opponents': [{'rank': '1-25', 'wins': 4, 'losses': 4},
#     {'rank': '1-50', 'wins': 6, 'losses': 5},
#     {'rank': '101-150', 'wins': 9, 'losses': 0},
#     {'rank': '151+', 'wins': 10, 'losses': 0},
#     {'rank': '26-50', 'wins': 2, 'losses': 1},
#     {'rank': '51-100', 'wins': 6, 'losses': 0}]},
#   {'id': '2267a1f4-68f6-418b-aaf6-2aa0c4b291f1',
#    'name': 'Wildcats',
#    'market': 'Kentucky',
#    'rank': 11,
#    'prev_rank': 11,
#    'wins': 26,
#    'losses': 11,
#    'home_wins': 16,
#    'home_losses': 2,
#    'away_wins': 4,
#    'away_losses': 6,
#    'neut_wins': 6,
#    'neut_losses': 3,
#    'opp_wins': 738,
#    'opp_losses': 454,
#    'owp': 0.6156,
#    'oowp': 0.5586,
#    'awp': 0.6928,
#    'sos': 0.5966,
#    'rpi': 0.6207,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 5},
#     {'rank': '1-50', 'wins': 11, 'losses': 9},
#     {'rank': '101-150', 'wins': 3, 'losses': 0},
#     {'rank': '151+', 'wins': 5, 'losses': 0},
#     {'rank': '26-50', 'wins': 8, 'losses': 4},
#     {'rank': '51-100', 'wins': 7, 'losses': 2}]},
#   {'id': 'dcf5c2e7-c227-4c20-af26-715d5f859412',
#    'name': 'Tigers',
#    'market': 'Clemson',
#    'rank': 12,
#    'prev_rank': 12,
#    'wins': 25,
#    'losses': 10,
#    'home_wins': 15,
#    'home_losses': 1,
#    'away_wins': 4,
#    'away_losses': 6,
#    'neut_wins': 6,
#    'neut_losses': 3,
#    'opp_wins': 696,
#    'opp_losses': 432,
#    'owp': 0.6031,
#    'oowp': 0.5538,
#    'awp': 0.7203,
#    'sos': 0.5867,
#    'rpi': 0.6201,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 5},
#     {'rank': '1-50', 'wins': 8, 'losses': 7},
#     {'rank': '101-150', 'wins': 5, 'losses': 0},
#     {'rank': '151+', 'wins': 8, 'losses': 0},
#     {'rank': '26-50', 'wins': 5, 'losses': 2},
#     {'rank': '51-100', 'wins': 4, 'losses': 3}]},
#   {'id': '12d7f888-675b-459f-9099-a38f771d8a95',
#    'name': 'Boilermakers',
#    'market': 'Purdue',
#    'rank': 13,
#    'prev_rank': 13,
#    'wins': 30,
#    'losses': 7,
#    'home_wins': 16,
#    'home_losses': 1,
#    'away_wins': 8,
#    'away_losses': 2,
#    'neut_wins': 6,
#    'neut_losses': 4,
#    'opp_wins': 701,
#    'opp_losses': 481,
#    'owp': 0.5713,
#    'oowp': 0.5346,
#    'awp': 0.8024,
#    'sos': 0.559,
#    'rpi': 0.6199,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 5},
#     {'rank': '1-50', 'wins': 4, 'losses': 6},
#     {'rank': '101-150', 'wins': 3, 'losses': 1},
#     {'rank': '151+', 'wins': 14, 'losses': 0},
#     {'rank': '26-50', 'wins': 1, 'losses': 1},
#     {'rank': '51-100', 'wins': 9, 'losses': 0}]},
#   {'id': '0c0608b3-f349-4f5e-9a10-7e6a744dd0d2',
#    'name': 'Tigers',
#    'market': 'Auburn',
#    'rank': 14,
#    'prev_rank': 14,
#    'wins': 26,
#    'losses': 8,
#    'home_wins': 15,
#    'home_losses': 1,
#    'away_wins': 7,
#    'away_losses': 4,
#    'neut_wins': 4,
#    'neut_losses': 3,
#    'opp_wins': 608,
#    'opp_losses': 452,
#    'owp': 0.5758,
#    'oowp': 0.5495,
#    'awp': 0.7703,
#    'sos': 0.567,
#    'rpi': 0.6178,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 2},
#     {'rank': '1-50', 'wins': 8, 'losses': 6},
#     {'rank': '101-150', 'wins': 4, 'losses': 0},
#     {'rank': '151+', 'wins': 9, 'losses': 0},
#     {'rank': '26-50', 'wins': 6, 'losses': 4},
#     {'rank': '51-100', 'wins': 5, 'losses': 2}]},
#   {'id': '61a3908a-7492-4b6f-809e-12c61976bb0a',
#    'name': 'Ramblers',
#    'market': 'Loyola (IL)',
#    'rank': 15,
#    'prev_rank': 15,
#    'wins': 31,
#    'losses': 6,
#    'home_wins': 13,
#    'home_losses': 1,
#    'away_wins': 9,
#    'away_losses': 4,
#    'neut_wins': 9,
#    'neut_losses': 1,
#    'opp_wins': 613,
#    'opp_losses': 502,
#    'owp': 0.5426,
#    'oowp': 0.5205,
#    'awp': 0.8596,
#    'sos': 0.5352,
#    'rpi': 0.6163,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 1},
#     {'rank': '1-50', 'wins': 4, 'losses': 1},
#     {'rank': '101-150', 'wins': 8, 'losses': 2},
#     {'rank': '151+', 'wins': 14, 'losses': 2},
#     {'rank': '26-50', 'wins': 2, 'losses': 0},
#     {'rank': '51-100', 'wins': 5, 'losses': 1}]},
#   {'id': 'a41d5a05-4c11-4171-a57e-e7a1ea325a6d',
#    'name': 'Spartans',
#    'market': 'Michigan State',
#    'rank': 16,
#    'prev_rank': 16,
#    'wins': 30,
#    'losses': 5,
#    'home_wins': 16,
#    'home_losses': 1,
#    'away_wins': 8,
#    'away_losses': 1,
#    'neut_wins': 6,
#    'neut_losses': 3,
#    'opp_wins': 611,
#    'opp_losses': 499,
#    'owp': 0.5362,
#    'oowp': 0.5378,
#    'awp': 0.8428,
#    'sos': 0.5367,
#    'rpi': 0.6132,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 4},
#     {'rank': '1-50', 'wins': 2, 'losses': 5},
#     {'rank': '101-150', 'wins': 6, 'losses': 0},
#     {'rank': '151+', 'wins': 16, 'losses': 0},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 6, 'losses': 0}]},
#   {'id': 'a9f5c9a2-342c-4881-9996-5d5c05ec9bd9',
#    'name': 'Bulls',
#    'market': 'Buffalo',
#    'rank': 17,
#    'prev_rank': 17,
#    'wins': 26,
#    'losses': 9,
#    'home_wins': 13,
#    'home_losses': 1,
#    'away_wins': 8,
#    'away_losses': 5,
#    'neut_wins': 5,
#    'neut_losses': 3,
#    'opp_wins': 610,
#    'opp_losses': 461,
#    'owp': 0.5868,
#    'oowp': 0.5038,
#    'awp': 0.7643,
#    'sos': 0.5591,
#    'rpi': 0.6104,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 3},
#     {'rank': '1-50', 'wins': 1, 'losses': 6},
#     {'rank': '101-150', 'wins': 3, 'losses': 0},
#     {'rank': '151+', 'wins': 20, 'losses': 3},
#     {'rank': '26-50', 'wins': 0, 'losses': 3},
#     {'rank': '51-100', 'wins': 2, 'losses': 0}]},
#   {'id': '7e42bca2-3cd7-4aca-aa46-f190fe5d8eb4',
#    'name': 'Rams',
#    'market': 'Rhode Island',
#    'rank': 18,
#    'prev_rank': 18,
#    'wins': 26,
#    'losses': 8,
#    'home_wins': 15,
#    'home_losses': 1,
#    'away_wins': 7,
#    'away_losses': 4,
#    'neut_wins': 4,
#    'neut_losses': 3,
#    'opp_wins': 608,
#    'opp_losses': 454,
#    'owp': 0.5704,
#    'oowp': 0.5249,
#    'awp': 0.7703,
#    'sos': 0.5552,
#    'rpi': 0.609,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 3},
#     {'rank': '1-50', 'wins': 2, 'losses': 5},
#     {'rank': '101-150', 'wins': 9, 'losses': 1},
#     {'rank': '151+', 'wins': 11, 'losses': 0},
#     {'rank': '26-50', 'wins': 2, 'losses': 2},
#     {'rank': '51-100', 'wins': 4, 'losses': 2}]},
#   {'id': '2f4d21f8-6d5f-48a5-abca-52a30583871a',
#    'name': 'Bulldogs',
#    'market': 'Gonzaga',
#    'rank': 19,
#    'prev_rank': 19,
#    'wins': 32,
#    'losses': 5,
#    'home_wins': 15,
#    'home_losses': 1,
#    'away_wins': 10,
#    'away_losses': 1,
#    'neut_wins': 7,
#    'neut_losses': 3,
#    'opp_wins': 624,
#    'opp_losses': 517,
#    'owp': 0.5282,
#    'oowp': 0.514,
#    'awp': 0.8571,
#    'sos': 0.5235,
#    'rpi': 0.6069,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 1},
#     {'rank': '1-50', 'wins': 4, 'losses': 4},
#     {'rank': '101-150', 'wins': 6, 'losses': 0},
#     {'rank': '151+', 'wins': 16, 'losses': 0},
#     {'rank': '26-50', 'wins': 2, 'losses': 3},
#     {'rank': '51-100', 'wins': 6, 'losses': 1}]},
#   {'id': '9b166a3f-e64b-4825-bb6b-92c6f0418263',
#    'name': 'Wildcats',
#    'market': 'Arizona',
#    'rank': 20,
#    'prev_rank': 20,
#    'wins': 27,
#    'losses': 8,
#    'home_wins': 15,
#    'home_losses': 1,
#    'away_wins': 8,
#    'away_losses': 3,
#    'neut_wins': 4,
#    'neut_losses': 4,
#    'opp_wins': 628,
#    'opp_losses': 473,
#    'owp': 0.5545,
#    'oowp': 0.5455,
#    'awp': 0.7707,
#    'sos': 0.5515,
#    'rpi': 0.6063,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 2},
#     {'rank': '1-50', 'wins': 7, 'losses': 4},
#     {'rank': '101-150', 'wins': 4, 'losses': 1},
#     {'rank': '151+', 'wins': 9, 'losses': 0},
#     {'rank': '26-50', 'wins': 6, 'losses': 2},
#     {'rank': '51-100', 'wins': 7, 'losses': 3}]},
#   {'id': '857462b3-0ab6-4d26-9669-10ca354e382b',
#    'name': 'Buckeyes',
#    'market': 'Ohio State',
#    'rank': 21,
#    'prev_rank': 21,
#    'wins': 25,
#    'losses': 9,
#    'home_wins': 16,
#    'home_losses': 2,
#    'away_wins': 6,
#    'away_losses': 2,
#    'neut_wins': 3,
#    'neut_losses': 5,
#    'opp_wins': 675,
#    'opp_losses': 432,
#    'owp': 0.5945,
#    'oowp': 0.5355,
#    'awp': 0.7,
#    'sos': 0.5748,
#    'rpi': 0.6061,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 5},
#     {'rank': '1-50', 'wins': 5, 'losses': 5},
#     {'rank': '101-150', 'wins': 4, 'losses': 0},
#     {'rank': '151+', 'wins': 11, 'losses': 0},
#     {'rank': '26-50', 'wins': 2, 'losses': 0},
#     {'rank': '51-100', 'wins': 5, 'losses': 4}]},
#   {'id': 'ef184799-d79b-49d9-a662-991eaf4044cd',
#    'name': 'Aggies',
#    'market': 'Texas A&M',
#    'rank': 22,
#    'prev_rank': 22,
#    'wins': 22,
#    'losses': 13,
#    'home_wins': 13,
#    'home_losses': 3,
#    'away_wins': 4,
#    'away_losses': 7,
#    'neut_wins': 5,
#    'neut_losses': 3,
#    'opp_wins': 712,
#    'opp_losses': 443,
#    'owp': 0.6124,
#    'oowp': 0.5608,
#    'awp': 0.6174,
#    'sos': 0.5952,
#    'rpi': 0.6007,
#    'opponents': [{'rank': '1-25', 'wins': 4, 'losses': 5},
#     {'rank': '1-50', 'wins': 9, 'losses': 11},
#     {'rank': '101-150', 'wins': 3, 'losses': 0},
#     {'rank': '151+', 'wins': 5, 'losses': 0},
#     {'rank': '26-50', 'wins': 5, 'losses': 6},
#     {'rank': '51-100', 'wins': 5, 'losses': 2}]},
#   {'id': 'f8c705b7-87d3-411a-9c8b-5124daab0469',
#    'name': 'Red Raiders',
#    'market': 'Texas Tech',
#    'rank': 23,
#    'prev_rank': 23,
#    'wins': 27,
#    'losses': 10,
#    'home_wins': 17,
#    'home_losses': 1,
#    'away_wins': 4,
#    'away_losses': 6,
#    'neut_wins': 6,
#    'neut_losses': 3,
#    'opp_wins': 700,
#    'opp_losses': 477,
#    'owp': 0.5619,
#    'oowp': 0.5417,
#    'awp': 0.7315,
#    'sos': 0.5552,
#    'rpi': 0.5993,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 2},
#     {'rank': '1-50', 'wins': 7, 'losses': 5},
#     {'rank': '101-150', 'wins': 4, 'losses': 1},
#     {'rank': '151+', 'wins': 9, 'losses': 1},
#     {'rank': '26-50', 'wins': 4, 'losses': 3},
#     {'rank': '51-100', 'wins': 7, 'losses': 3}]},
#   {'id': '1f99a164-d593-4d81-85d5-0d7889d6f486',
#    'name': 'Cougars',
#    'market': 'Houston',
#    'rank': 24,
#    'prev_rank': 24,
#    'wins': 27,
#    'losses': 8,
#    'home_wins': 16,
#    'home_losses': 0,
#    'away_wins': 6,
#    'away_losses': 5,
#    'neut_wins': 5,
#    'neut_losses': 3,
#    'opp_wins': 610,
#    'opp_losses': 466,
#    'owp': 0.5305,
#    'oowp': 0.5245,
#    'awp': 0.7931,
#    'sos': 0.5285,
#    'rpi': 0.5946,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 4},
#     {'rank': '1-50', 'wins': 4, 'losses': 4},
#     {'rank': '101-150', 'wins': 4, 'losses': 1},
#     {'rank': '151+', 'wins': 12, 'losses': 2},
#     {'rank': '26-50', 'wins': 1, 'losses': 0},
#     {'rank': '51-100', 'wins': 7, 'losses': 1}]},
#   {'id': 'f38b58de-3273-4723-a78b-2f918e9aa2d5',
#    'name': 'Shockers',
#    'market': 'Wichita State',
#    'rank': 25,
#    'prev_rank': 25,
#    'wins': 25,
#    'losses': 8,
#    'home_wins': 13,
#    'home_losses': 3,
#    'away_wins': 9,
#    'away_losses': 2,
#    'neut_wins': 3,
#    'neut_losses': 3,
#    'opp_wins': 599,
#    'opp_losses': 426,
#    'owp': 0.5555,
#    'oowp': 0.5307,
#    'awp': 0.7358,
#    'sos': 0.5473,
#    'rpi': 0.5944,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 3},
#     {'rank': '1-50', 'wins': 3, 'losses': 3},
#     {'rank': '101-150', 'wins': 6, 'losses': 1},
#     {'rank': '151+', 'wins': 7, 'losses': 0},
#     {'rank': '26-50', 'wins': 1, 'losses': 0},
#     {'rank': '51-100', 'wins': 9, 'losses': 4}]},
#   {'id': '8cd24de1-2be8-4b77-bcfa-47be0495a5f4',
#    'name': 'Orange',
#    'market': 'Syracuse',
#    'rank': 26,
#    'prev_rank': 26,
#    'wins': 23,
#    'losses': 14,
#    'home_wins': 14,
#    'home_losses': 5,
#    'away_wins': 4,
#    'away_losses': 6,
#    'neut_wins': 5,
#    'neut_losses': 3,
#    'opp_wins': 728,
#    'opp_losses': 460,
#    'owp': 0.6164,
#    'oowp': 0.5539,
#    'awp': 0.5828,
#    'sos': 0.5956,
#    'rpi': 0.5924,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 7},
#     {'rank': '1-50', 'wins': 6, 'losses': 9},
#     {'rank': '101-150', 'wins': 5, 'losses': 1},
#     {'rank': '151+', 'wins': 8, 'losses': 2},
#     {'rank': '26-50', 'wins': 3, 'losses': 2},
#     {'rank': '51-100', 'wins': 4, 'losses': 2}]},
#   {'id': '22d90601-19d4-461b-a901-924d12f116ed',
#    'name': 'Bonnies',
#    'market': 'St. Bonaventure',
#    'rank': 27,
#    'prev_rank': 27,
#    'wins': 26,
#    'losses': 8,
#    'home_wins': 13,
#    'home_losses': 1,
#    'away_wins': 9,
#    'away_losses': 4,
#    'neut_wins': 4,
#    'neut_losses': 3,
#    'opp_wins': 575,
#    'opp_losses': 481,
#    'owp': 0.5323,
#    'oowp': 0.5215,
#    'awp': 0.7821,
#    'sos': 0.5287,
#    'rpi': 0.592,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 1},
#     {'rank': '1-50', 'wins': 6, 'losses': 3},
#     {'rank': '101-150', 'wins': 5, 'losses': 2},
#     {'rank': '151+', 'wins': 13, 'losses': 1},
#     {'rank': '26-50', 'wins': 4, 'losses': 2},
#     {'rank': '51-100', 'wins': 2, 'losses': 2}]},
#   {'id': '7aec5187-cb1b-45e5-8f7d-406d766cdc73',
#    'name': 'Hurricanes',
#    'market': 'Miami (FL)',
#    'rank': 28,
#    'prev_rank': 28,
#    'wins': 22,
#    'losses': 10,
#    'home_wins': 11,
#    'home_losses': 3,
#    'away_wins': 8,
#    'away_losses': 4,
#    'neut_wins': 3,
#    'neut_losses': 3,
#    'opp_wins': 589,
#    'opp_losses': 429,
#    'owp': 0.5711,
#    'oowp': 0.5402,
#    'awp': 0.6842,
#    'sos': 0.5608,
#    'rpi': 0.5917,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 5},
#     {'rank': '1-50', 'wins': 4, 'losses': 8},
#     {'rank': '101-150', 'wins': 1, 'losses': 1},
#     {'rank': '151+', 'wins': 13, 'losses': 1},
#     {'rank': '26-50', 'wins': 3, 'losses': 3},
#     {'rank': '51-100', 'wins': 4, 'losses': 0}]},
#   {'id': '5016fe1a-9571-4d10-bf5b-b9c1b496bd57',
#    'name': 'Aggies',
#    'market': 'New Mexico State',
#    'rank': 29,
#    'prev_rank': 29,
#    'wins': 25,
#    'losses': 6,
#    'home_wins': 11,
#    'home_losses': 1,
#    'away_wins': 8,
#    'away_losses': 3,
#    'neut_wins': 6,
#    'neut_losses': 2,
#    'opp_wins': 459,
#    'opp_losses': 457,
#    'owp': 0.519,
#    'oowp': 0.501,
#    'awp': 0.8207,
#    'sos': 0.513,
#    'rpi': 0.5899,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 1, 'losses': 3},
#     {'rank': '101-150', 'wins': 3, 'losses': 1},
#     {'rank': '151+', 'wins': 19, 'losses': 1},
#     {'rank': '26-50', 'wins': 1, 'losses': 2},
#     {'rank': '51-100', 'wins': 2, 'losses': 1}]},
#   {'id': 'f770d3a2-221c-49ce-9c7a-680f7417fe9e',
#    'name': 'Mountaineers',
#    'market': 'West Virginia',
#    'rank': 30,
#    'prev_rank': 30,
#    'wins': 26,
#    'losses': 11,
#    'home_wins': 14,
#    'home_losses': 3,
#    'away_wins': 5,
#    'away_losses': 5,
#    'neut_wins': 7,
#    'neut_losses': 3,
#    'opp_wins': 710,
#    'opp_losses': 476,
#    'owp': 0.5583,
#    'oowp': 0.5484,
#    'awp': 0.6871,
#    'sos': 0.555,
#    'rpi': 0.588,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 7},
#     {'rank': '1-50', 'wins': 6, 'losses': 8},
#     {'rank': '101-150', 'wins': 1, 'losses': 1},
#     {'rank': '151+', 'wins': 9, 'losses': 1},
#     {'rank': '26-50', 'wins': 3, 'losses': 1},
#     {'rank': '51-100', 'wins': 10, 'losses': 1}]},
#   {'id': '3d2f0819-8f3b-4ff3-afd6-6227c469a751',
#    'name': 'Blue Raiders',
#    'market': 'Middle Tennessee',
#    'rank': 31,
#    'prev_rank': 31,
#    'wins': 24,
#    'losses': 8,
#    'home_wins': 11,
#    'home_losses': 2,
#    'away_wins': 12,
#    'away_losses': 2,
#    'neut_wins': 1,
#    'neut_losses': 4,
#    'opp_wins': 547,
#    'opp_losses': 426,
#    'owp': 0.5461,
#    'oowp': 0.5051,
#    'awp': 0.7531,
#    'sos': 0.5324,
#    'rpi': 0.5876,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 4, 'losses': 4},
#     {'rank': '101-150', 'wins': 3, 'losses': 0},
#     {'rank': '151+', 'wins': 16, 'losses': 1},
#     {'rank': '26-50', 'wins': 4, 'losses': 3},
#     {'rank': '51-100', 'wins': 1, 'losses': 3}]},
#   {'id': 'f7fcbb6e-4a55-41ea-ba21-f763ed914467',
#    'name': 'Horned Frogs',
#    'market': 'TCU',
#    'rank': 32,
#    'prev_rank': 32,
#    'wins': 21,
#    'losses': 12,
#    'home_wins': 15,
#    'home_losses': 3,
#    'away_wins': 3,
#    'away_losses': 7,
#    'neut_wins': 3,
#    'neut_losses': 2,
#    'opp_wins': 653,
#    'opp_losses': 415,
#    'owp': 0.5926,
#    'oowp': 0.5444,
#    'awp': 0.609,
#    'sos': 0.5765,
#    'rpi': 0.5847,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 4},
#     {'rank': '1-50', 'wins': 3, 'losses': 6},
#     {'rank': '101-150', 'wins': 5, 'losses': 1},
#     {'rank': '151+', 'wins': 6, 'losses': 0},
#     {'rank': '26-50', 'wins': 2, 'losses': 2},
#     {'rank': '51-100', 'wins': 7, 'losses': 5}]},
#   {'id': 'aef5e386-d8e8-460c-8014-3a2f090fd988',
#    'name': 'Pirates',
#    'market': 'Seton Hall',
#    'rank': 33,
#    'prev_rank': 33,
#    'wins': 22,
#    'losses': 12,
#    'home_wins': 14,
#    'home_losses': 3,
#    'away_wins': 5,
#    'away_losses': 6,
#    'neut_wins': 3,
#    'neut_losses': 3,
#    'opp_wins': 647,
#    'opp_losses': 432,
#    'owp': 0.5773,
#    'oowp': 0.5424,
#    'awp': 0.6301,
#    'sos': 0.5657,
#    'rpi': 0.5818,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 6},
#     {'rank': '1-50', 'wins': 2, 'losses': 6},
#     {'rank': '101-150', 'wins': 6, 'losses': 0},
#     {'rank': '151+', 'wins': 8, 'losses': 2},
#     {'rank': '26-50', 'wins': 1, 'losses': 0},
#     {'rank': '51-100', 'wins': 6, 'losses': 4}]},
#   {'id': '912f8837-1d81-4ef9-a576-a21f271d4c64',
#    'name': 'Gators',
#    'market': 'Florida',
#    'rank': 34,
#    'prev_rank': 34,
#    'wins': 21,
#    'losses': 13,
#    'home_wins': 12,
#    'home_losses': 5,
#    'away_wins': 5,
#    'away_losses': 4,
#    'neut_wins': 4,
#    'neut_losses': 4,
#    'opp_wins': 661,
#    'opp_losses': 439,
#    'owp': 0.5927,
#    'oowp': 0.5601,
#    'awp': 0.5759,
#    'sos': 0.5818,
#    'rpi': 0.5804,
#    'opponents': [{'rank': '1-25', 'wins': 6, 'losses': 5},
#     {'rank': '1-50', 'wins': 11, 'losses': 8},
#     {'rank': '101-150', 'wins': 1, 'losses': 1},
#     {'rank': '151+', 'wins': 5, 'losses': 1},
#     {'rank': '26-50', 'wins': 5, 'losses': 3},
#     {'rank': '51-100', 'wins': 4, 'losses': 3}]},
#   {'id': 'c70c23c4-ab09-4797-a1af-792c848ab17f',
#    'name': 'Razorbacks',
#    'market': 'Arkansas',
#    'rank': 35,
#    'prev_rank': 35,
#    'wins': 23,
#    'losses': 12,
#    'home_wins': 15,
#    'home_losses': 2,
#    'away_wins': 3,
#    'away_losses': 7,
#    'neut_wins': 5,
#    'neut_losses': 3,
#    'opp_wins': 636,
#    'opp_losses': 472,
#    'owp': 0.5554,
#    'oowp': 0.5605,
#    'awp': 0.6454,
#    'sos': 0.5571,
#    'rpi': 0.5792,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 6},
#     {'rank': '1-50', 'wins': 6, 'losses': 9},
#     {'rank': '101-150', 'wins': 4, 'losses': 0},
#     {'rank': '151+', 'wins': 8, 'losses': 0},
#     {'rank': '26-50', 'wins': 3, 'losses': 3},
#     {'rank': '51-100', 'wins': 5, 'losses': 3}]},
#   {'id': 'b18f34af-a7f1-4659-a2e5-fc11a31cd316',
#    'name': 'Gaels',
#    'market': "Saint Mary's",
#    'rank': 35,
#    'prev_rank': 35,
#    'wins': 30,
#    'losses': 6,
#    'home_wins': 18,
#    'home_losses': 2,
#    'away_wins': 10,
#    'away_losses': 1,
#    'neut_wins': 2,
#    'neut_losses': 3,
#    'opp_wins': 552,
#    'opp_losses': 540,
#    'owp': 0.4994,
#    'oowp': 0.5109,
#    'awp': 0.8072,
#    'sos': 0.5033,
#    'rpi': 0.5792,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 1},
#     {'rank': '1-50', 'wins': 3, 'losses': 2},
#     {'rank': '101-150', 'wins': 9, 'losses': 1},
#     {'rank': '151+', 'wins': 16, 'losses': 1},
#     {'rank': '26-50', 'wins': 2, 'losses': 1},
#     {'rank': '51-100', 'wins': 2, 'losses': 2}]},
#   {'id': '6ef40534-5fad-4755-84de-7dcbd645d1f0',
#    'name': 'Jackrabbits',
#    'market': 'South Dakota State',
#    'rank': 37,
#    'prev_rank': 37,
#    'wins': 24,
#    'losses': 7,
#    'home_wins': 11,
#    'home_losses': 0,
#    'away_wins': 8,
#    'away_losses': 4,
#    'neut_wins': 5,
#    'neut_losses': 3,
#    'opp_wins': 445,
#    'opp_losses': 436,
#    'owp': 0.5021,
#    'oowp': 0.5033,
#    'awp': 0.8085,
#    'sos': 0.5025,
#    'rpi': 0.579,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 3},
#     {'rank': '1-50', 'wins': 1, 'losses': 3},
#     {'rank': '101-150', 'wins': 1, 'losses': 1},
#     {'rank': '151+', 'wins': 20, 'losses': 0},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 2, 'losses': 3}]},
#   {'id': '93df9b18-e9fc-42a7-bb45-a736c203b4dc',
#    'name': 'Huskies',
#    'market': 'Northeastern',
#    'rank': 38,
#    'prev_rank': 38,
#    'wins': 22,
#    'losses': 10,
#    'home_wins': 11,
#    'home_losses': 2,
#    'away_wins': 9,
#    'away_losses': 5,
#    'neut_wins': 2,
#    'neut_losses': 3,
#    'opp_wins': 501,
#    'opp_losses': 437,
#    'owp': 0.5523,
#    'oowp': 0.5033,
#    'awp': 0.7067,
#    'sos': 0.5359,
#    'rpi': 0.5786,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 1, 'losses': 2},
#     {'rank': '101-150', 'wins': 4, 'losses': 1},
#     {'rank': '151+', 'wins': 14, 'losses': 2},
#     {'rank': '26-50', 'wins': 1, 'losses': 1},
#     {'rank': '51-100', 'wins': 3, 'losses': 5}]},
#   {'id': 'd3c8a767-b6fc-45d4-a5f2-18406f2993f1',
#    'name': 'Seminoles',
#    'market': 'Florida State',
#    'rank': 39,
#    'prev_rank': 39,
#    'wins': 23,
#    'losses': 12,
#    'home_wins': 13,
#    'home_losses': 2,
#    'away_wins': 4,
#    'away_losses': 7,
#    'neut_wins': 6,
#    'neut_losses': 3,
#    'opp_wins': 646,
#    'opp_losses': 478,
#    'owp': 0.5519,
#    'oowp': 0.5486,
#    'awp': 0.6599,
#    'sos': 0.5508,
#    'rpi': 0.5781,
#    'opponents': [{'rank': '1-25', 'wins': 4, 'losses': 4},
#     {'rank': '1-50', 'wins': 9, 'losses': 7},
#     {'rank': '101-150', 'wins': 1, 'losses': 2},
#     {'rank': '151+', 'wins': 12, 'losses': 1},
#     {'rank': '26-50', 'wins': 5, 'losses': 3},
#     {'rank': '51-100', 'wins': 1, 'losses': 2}]},
#   {'id': '3a000455-de7c-4ca8-880e-abdce7f21da9',
#    'name': 'Trojans',
#    'market': 'USC',
#    'rank': 40,
#    'prev_rank': 40,
#    'wins': 24,
#    'losses': 12,
#    'home_wins': 13,
#    'home_losses': 5,
#    'away_wins': 6,
#    'away_losses': 5,
#    'neut_wins': 5,
#    'neut_losses': 2,
#    'opp_wins': 647,
#    'opp_losses': 466,
#    'owp': 0.5692,
#    'oowp': 0.5335,
#    'awp': 0.6386,
#    'sos': 0.5573,
#    'rpi': 0.5776,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 3},
#     {'rank': '1-50', 'wins': 4, 'losses': 7},
#     {'rank': '101-150', 'wins': 4, 'losses': 1},
#     {'rank': '151+', 'wins': 10, 'losses': 1},
#     {'rank': '26-50', 'wins': 4, 'losses': 4},
#     {'rank': '51-100', 'wins': 6, 'losses': 3}]},
#   {'id': '18e89867-9201-41ce-ba19-fadddf92fa17',
#    'name': 'Catamounts',
#    'market': 'Vermont',
#    'rank': 41,
#    'prev_rank': 41,
#    'wins': 26,
#    'losses': 8,
#    'home_wins': 11,
#    'home_losses': 2,
#    'away_wins': 12,
#    'away_losses': 5,
#    'neut_wins': 3,
#    'neut_losses': 1,
#    'opp_wins': 501,
#    'opp_losses': 499,
#    'owp': 0.5135,
#    'oowp': 0.4779,
#    'awp': 0.7952,
#    'sos': 0.5016,
#    'rpi': 0.575,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 4},
#     {'rank': '101-150', 'wins': 6, 'losses': 1},
#     {'rank': '151+', 'wins': 19, 'losses': 1},
#     {'rank': '26-50', 'wins': 0, 'losses': 3},
#     {'rank': '51-100', 'wins': 1, 'losses': 2}]},
#   {'id': '881380da-861c-4ab6-a7d2-20699d8ea883',
#    'name': 'Hilltoppers',
#    'market': 'Western Kentucky',
#    'rank': 42,
#    'prev_rank': 42,
#    'wins': 26,
#    'losses': 11,
#    'home_wins': 13,
#    'home_losses': 3,
#    'away_wins': 9,
#    'away_losses': 5,
#    'neut_wins': 4,
#    'neut_losses': 3,
#    'opp_wins': 655,
#    'opp_losses': 476,
#    'owp': 0.5434,
#    'oowp': 0.5018,
#    'awp': 0.7052,
#    'sos': 0.5295,
#    'rpi': 0.5734,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 1},
#     {'rank': '1-50', 'wins': 2, 'losses': 4},
#     {'rank': '101-150', 'wins': 4, 'losses': 2},
#     {'rank': '151+', 'wins': 14, 'losses': 3},
#     {'rank': '26-50', 'wins': 1, 'losses': 3},
#     {'rank': '51-100', 'wins': 6, 'losses': 2}]},
#   {'id': 'e52c9644-717a-46f4-bf16-aeca000b3b44',
#    'name': 'Huskies',
#    'market': 'Washington',
#    'rank': 43,
#    'prev_rank': 43,
#    'wins': 21,
#    'losses': 13,
#    'home_wins': 16,
#    'home_losses': 4,
#    'away_wins': 5,
#    'away_losses': 6,
#    'neut_wins': 0,
#    'neut_losses': 3,
#    'opp_wins': 622,
#    'opp_losses': 446,
#    'owp': 0.5951,
#    'oowp': 0.526,
#    'awp': 0.5764,
#    'sos': 0.5721,
#    'rpi': 0.5732,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 1},
#     {'rank': '1-50', 'wins': 3, 'losses': 5},
#     {'rank': '101-150', 'wins': 1, 'losses': 0},
#     {'rank': '151+', 'wins': 10, 'losses': 2},
#     {'rank': '26-50', 'wins': 1, 'losses': 4},
#     {'rank': '51-100', 'wins': 7, 'losses': 6}]},
#   {'id': 'ec0d6b67-4b16-4b50-92b2-1a651dae6b0f',
#    'name': 'Bruins',
#    'market': 'UCLA',
#    'rank': 44,
#    'prev_rank': 44,
#    'wins': 21,
#    'losses': 12,
#    'home_wins': 14,
#    'home_losses': 2,
#    'away_wins': 3,
#    'away_losses': 7,
#    'neut_wins': 4,
#    'neut_losses': 3,
#    'opp_wins': 607,
#    'opp_losses': 445,
#    'owp': 0.5627,
#    'oowp': 0.5421,
#    'awp': 0.6241,
#    'sos': 0.5559,
#    'rpi': 0.5729,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 3},
#     {'rank': '1-50', 'wins': 6, 'losses': 5},
#     {'rank': '101-150', 'wins': 2, 'losses': 0},
#     {'rank': '151+', 'wins': 9, 'losses': 1},
#     {'rank': '26-50', 'wins': 4, 'losses': 2},
#     {'rank': '51-100', 'wins': 4, 'losses': 6}]},
#   {'id': '0d037a5d-827a-44dd-8b70-57603d671d5d',
#    'name': 'Utes',
#    'market': 'Utah',
#    'rank': 45,
#    'prev_rank': 45,
#    'wins': 23,
#    'losses': 12,
#    'home_wins': 14,
#    'home_losses': 3,
#    'away_wins': 6,
#    'away_losses': 6,
#    'neut_wins': 3,
#    'neut_losses': 3,
#    'opp_wins': 639,
#    'opp_losses': 473,
#    'owp': 0.5518,
#    'oowp': 0.5366,
#    'awp': 0.6471,
#    'sos': 0.5467,
#    'rpi': 0.5718,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 2},
#     {'rank': '1-50', 'wins': 6, 'losses': 5},
#     {'rank': '101-150', 'wins': 1, 'losses': 1},
#     {'rank': '151+', 'wins': 10, 'losses': 0},
#     {'rank': '26-50', 'wins': 6, 'losses': 3},
#     {'rank': '51-100', 'wins': 6, 'losses': 6}]},
#   {'id': 'c2104cdc-c83d-40d2-a3cd-df986e29f5d3',
#    'name': 'Crimson Tide',
#    'market': 'Alabama',
#    'rank': 46,
#    'prev_rank': 46,
#    'wins': 20,
#    'losses': 16,
#    'home_wins': 12,
#    'home_losses': 5,
#    'away_wins': 2,
#    'away_losses': 8,
#    'neut_wins': 6,
#    'neut_losses': 3,
#    'opp_wins': 725,
#    'opp_losses': 435,
#    'owp': 0.6018,
#    'oowp': 0.5561,
#    'awp': 0.5195,
#    'sos': 0.5865,
#    'rpi': 0.5698,
#    'opponents': [{'rank': '1-25', 'wins': 6, 'losses': 6},
#     {'rank': '1-50', 'wins': 8, 'losses': 10},
#     {'rank': '101-150', 'wins': 2, 'losses': 1},
#     {'rank': '151+', 'wins': 3, 'losses': 2},
#     {'rank': '26-50', 'wins': 2, 'losses': 4},
#     {'rank': '51-100', 'wins': 7, 'losses': 3}]},
#   {'id': 'b795ddbc-baab-4499-8803-52e8608520ab',
#    'name': 'Cardinals',
#    'market': 'Louisville',
#    'rank': 47,
#    'prev_rank': 47,
#    'wins': 22,
#    'losses': 14,
#    'home_wins': 16,
#    'home_losses': 6,
#    'away_wins': 4,
#    'away_losses': 7,
#    'neut_wins': 2,
#    'neut_losses': 1,
#    'opp_wins': 701,
#    'opp_losses': 449,
#    'owp': 0.5878,
#    'oowp': 0.5441,
#    'awp': 0.5584,
#    'sos': 0.5733,
#    'rpi': 0.5696,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 8},
#     {'rank': '1-50', 'wins': 3, 'losses': 13},
#     {'rank': '101-150', 'wins': 5, 'losses': 0},
#     {'rank': '151+', 'wins': 10, 'losses': 0},
#     {'rank': '26-50', 'wins': 3, 'losses': 5},
#     {'rank': '51-100', 'wins': 4, 'losses': 1}]},
#   {'id': 'a1ba4b89-d97c-44e2-835f-79ad3ccaa5ae',
#    'name': 'Bulldogs',
#    'market': 'Mississippi State',
#    'rank': 48,
#    'prev_rank': 48,
#    'wins': 24,
#    'losses': 12,
#    'home_wins': 18,
#    'home_losses': 2,
#    'away_wins': 4,
#    'away_losses': 8,
#    'neut_wins': 2,
#    'neut_losses': 2,
#    'opp_wins': 617,
#    'opp_losses': 521,
#    'owp': 0.5355,
#    'oowp': 0.5463,
#    'awp': 0.6571,
#    'sos': 0.5391,
#    'rpi': 0.5686,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 5},
#     {'rank': '1-50', 'wins': 5, 'losses': 8},
#     {'rank': '101-150', 'wins': 3, 'losses': 1},
#     {'rank': '151+', 'wins': 10, 'losses': 1},
#     {'rank': '26-50', 'wins': 4, 'losses': 3},
#     {'rank': '51-100', 'wins': 6, 'losses': 2}]},
#   {'id': '77ca152a-cb2f-48a5-97b2-492351250d94',
#    'name': 'Tigers',
#    'market': 'Missouri',
#    'rank': 49,
#    'prev_rank': 49,
#    'wins': 19,
#    'losses': 13,
#    'home_wins': 12,
#    'home_losses': 3,
#    'away_wins': 5,
#    'away_losses': 6,
#    'neut_wins': 2,
#    'neut_losses': 4,
#    'opp_wins': 595,
#    'opp_losses': 431,
#    'owp': 0.5681,
#    'oowp': 0.5543,
#    'awp': 0.5786,
#    'sos': 0.5635,
#    'rpi': 0.5673,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 3},
#     {'rank': '1-50', 'wins': 6, 'losses': 9},
#     {'rank': '101-150', 'wins': 4, 'losses': 0},
#     {'rank': '151+', 'wins': 6, 'losses': 2},
#     {'rank': '26-50', 'wins': 3, 'losses': 6},
#     {'rank': '51-100', 'wins': 3, 'losses': 2}]},
#   {'id': '77a69fb0-1355-4342-ac09-b4cc7949d95e',
#    'name': 'Racers',
#    'market': 'Murray State',
#    'rank': 50,
#    'prev_rank': 50,
#    'wins': 24,
#    'losses': 6,
#    'home_wins': 12,
#    'home_losses': 2,
#    'away_wins': 10,
#    'away_losses': 3,
#    'neut_wins': 2,
#    'neut_losses': 1,
#    'opp_wins': 450,
#    'opp_losses': 441,
#    'owp': 0.4872,
#    'oowp': 0.4862,
#    'awp': 0.8056,
#    'sos': 0.4869,
#    'rpi': 0.5666,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 3},
#     {'rank': '101-150', 'wins': 1, 'losses': 1},
#     {'rank': '151+', 'wins': 20, 'losses': 1},
#     {'rank': '26-50', 'wins': 0, 'losses': 2},
#     {'rank': '51-100', 'wins': 3, 'losses': 1}]},
#   {'id': '0b73b9b9-1e29-4b14-b5d8-0405fe942e32',
#    'name': 'Broncs',
#    'market': 'Rider',
#    'rank': 51,
#    'prev_rank': 51,
#    'wins': 22,
#    'losses': 10,
#    'home_wins': 12,
#    'home_losses': 1,
#    'away_wins': 8,
#    'away_losses': 8,
#    'neut_wins': 2,
#    'neut_losses': 1,
#    'opp_wins': 503,
#    'opp_losses': 489,
#    'owp': 0.5194,
#    'oowp': 0.486,
#    'awp': 0.7391,
#    'sos': 0.5083,
#    'rpi': 0.566,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 1},
#     {'rank': '101-150', 'wins': 4, 'losses': 3},
#     {'rank': '151+', 'wins': 17, 'losses': 4},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 1, 'losses': 2}]},
#   {'id': '4aebd148-8119-4875-954c-66779867989b',
#    'name': 'Nittany Lions',
#    'market': 'Penn State',
#    'rank': 52,
#    'prev_rank': 52,
#    'wins': 26,
#    'losses': 13,
#    'home_wins': 15,
#    'home_losses': 4,
#    'away_wins': 6,
#    'away_losses': 7,
#    'neut_wins': 5,
#    'neut_losses': 2,
#    'opp_wins': 689,
#    'opp_losses': 529,
#    'owp': 0.5376,
#    'oowp': 0.5314,
#    'awp': 0.655,
#    'sos': 0.5356,
#    'rpi': 0.5654,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 5},
#     {'rank': '1-50', 'wins': 5, 'losses': 5},
#     {'rank': '101-150', 'wins': 0, 'losses': 2},
#     {'rank': '151+', 'wins': 15, 'losses': 2},
#     {'rank': '26-50', 'wins': 2, 'losses': 0},
#     {'rank': '51-100', 'wins': 6, 'losses': 4}]},
#   {'id': 'f8b1bf00-5b73-4ac4-98c0-ec554027ae32',
#    'name': 'Cornhuskers',
#    'market': 'Nebraska',
#    'rank': 53,
#    'prev_rank': 53,
#    'wins': 22,
#    'losses': 11,
#    'home_wins': 16,
#    'home_losses': 1,
#    'away_wins': 4,
#    'away_losses': 8,
#    'neut_wins': 2,
#    'neut_losses': 2,
#    'opp_wins': 575,
#    'opp_losses': 481,
#    'owp': 0.5251,
#    'oowp': 0.5298,
#    'awp': 0.6772,
#    'sos': 0.5267,
#    'rpi': 0.5643,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 5},
#     {'rank': '1-50', 'wins': 1, 'losses': 6},
#     {'rank': '101-150', 'wins': 4, 'losses': 1},
#     {'rank': '151+', 'wins': 15, 'losses': 1},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 2, 'losses': 3}]},
#   {'id': '98d2123a-c7b9-4b5f-8a81-43f76d8537dc',
#    'name': 'Bison',
#    'market': 'Bucknell',
#    'rank': 54,
#    'prev_rank': 54,
#    'wins': 25,
#    'losses': 10,
#    'home_wins': 14,
#    'home_losses': 1,
#    'away_wins': 10,
#    'away_losses': 8,
#    'neut_wins': 1,
#    'neut_losses': 1,
#    'opp_wins': 506,
#    'opp_losses': 523,
#    'owp': 0.5046,
#    'oowp': 0.4823,
#    'awp': 0.7647,
#    'sos': 0.4972,
#    'rpi': 0.5641,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 2},
#     {'rank': '1-50', 'wins': 1, 'losses': 4},
#     {'rank': '101-150', 'wins': 1, 'losses': 2},
#     {'rank': '151+', 'wins': 23, 'losses': 3},
#     {'rank': '26-50', 'wins': 1, 'losses': 2},
#     {'rank': '51-100', 'wins': 0, 'losses': 1}]},
#   {'id': '63cad858-8654-4956-8438-8fe79cd1208a',
#    'name': "Ragin' Cajuns",
#    'market': 'Louisiana-Lafayette',
#    'rank': 55,
#    'prev_rank': 55,
#    'wins': 25,
#    'losses': 7,
#    'home_wins': 12,
#    'home_losses': 1,
#    'away_wins': 10,
#    'away_losses': 4,
#    'neut_wins': 3,
#    'neut_losses': 2,
#    'opp_wins': 447,
#    'opp_losses': 487,
#    'owp': 0.4824,
#    'oowp': 0.4846,
#    'awp': 0.8067,
#    'sos': 0.4832,
#    'rpi': 0.564,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 1},
#     {'rank': '101-150', 'wins': 5, 'losses': 2},
#     {'rank': '151+', 'wins': 20, 'losses': 2},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 2}]},
#   {'id': 'e3848467-66c0-41e5-8283-02e3586d8601',
#    'name': 'Grizzlies',
#    'market': 'Montana',
#    'rank': 56,
#    'prev_rank': 56,
#    'wins': 24,
#    'losses': 8,
#    'home_wins': 12,
#    'home_losses': 0,
#    'away_wins': 8,
#    'away_losses': 6,
#    'neut_wins': 4,
#    'neut_losses': 2,
#    'opp_wins': 455,
#    'opp_losses': 498,
#    'owp': 0.4759,
#    'oowp': 0.4977,
#    'awp': 0.8,
#    'sos': 0.4832,
#    'rpi': 0.5624,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 2},
#     {'rank': '101-150', 'wins': 6, 'losses': 4},
#     {'rank': '151+', 'wins': 18, 'losses': 0},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 2}]},
#   {'id': '7d3b9c72-cbdd-4b64-9aa3-a5bde9b75fdc',
#    'name': 'Friars',
#    'market': 'Providence',
#    'rank': 57,
#    'prev_rank': 57,
#    'wins': 21,
#    'losses': 14,
#    'home_wins': 13,
#    'home_losses': 4,
#    'away_wins': 4,
#    'away_losses': 7,
#    'neut_wins': 4,
#    'neut_losses': 3,
#    'opp_wins': 677,
#    'opp_losses': 423,
#    'owp': 0.5663,
#    'oowp': 0.5405,
#    'awp': 0.5762,
#    'sos': 0.5577,
#    'rpi': 0.5623,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 6},
#     {'rank': '1-50', 'wins': 4, 'losses': 8},
#     {'rank': '101-150', 'wins': 4, 'losses': 0},
#     {'rank': '151+', 'wins': 7, 'losses': 3},
#     {'rank': '26-50', 'wins': 1, 'losses': 2},
#     {'rank': '51-100', 'wins': 6, 'losses': 3}]},
#   {'id': 'd203f38a-a166-4258-bca2-e161b591ecfb',
#    'name': 'Wildcats',
#    'market': 'Kansas State',
#    'rank': 58,
#    'prev_rank': 58,
#    'wins': 25,
#    'losses': 12,
#    'home_wins': 14,
#    'home_losses': 4,
#    'away_wins': 6,
#    'away_losses': 5,
#    'neut_wins': 5,
#    'neut_losses': 3,
#    'opp_wins': 667,
#    'opp_losses': 504,
#    'owp': 0.5207,
#    'oowp': 0.5523,
#    'awp': 0.6527,
#    'sos': 0.5312,
#    'rpi': 0.5616,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 6},
#     {'rank': '1-50', 'wins': 3, 'losses': 9},
#     {'rank': '101-150', 'wins': 5, 'losses': 0},
#     {'rank': '151+', 'wins': 10, 'losses': 0},
#     {'rank': '26-50', 'wins': 2, 'losses': 3},
#     {'rank': '51-100', 'wins': 7, 'losses': 3}]},
#   {'id': 'bdb7d7a4-45f8-4bf3-ab85-15488c451494',
#    'name': 'Bulldogs',
#    'market': 'Butler',
#    'rank': 59,
#    'prev_rank': 59,
#    'wins': 21,
#    'losses': 14,
#    'home_wins': 14,
#    'home_losses': 3,
#    'away_wins': 3,
#    'away_losses': 7,
#    'neut_wins': 4,
#    'neut_losses': 4,
#    'opp_wins': 670,
#    'opp_losses': 423,
#    'owp': 0.5624,
#    'oowp': 0.5447,
#    'awp': 0.5724,
#    'sos': 0.5565,
#    'rpi': 0.5605,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 6},
#     {'rank': '1-50', 'wins': 5, 'losses': 8},
#     {'rank': '101-150', 'wins': 2, 'losses': 1},
#     {'rank': '151+', 'wins': 9, 'losses': 1},
#     {'rank': '26-50', 'wins': 3, 'losses': 2},
#     {'rank': '51-100', 'wins': 5, 'losses': 4}]},
#   {'id': '6ed15092-2670-450a-99c2-61d861e87644',
#    'name': 'Longhorns',
#    'market': 'Texas',
#    'rank': 60,
#    'prev_rank': 60,
#    'wins': 19,
#    'losses': 15,
#    'home_wins': 13,
#    'home_losses': 4,
#    'away_wins': 4,
#    'away_losses': 7,
#    'neut_wins': 2,
#    'neut_losses': 4,
#    'opp_wins': 671,
#    'opp_losses': 430,
#    'owp': 0.5802,
#    'oowp': 0.5492,
#    'awp': 0.5274,
#    'sos': 0.5699,
#    'rpi': 0.5592,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 8},
#     {'rank': '1-50', 'wins': 4, 'losses': 10},
#     {'rank': '101-150', 'wins': 2, 'losses': 1},
#     {'rank': '151+', 'wins': 9, 'losses': 0},
#     {'rank': '26-50', 'wins': 3, 'losses': 2},
#     {'rank': '51-100', 'wins': 4, 'losses': 4}]},
#   {'id': 'c1c54dbf-805c-47fc-a707-c803e94db2a4',
#    'name': 'Broncos',
#    'market': 'Boise State',
#    'rank': 61,
#    'prev_rank': 61,
#    'wins': 22,
#    'losses': 9,
#    'home_wins': 14,
#    'home_losses': 1,
#    'away_wins': 6,
#    'away_losses': 6,
#    'neut_wins': 2,
#    'neut_losses': 2,
#    'opp_wins': 493,
#    'opp_losses': 453,
#    'owp': 0.4967,
#    'oowp': 0.5143,
#    'awp': 0.7287,
#    'sos': 0.5026,
#    'rpi': 0.5591,
#    'opponents': [{'rank': '1-25', 'wins': 1, 'losses': 2},
#     {'rank': '1-50', 'wins': 1, 'losses': 3},
#     {'rank': '101-150', 'wins': 5, 'losses': 1},
#     {'rank': '151+', 'wins': 12, 'losses': 3},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 4, 'losses': 2}]},
#   {'id': '9c396fa7-c165-4599-8542-158bd0d9a199',
#    'name': 'Raiders',
#    'market': 'Wright State',
#    'rank': 62,
#    'prev_rank': 62,
#    'wins': 23,
#    'losses': 10,
#    'home_wins': 12,
#    'home_losses': 2,
#    'away_wins': 8,
#    'away_losses': 7,
#    'neut_wins': 3,
#    'neut_losses': 1,
#    'opp_wins': 475,
#    'opp_losses': 509,
#    'owp': 0.5095,
#    'oowp': 0.487,
#    'awp': 0.7279,
#    'sos': 0.502,
#    'rpi': 0.5584,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 2},
#     {'rank': '1-50', 'wins': 0, 'losses': 4},
#     {'rank': '101-150', 'wins': 0, 'losses': 1},
#     {'rank': '151+', 'wins': 20, 'losses': 5},
#     {'rank': '26-50', 'wins': 0, 'losses': 2},
#     {'rank': '51-100', 'wins': 3, 'losses': 0}]},
#   {'id': '8548dacb-3636-48a8-8c46-611ab0c15fc0',
#    'name': 'Cougars',
#    'market': 'Charleston',
#    'rank': 63,
#    'prev_rank': 63,
#    'wins': 24,
#    'losses': 8,
#    'home_wins': 13,
#    'home_losses': 0,
#    'away_wins': 7,
#    'away_losses': 6,
#    'neut_wins': 4,
#    'neut_losses': 2,
#    'opp_wins': 446,
#    'opp_losses': 473,
#    'owp': 0.4656,
#    'oowp': 0.5074,
#    'awp': 0.7941,
#    'sos': 0.4796,
#    'rpi': 0.5582,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 3},
#     {'rank': '1-50', 'wins': 3, 'losses': 3},
#     {'rank': '101-150', 'wins': 3, 'losses': 1},
#     {'rank': '151+', 'wins': 16, 'losses': 3},
#     {'rank': '26-50', 'wins': 3, 'losses': 0},
#     {'rank': '51-100', 'wins': 2, 'losses': 1}]},
#   {'id': '612f7f66-1de1-4d42-b842-9a508daab911',
#    'name': 'Spartans',
#    'market': 'UNC Greensboro',
#    'rank': 64,
#    'prev_rank': 64,
#    'wins': 24,
#    'losses': 8,
#    'home_wins': 14,
#    'home_losses': 1,
#    'away_wins': 8,
#    'away_losses': 6,
#    'neut_wins': 2,
#    'neut_losses': 1,
#    'opp_wins': 457,
#    'opp_losses': 472,
#    'owp': 0.4792,
#    'oowp': 0.4915,
#    'awp': 0.7826,
#    'sos': 0.4833,
#    'rpi': 0.5581,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 2},
#     {'rank': '1-50', 'wins': 0, 'losses': 2},
#     {'rank': '101-150', 'wins': 3, 'losses': 1},
#     {'rank': '151+', 'wins': 16, 'losses': 4},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 5, 'losses': 1}]},
#   {'id': '8598d1b6-106b-4083-a512-2e495729525a',
#    'name': 'Owls',
#    'market': 'Temple',
#    'rank': 65,
#    'prev_rank': 65,
#    'wins': 17,
#    'losses': 16,
#    'home_wins': 8,
#    'home_losses': 5,
#    'away_wins': 4,
#    'away_losses': 9,
#    'neut_wins': 5,
#    'neut_losses': 2,
#    'opp_wins': 632,
#    'opp_losses': 405,
#    'owp': 0.5905,
#    'oowp': 0.5345,
#    'awp': 0.5168,
#    'sos': 0.5718,
#    'rpi': 0.558,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 7},
#     {'rank': '1-50', 'wins': 3, 'losses': 7},
#     {'rank': '101-150', 'wins': 5, 'losses': 2},
#     {'rank': '151+', 'wins': 5, 'losses': 3},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 4, 'losses': 4}]},
#   {'id': '2920c5fa-1e86-4958-a7c4-1e97b8e201d8',
#    'name': 'Wildcats',
#    'market': 'Davidson',
#    'rank': 65,
#    'prev_rank': 65,
#    'wins': 21,
#    'losses': 12,
#    'home_wins': 11,
#    'home_losses': 2,
#    'away_wins': 6,
#    'away_losses': 8,
#    'neut_wins': 4,
#    'neut_losses': 2,
#    'opp_wins': 559,
#    'opp_losses': 454,
#    'owp': 0.5222,
#    'oowp': 0.5234,
#    'awp': 0.6643,
#    'sos': 0.5226,
#    'rpi': 0.558,
#    'opponents': [{'rank': '1-25', 'wins': 2, 'losses': 5},
#     {'rank': '1-50', 'wins': 4, 'losses': 7},
#     {'rank': '101-150', 'wins': 4, 'losses': 1},
#     {'rank': '151+', 'wins': 13, 'losses': 4},
#     {'rank': '26-50', 'wins': 2, 'losses': 2},
#     {'rank': '51-100', 'wins': 0, 'losses': 0}]},
#   {'id': 'b2fda957-e15c-4fb2-8a13-6e58496f561e',
#    'name': 'Sooners',
#    'market': 'Oklahoma',
#    'rank': 67,
#    'prev_rank': 67,
#    'wins': 18,
#    'losses': 14,
#    'home_wins': 13,
#    'home_losses': 2,
#    'away_wins': 2,
#    'away_losses': 9,
#    'neut_wins': 3,
#    'neut_losses': 3,
#    'opp_wins': 620,
#    'opp_losses': 419,
#    'owp': 0.5662,
#    'oowp': 0.5467,
#    'awp': 0.5484,
#    'sos': 0.5597,
#    'rpi': 0.5569,
#    'opponents': [{'rank': '1-25', 'wins': 3, 'losses': 3},
#     {'rank': '1-50', 'wins': 6, 'losses': 7},
#     {'rank': '101-150', 'wins': 2, 'losses': 2},
# ...
#     {'rank': '151+', 'wins': 8, 'losses': 15},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 4}]},
#   {'id': '3556d445-b3f1-467e-b150-952b32dfb150',
#    'name': 'Pioneers',
#    'market': 'Sacred Heart',
#    'rank': 332,
#    'prev_rank': 332,
#    'wins': 9,
#    'losses': 21,
#    'home_wins': 4,
#    'home_losses': 9,
#    'away_wins': 4,
#    'away_losses': 11,
#    'neut_wins': 1,
#    'neut_losses': 1,
#    'opp_wins': 368,
#    'opp_losses': 512,
#    'owp': 0.4083,
#    'oowp': 0.4557,
#    'awp': 0.3082,
#    'sos': 0.4241,
#    'rpi': 0.3951,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 0},
#     {'rank': '101-150', 'wins': 0, 'losses': 4},
#     {'rank': '151+', 'wins': 9, 'losses': 16},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 1}]},
#   {'id': '8ddbfca9-a931-4908-aa31-9fcd17624b5f',
#    'name': '49ers',
#    'market': 'Charlotte',
#    'rank': 333,
#    'prev_rank': 333,
#    'wins': 5,
#    'losses': 23,
#    'home_wins': 3,
#    'home_losses': 11,
#    'away_wins': 2,
#    'away_losses': 12,
#    'neut_wins': 0,
#    'neut_losses': 0,
#    'opp_wins': 410,
#    'opp_losses': 437,
#    'owp': 0.4571,
#    'oowp': 0.4885,
#    'awp': 0.1691,
#    'sos': 0.4676,
#    'rpi': 0.393,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 3},
#     {'rank': '101-150', 'wins': 0, 'losses': 1},
#     {'rank': '151+', 'wins': 5, 'losses': 13},
#     {'rank': '26-50', 'wins': 0, 'losses': 3},
#     {'rank': '51-100', 'wins': 0, 'losses': 6}]},
#   {'id': '22fbe5dc-c6db-4675-b3a3-2d8af7f5d313',
#    'name': 'Bison',
#    'market': 'Howard',
#    'rank': 334,
#    'prev_rank': 334,
#    'wins': 8,
#    'losses': 23,
#    'home_wins': 5,
#    'home_losses': 4,
#    'away_wins': 2,
#    'away_losses': 18,
#    'neut_wins': 1,
#    'neut_losses': 1,
#    'opp_wins': 376,
#    'opp_losses': 557,
#    'owp': 0.4104,
#    'oowp': 0.4493,
#    'awp': 0.281,
#    'sos': 0.4234,
#    'rpi': 0.3878,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 1},
#     {'rank': '101-150', 'wins': 0, 'losses': 3},
#     {'rank': '151+', 'wins': 8, 'losses': 19},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 0}]},
#   {'id': '600aad0e-85e7-4db8-be0b-94ba02a08e55',
#    'name': 'Lancers',
#    'market': 'Longwood',
#    'rank': 335,
#    'prev_rank': 335,
#    'wins': 4,
#    'losses': 26,
#    'home_wins': 2,
#    'home_losses': 11,
#    'away_wins': 2,
#    'away_losses': 13,
#    'neut_wins': 0,
#    'neut_losses': 2,
#    'opp_wins': 404,
#    'opp_losses': 445,
#    'owp': 0.4726,
#    'oowp': 0.4668,
#    'awp': 0.137,
#    'sos': 0.4706,
#    'rpi': 0.3872,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 0},
#     {'rank': '101-150', 'wins': 0, 'losses': 3},
#     {'rank': '151+', 'wins': 4, 'losses': 18},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 5}]},
#   {'id': '2f513e67-f019-4eec-9096-fbc5911858b6',
#    'name': 'Eagles',
#    'market': 'American University',
#    'rank': 336,
#    'prev_rank': 336,
#    'wins': 6,
#    'losses': 24,
#    'home_wins': 4,
#    'home_losses': 8,
#    'away_wins': 2,
#    'away_losses': 16,
#    'neut_wins': 0,
#    'neut_losses': 0,
#    'opp_wins': 391,
#    'opp_losses': 482,
#    'owp': 0.4454,
#    'oowp': 0.4572,
#    'awp': 0.2,
#    'sos': 0.4493,
#    'rpi': 0.387,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 1},
#     {'rank': '101-150', 'wins': 0, 'losses': 1},
#     {'rank': '151+', 'wins': 6, 'losses': 18},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 4}]},
#   {'id': '1bddc811-44cf-4e53-b4ab-11c8dc82c9de',
#    'name': 'Braves',
#    'market': 'Alcorn State',
#    'rank': 337,
#    'prev_rank': 337,
#    'wins': 7,
#    'losses': 21,
#    'home_wins': 5,
#    'home_losses': 5,
#    'away_wins': 2,
#    'away_losses': 16,
#    'neut_wins': 0,
#    'neut_losses': 0,
#    'opp_wins': 318,
#    'opp_losses': 529,
#    'owp': 0.3979,
#    'oowp': 0.4737,
#    'awp': 0.2589,
#    'sos': 0.4232,
#    'rpi': 0.3821,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 0},
#     {'rank': '101-150', 'wins': 0, 'losses': 4},
#     {'rank': '151+', 'wins': 7, 'losses': 14},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 3}]},
#   {'id': 'd60357bd-1205-42e9-9092-d986a2843a34',
#    'name': 'Big Green',
#    'market': 'Dartmouth',
#    'rank': 338,
#    'prev_rank': 338,
#    'wins': 6,
#    'losses': 20,
#    'home_wins': 5,
#    'home_losses': 6,
#    'away_wins': 1,
#    'away_losses': 14,
#    'neut_wins': 0,
#    'neut_losses': 0,
#    'opp_wins': 328,
#    'opp_losses': 417,
#    'owp': 0.4277,
#    'oowp': 0.4647,
#    'awp': 0.2075,
#    'sos': 0.44,
#    'rpi': 0.3819,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 1},
#     {'rank': '101-150', 'wins': 0, 'losses': 7},
#     {'rank': '151+', 'wins': 6, 'losses': 11},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 1}]},
#   {'id': '5873529e-e5e3-4a06-8a03-fa4cbe509880',
#    'name': 'Delta Devils',
#    'market': 'Mississippi Valley State',
#    'rank': 339,
#    'prev_rank': 339,
#    'wins': 4,
#    'losses': 28,
#    'home_wins': 3,
#    'home_losses': 6,
#    'away_wins': 1,
#    'away_losses': 21,
#    'neut_wins': 0,
#    'neut_losses': 1,
#    'opp_wins': 418,
#    'opp_losses': 563,
#    'owp': 0.4586,
#    'oowp': 0.4574,
#    'awp': 0.127,
#    'sos': 0.4582,
#    'rpi': 0.3754,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 2},
#     {'rank': '101-150', 'wins': 0, 'losses': 5},
#     {'rank': '151+', 'wins': 4, 'losses': 20},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 1}]},
#   {'id': '2f8c85a7-54f4-4942-be16-2cbac77c82d7',
#    'name': 'Cougars',
#    'market': 'Chicago State',
#    'rank': 339,
#    'prev_rank': 339,
#    'wins': 1,
#    'losses': 29,
#    'home_wins': 1,
#    'home_losses': 8,
#    'away_wins': 0,
#    'away_losses': 19,
#    'neut_wins': 0,
#    'neut_losses': 2,
#    'opp_wins': 452,
#    'opp_losses': 441,
#    'owp': 0.4889,
#    'oowp': 0.5,
#    'awp': 0.0238,
#    'sos': 0.4926,
#    'rpi': 0.3754,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 4},
#     {'rank': '101-150', 'wins': 0, 'losses': 4},
#     {'rank': '151+', 'wins': 1, 'losses': 17},
#     {'rank': '26-50', 'wins': 0, 'losses': 3},
#     {'rank': '51-100', 'wins': 0, 'losses': 4}]},
#   {'id': '95a27dc5-16d5-4745-9adb-34c41e1444e8',
#    'name': 'Huskies',
#    'market': 'Houston Baptist',
#    'rank': 341,
#    'prev_rank': 341,
#    'wins': 3,
#    'losses': 25,
#    'home_wins': 2,
#    'home_losses': 8,
#    'away_wins': 1,
#    'away_losses': 16,
#    'neut_wins': 0,
#    'neut_losses': 1,
#    'opp_wins': 366,
#    'opp_losses': 430,
#    'owp': 0.4622,
#    'oowp': 0.4675,
#    'awp': 0.1066,
#    'sos': 0.464,
#    'rpi': 0.3746,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 1},
#     {'rank': '101-150', 'wins': 0, 'losses': 6},
#     {'rank': '151+', 'wins': 3, 'losses': 15},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 3}]},
#   {'id': '61dadefa-76bf-4db4-8067-f88df540b9cd',
#    'name': 'Bulldogs',
#    'market': 'Bryant University',
#    'rank': 342,
#    'prev_rank': 342,
#    'wins': 3,
#    'losses': 28,
#    'home_wins': 1,
#    'home_losses': 11,
#    'away_wins': 2,
#    'away_losses': 17,
#    'neut_wins': 0,
#    'neut_losses': 0,
#    'opp_wins': 419,
#    'opp_losses': 492,
#    'owp': 0.4599,
#    'oowp': 0.4569,
#    'awp': 0.1172,
#    'sos': 0.4589,
#    'rpi': 0.3735,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 1},
#     {'rank': '101-150', 'wins': 0, 'losses': 4},
#     {'rank': '151+', 'wins': 3, 'losses': 21},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 2}]},
#   {'id': 'cb732075-23a5-4e71-9037-50a7a002bdb2',
#    'name': 'Matadors',
#    'market': 'Cal State Northridge',
#    'rank': 343,
#    'prev_rank': 343,
#    'wins': 4,
#    'losses': 24,
#    'home_wins': 2,
#    'home_losses': 9,
#    'away_wins': 2,
#    'away_losses': 13,
#    'neut_wins': 0,
#    'neut_losses': 2,
#    'opp_wins': 351,
#    'opp_losses': 448,
#    'owp': 0.4301,
#    'oowp': 0.4801,
#    'awp': 0.1515,
#    'sos': 0.4467,
#    'rpi': 0.3729,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 0},
#     {'rank': '101-150', 'wins': 0, 'losses': 8},
#     {'rank': '151+', 'wins': 4, 'losses': 13},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 3}]},
#   {'id': '5f9a90a2-3926-404e-8c8a-d9f22ad6907d',
#    'name': 'Eagles',
#    'market': 'Coppin State',
#    'rank': 344,
#    'prev_rank': 344,
#    'wins': 5,
#    'losses': 27,
#    'home_wins': 4,
#    'home_losses': 6,
#    'away_wins': 1,
#    'away_losses': 20,
#    'neut_wins': 0,
#    'neut_losses': 1,
#    'opp_wins': 434,
#    'opp_losses': 544,
#    'owp': 0.44,
#    'oowp': 0.4522,
#    'awp': 0.1508,
#    'sos': 0.444,
#    'rpi': 0.3707,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 2},
#     {'rank': '101-150', 'wins': 0, 'losses': 2},
#     {'rank': '151+', 'wins': 5, 'losses': 21},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 2}]},
#   {'id': '2e78bd1b-9422-491e-9c73-37cf83b0e34e',
#    'name': 'Spartans',
#    'market': 'USC Upstate',
#    'rank': 345,
#    'prev_rank': 345,
#    'wins': 3,
#    'losses': 25,
#    'home_wins': 2,
#    'home_losses': 7,
#    'away_wins': 0,
#    'away_losses': 17,
#    'neut_wins': 1,
#    'neut_losses': 1,
#    'opp_wins': 363,
#    'opp_losses': 437,
#    'owp': 0.4542,
#    'oowp': 0.4757,
#    'awp': 0.0948,
#    'sos': 0.4614,
#    'rpi': 0.3697,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 0},
#     {'rank': '101-150', 'wins': 0, 'losses': 4},
#     {'rank': '151+', 'wins': 3, 'losses': 16},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 5}]},
#   {'id': '0095032d-6143-44f2-8974-f6815fc56c5b',
#    'name': 'Black Bears',
#    'market': 'Maine',
#    'rank': 346,
#    'prev_rank': 346,
#    'wins': 4,
#    'losses': 26,
#    'home_wins': 2,
#    'home_losses': 8,
#    'away_wins': 2,
#    'away_losses': 16,
#    'neut_wins': 0,
#    'neut_losses': 2,
#    'opp_wins': 410,
#    'opp_losses': 475,
#    'owp': 0.4307,
#    'oowp': 0.4629,
#    'awp': 0.1493,
#    'sos': 0.4414,
#    'rpi': 0.3684,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 4},
#     {'rank': '101-150', 'wins': 0, 'losses': 6},
#     {'rank': '151+', 'wins': 4, 'losses': 16},
#     {'rank': '26-50', 'wins': 0, 'losses': 3},
#     {'rank': '51-100', 'wins': 0, 'losses': 0}]},
#   {'id': '912671c7-19fd-451b-813e-885485427820',
#    'name': 'Cardinals',
#    'market': 'Incarnate Word',
#    'rank': 347,
#    'prev_rank': 347,
#    'wins': 3,
#    'losses': 21,
#    'home_wins': 2,
#    'home_losses': 9,
#    'away_wins': 1,
#    'away_losses': 12,
#    'neut_wins': 0,
#    'neut_losses': 0,
#    'opp_wins': 307,
#    'opp_losses': 371,
#    'owp': 0.4473,
#    'oowp': 0.4625,
#    'awp': 0.1161,
#    'sos': 0.4524,
#    'rpi': 0.3683,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 2},
#     {'rank': '1-50', 'wins': 0, 'losses': 3},
#     {'rank': '101-150', 'wins': 0, 'losses': 4},
#     {'rank': '151+', 'wins': 3, 'losses': 14},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 0}]},
#   {'id': 'd20216d8-161c-46e3-b8d2-92208ddf5acf',
#    'name': 'Hawks',
#    'market': 'Maryland-Eastern Shore',
#    'rank': 348,
#    'prev_rank': 348,
#    'wins': 5,
#    'losses': 25,
#    'home_wins': 4,
#    'home_losses': 5,
#    'away_wins': 0,
#    'away_losses': 18,
#    'neut_wins': 1,
#    'neut_losses': 2,
#    'opp_wins': 392,
#    'opp_losses': 510,
#    'owp': 0.434,
#    'oowp': 0.4453,
#    'awp': 0.1466,
#    'sos': 0.4377,
#    'rpi': 0.3649,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 1},
#     {'rank': '101-150', 'wins': 0, 'losses': 0},
#     {'rank': '151+', 'wins': 5, 'losses': 20},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 4}]},
#   {'id': '71874e7e-8260-43f9-bb7c-65f267dbe8ce',
#    'name': 'Demons',
#    'market': 'Northwestern State',
#    'rank': 349,
#    'prev_rank': 349,
#    'wins': 2,
#    'losses': 23,
#    'home_wins': 0,
#    'home_losses': 10,
#    'away_wins': 2,
#    'away_losses': 13,
#    'neut_wins': 0,
#    'neut_losses': 0,
#    'opp_wins': 324,
#    'opp_losses': 387,
#    'owp': 0.4263,
#    'oowp': 0.4723,
#    'awp': 0.1138,
#    'sos': 0.4417,
#    'rpi': 0.3597,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 1},
#     {'rank': '101-150', 'wins': 0, 'losses': 7},
#     {'rank': '151+', 'wins': 2, 'losses': 13},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 2}]},
#   {'id': '949c3398-85e4-4c63-ba71-9a82e06ddea4',
#    'name': 'Bulldogs',
#    'market': 'Alabama A&M',
#    'rank': 350,
#    'prev_rank': 350,
#    'wins': 3,
#    'losses': 28,
#    'home_wins': 2,
#    'home_losses': 9,
#    'away_wins': 1,
#    'away_losses': 18,
#    'neut_wins': 0,
#    'neut_losses': 1,
#    'opp_wins': 376,
#    'opp_losses': 565,
#    'owp': 0.4189,
#    'oowp': 0.4673,
#    'awp': 0.0963,
#    'sos': 0.4351,
#    'rpi': 0.3504,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 1},
#     {'rank': '1-50', 'wins': 0, 'losses': 2},
#     {'rank': '101-150', 'wins': 0, 'losses': 3},
#     {'rank': '151+', 'wins': 3, 'losses': 23},
#     {'rank': '26-50', 'wins': 0, 'losses': 1},
#     {'rank': '51-100', 'wins': 0, 'losses': 0}]},
#   {'id': 'ffa04cde-aa2d-4e91-b2cd-bde2bfed44de',
#    'name': 'Hornets',
#    'market': 'Delaware State',
#    'rank': 351,
#    'prev_rank': 351,
#    'wins': 2,
#    'losses': 28,
#    'home_wins': 2,
#    'home_losses': 9,
#    'away_wins': 0,
#    'away_losses': 18,
#    'neut_wins': 0,
#    'neut_losses': 1,
#    'opp_wins': 371,
#    'opp_losses': 530,
#    'owp': 0.4108,
#    'oowp': 0.444,
#    'awp': 0.0469,
#    'sos': 0.4219,
#    'rpi': 0.3281,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 0},
#     {'rank': '101-150', 'wins': 0, 'losses': 2},
#     {'rank': '151+', 'wins': 2, 'losses': 24},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 2}]},
#   {'id': '61db8108-45f1-43e5-ade8-83278324bc7d',
#    'name': 'Lions',
#    'market': 'North Alabama',
#    'rank': 352,
#    'prev_rank': 352,
#    'wins': 0,
#    'losses': 0,
#    'home_wins': 0,
#    'home_losses': 0,
#    'away_wins': 0,
#    'away_losses': 0,
#    'neut_wins': 0,
#    'neut_losses': 0,
#    'opp_wins': 0,
#    'opp_losses': 0,
#    'owp': 0.0,
#    'oowp': 0.0,
#    'awp': 0.0,
#    'sos': 0.0,
#    'rpi': 0.0,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 0},
#     {'rank': '101-150', 'wins': 0, 'losses': 0},
#     {'rank': '151+', 'wins': 0, 'losses': 0},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 0}]},
#   {'id': 'a43197e1-de68-41cf-bd75-88c695738601',
#    'name': 'Lancers',
#    'market': 'California Baptist',
#    'rank': 352,
#    'prev_rank': 352,
#    'wins': 0,
#    'losses': 0,
#    'home_wins': 0,
#    'home_losses': 0,
#    'away_wins': 0,
#    'away_losses': 0,
#    'neut_wins': 0,
#    'neut_losses': 0,
#    'opp_wins': 0,
#    'opp_losses': 0,
#    'owp': 0.0,
#    'oowp': 0.0,
#    'awp': 0.0,
#    'sos': 0.0,
#    'rpi': 0.0,
#    'opponents': [{'rank': '1-25', 'wins': 0, 'losses': 0},
#     {'rank': '1-50', 'wins': 0, 'losses': 0},
#     {'rank': '101-150', 'wins': 0, 'losses': 0},
#     {'rank': '151+', 'wins': 0, 'losses': 0},
#     {'rank': '26-50', 'wins': 0, 'losses': 0},
#     {'rank': '51-100', 'wins': 0, 'losses': 0}]}]}

# %%
#352
chicken_face = turkey_farts['rankings'][0]#['rank']
chicken_face
# Out:
# {'id': '4383eb6a-7fd8-4ff2-94c5-43c933121e88',
#  'name': 'Wildcats',
#  'market': 'Villanova',
#  'rank': 1,
#  'prev_rank': 1,
#  'wins': 36,
#  'losses': 4,
#  'home_wins': 12,
#  'home_losses': 1,
#  'away_wins': 9,
#  'away_losses': 3,
#  'neut_wins': 15,
#  'neut_losses': 0,
#  'opp_wins': 792,
#  'opp_losses': 478,
#  'owp': 0.613,
#  'oowp': 0.5457,
#  'awp': 0.9158,
#  'sos': 0.5906,
#  'rpi': 0.6719,
#  'opponents': [{'rank': '1-25', 'wins': 7, 'losses': 0},
#   {'rank': '1-50', 'wins': 12, 'losses': 0},
#   {'rank': '101-150', 'wins': 7, 'losses': 1},
#   {'rank': '151+', 'wins': 7, 'losses': 0},
#   {'rank': '26-50', 'wins': 5, 'losses': 0},
#   {'rank': '51-100', 'wins': 10, 'losses': 3}]}

# %%
team_id = []
team_name = []
rank = []
total_wins = []
total_losses = []
adj_win_perc = []
str_of_sched = []
rpi = []

# %%
m=0
for m in range(0,353):
#for turkey in turkey_farts:
    chicken_face = turkey_farts['rankings'][m]
    #print(turkey_farts['rankings'][m]["rank"])
    team_id.append(turkey_farts['rankings'][m]["id"])
    team_name.append(turkey_farts['rankings'][m]["name"])
    rank.append(turkey_farts['rankings'][m]["rank"])
    total_wins.append(turkey_farts['rankings'][m]["wins"])
    total_losses.append(turkey_farts['rankings'][m]["losses"])
    adj_win_perc.append(turkey_farts['rankings'][m]["awp"])
    str_of_sched.append(turkey_farts['rankings'][m]["sos"])
    rpi.append(turkey_farts['rankings'][m]["rpi"])

# %%
zippedList2 = list(zip(team_id,team_name,rank,total_wins,total_losses,adj_win_perc,str_of_sched,rpi))

# %%
team_wins_df = pd.DataFrame({"team_id":team_id,
                      "team_name":team_name,
                      "rank":rank,
                      "total_wins":total_wins,
                      "total_losses":total_losses,
                      "adj_win_perc":adj_win_perc,
                      "str_of_sched":str_of_sched,
                      "rpi":rpi})

# %%
team_wins_df.to_csv("2017_Reg_Season_win_loss.csv", index=False)
